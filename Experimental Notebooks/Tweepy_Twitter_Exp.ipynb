# %%
from __future__ import absolute_import, print_function

from tweepy import OAuthHandler, Stream, StreamListener

# Go to http://apps.twitter.com and create an app.
# The consumer key and secret will be generated for you after
consumer_key="yUPNsUd8nAz0BmHzGqyC88POR"
consumer_secret="901nAY1xXwaQxWhU2X8KJwftrfEEXJuoOkTdyDKolhnCDyKbCo"

# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
access_token="1047724181079478272-VZ9ZsVejLzZAh0rRWj6UWrw3oCnB5t"
access_token_secret="bSu67sTf7tE4gFEDAvmQ21AaK05VvkS3tGqQ9kphzI0ci"

class StdOutListener(StreamListener):
    """ A listener handles tweets that are received from the stream.
    This is a basic listener that just prints received tweets to stdout.

    """
    def on_data(self, data):
        print(data)
        return True

    def on_error(self, status):
        print(status)

if __name__ == '__main__':
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    stream = Stream(auth, l)
    stream.filter(track=['rekening'],languages=["id"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6320c6fe3306> in <module>()
#      31
#      32     stream = Stream(auth, l)
# ---> 33     stream.filter(track=['rekening'],languages=["id"])
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python3.6/dist-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# ...

# %%
import tweepy

# Go to http://apps.twitter.com and create an app.
# The consumer key and secret will be generated for you after
consumer_key="yUPNsUd8nAz0BmHzGqyC88POR"
consumer_secret="901nAY1xXwaQxWhU2X8KJwftrfEEXJuoOkTdyDKolhnCDyKbCo"

# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
access_token="1047724181079478272-VZ9ZsVejLzZAh0rRWj6UWrw3oCnB5t"
access_token_secret="bSu67sTf7tE4gFEDAvmQ21AaK05VvkS3tGqQ9kphzI0ci"


# Authenticate to Twitter
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Create API object
api = tweepy.API(auth, wait_on_rate_limit=True,
    wait_on_rate_limit_notify=True)

# %%
for tweet in api.search(q="akun bank", lang="id", rpp=100):
    print(f"{tweet.user.name}:{tweet.text}")
    print("------------")
# Out:
# LL - ON:LL yang jual akun inactive, f gede, t kecil, drop dong. Budget 50k via bank / ovo.
# ------------
# vant€ wif€:RT @indomymenfess: [idm] spotify premium
# 2bln: 20k
# Legal,bisa akun lama yg sudah premium
# Pembayaran via bank/pulsa/ovo
#
# Minat dm @minchimm…
# ------------
# idm.:[idm] spotify premium
# 2bln: 20k
# Legal,bisa akun lama yg sudah premium
# Pembayaran via bank/pulsa/ovo
#
# Minat dm… https://t.co/JghPkckKbn
# ------------
# Tomio:RT @WAMINFO: Yuk ikutan, siapa tau kali ini giliran kalian yg b’untung mdptkn power bank. Caranya: Like &amp; Follow akun sosmed WAMI, like pos…
# ------------
# DANA.id:@Azakizam Hi Zaki, silakan coba pake fitur Kirim DANA dg cara buka app DANA - klik “Kirim” - klik “+ Kirim ke Reken… https://t.co/KwKOxnLxsA
# ------------
# Tiara:Astagfirullah aku kaget liat dm bank dsp kirain dibekuin ternyata dm di akun toko. :")
# ------------
# ...

# %%
import json
import tweepy

class MyStreamListener(tweepy.StreamListener):
    def __init__(self, api):
        self.api = api
        self.me = api.me()

    def on_status(self, tweet):
        print(f"{tweet.user.name}:{tweet.text}")

    def on_error(self, status):
        print("Error detected")

tweets_listener = MyStreamListener(api)
stream = tweepy.Stream(api.auth, tweets_listener)
stream.filter(track=["mutual fund"], languages=["en"])
# Out:
# Andy.com:In terms of susu (mutual fund) you just have to be careful about the person keeping the money -Mr Eric Kweku Mensah… https://t.co/2JxMuJcRhG
# Mint Events:Mint brings to you the 6th edition of Mint Mutual Fund Conclave which will talk about India’s #MutualFund Industry.… https://t.co/W8yxn9p2o9
# Nifty Team Bangalore:@Trendmyfriends Only Mutual Fund Distributor &amp; PMS-MF Fund Manager is screaming about the bottom as they need fund… https://t.co/eUjQfC0Cda
# avinash singh:https://t.co/BDqwimhofN If you have any mutual fund queries, message on ET Mutual Funds on Facebook. We will get it… https://t.co/I3GXvSjamz
# Samuel Scoot:Mutual Fund Transfer Agent Market Expected to Deliver Dynamic Progression until 2026 with a CAGR of 5.60%… https://t.co/f0P7ZUYKpW
# sreekanth:@anilbalaji11 Thank u. U r telling about 19 % negative return in Bluechip mutual fund right?
# Becuz mid cap and sma… https://t.co/SOPuc5puRj
# ...
