# %%
# !python -m gensim.downloader -d glove-wiki-gigaword-50  # download model in word2vec format
# Out:
# 2019-07-26 09:49:43,422 : gensim.api : INFO : Creating /root/gensim-data
# [==================================================] 100.0% 66.0/66.0MB downloaded
# 2019-07-26 09:49:47,928 : gensim.api : INFO : glove-wiki-gigaword-50 downloaded
# 2019-07-26 09:49:47,928 : gensim.api : INFO : Data has been installed and data path is /root/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.id.zip
# Out:
# --2019-07-26 09:50:34--  https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.id.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.20.6.166, 104.20.22.166, 2606:4700:10::6814:6a6, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.20.6.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3243640514 (3.0G) [application/zip]
# Saving to: ‘wiki.id.zip’
#
# wiki.id.zip         100%[===================>]   3.02G  42.3MB/s    in 75s
#
# 2019-07-26 09:51:50 (41.0 MB/s) - ‘wiki.id.zip’ saved [3243640514/3243640514]

# %%
# !python -m gensim.scripts.word2vec2tensor -i ~/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz -o /content/
# Out:
# 2019-07-26 09:53:25,277 - word2vec2tensor - INFO - running /usr/local/lib/python3.6/dist-packages/gensim/scripts/word2vec2tensor.py -i /root/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz -o /content/
# 2019-07-26 09:53:25,278 - utils_any2vec - INFO - loading projection weights from /root/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-07-26 09:53:45,902 - utils_any2vec - INFO - loaded (400000, 50) matrix from /root/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz
# 2019-07-26 09:54:01,012 - word2vec2tensor - INFO - 2D tensor file saved to /content/_tensor.tsv
# ...

# %%
# !unzip wiki.id.zip
# Out:
# Archive:  wiki.id.zip
#   inflating: wiki.id.vec
#   inflating: wiki.id.bin

# %%
# !python -m gensim.scripts.word2vec2tensor -i /content/wiki.id.vec -o /content/
# Out:
# 2019-07-26 09:56:34,380 - word2vec2tensor - INFO - running /usr/local/lib/python3.6/dist-packages/gensim/scripts/word2vec2tensor.py -i /content/wiki.id.vec -o /content/
# 2019-07-26 09:56:34,381 - utils_any2vec - INFO - loading projection weights from /content/wiki.id.vec
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-07-26 09:57:49,007 - utils_any2vec - INFO - loaded (300686, 300) matrix from /content/wiki.id.vec
# 2019-07-26 09:58:48,620 - word2vec2tensor - INFO - 2D tensor file saved to /content/_tensor.tsv
# 2019-07-26 09:58:48,621 - word2vec2tensor - INFO - Tensor metadata file saved to /content/_metadata.tsv
# ...

# %%
# !ls -l --block-size=G
# Out:
# total 8G
# -rw-r--r-- 1 root root 1G Jul 26 09:58 _metadata.tsv
# drwxr-xr-x 1 root root 1G Jul 19 16:14 sample_data
# -rw-r--r-- 1 root root 1G Jul 26 09:58 _tensor.tsv
# -rw-r--r-- 1 root root 3G Oct 19  2017 wiki.id.bin
# -rw-rw-r-- 1 root root 1G Sep 19  2016 wiki.id.vec
# -rw-r--r-- 1 root root 4G Jan 18  2019 wiki.id.zip

# %%
import pandas as pd
df = pd.read_csv("/content/_tensor.tsv", sep="\t")

# %%
len(df)
# Out:
# 300685

# %%
df_sub = df[:50000]

# %%
df_sub.to_csv("model.tsv",sep="\t")

# %%
import sys
import csv

csv.field_size_limit(sys.maxsize)
# Out:
# 131072

# %%
import pandas as pd
df_m = pd.read_csv("/content/_metadata.tsv", sep="\t", engine="python" )
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/io/parsers.py in _next_iter_line(self, row_num)
#    2853         try:
# -> 2854             return next(self.data)
#    2855         except csv.Error as e:
#
# Error: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-0cb7a4246203> in <module>()
#       1 import pandas as pd
# ----> 2 df_m = pd.read_csv("/content/_metadata.tsv", sep="\t", engine="python" )
#
# ...
