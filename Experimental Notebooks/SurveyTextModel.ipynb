# %% [markdown]
# # Library Installation

# %%
# !pip install rake-nltk
# !pip install -U textblob
# !pip install flask_jsonpify
# !!pip install swifter
# !python -m textblob.download_corpora
# !pip install numba
import spacy.cli
spacy.cli.download("en_core_web_md")

# spacy.cli.download("en_core_web_lg")
# Out:
# Collecting rake-nltk
#   Downloading https://files.pythonhosted.org/packages/8e/c4/b4ff57e541ac5624ad4b20b89c2bafd4e98f29fd83139f3a81858bdb3815/rake_nltk-1.0.4.tar.gz
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from rake-nltk) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk->rake-nltk) (1.12.0)
# Building wheels for collected packages: rake-nltk
#   Building wheel for rake-nltk (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.4
# Requirement already up-to-date: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied, skipping upgrade: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.12.0)
# Collecting flask_jsonpify
#   Downloading https://files.pythonhosted.org/packages/60/0f/c389dea3988bffbe32c1a667989914b1cc0bce31b338c8da844d5e42b503/Flask-Jsonpify-1.5.0.tar.gz
# Requirement already satisfied: Flask in /usr/local/lib/python3.6/dist-packages (from flask_jsonpify) (1.0.2)
# Requirement already satisfied: Werkzeug>=0.14 in /usr/local/lib/python3.6/dist-packages (from Flask->flask_jsonpify) (0.15.3)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from Flask->flask_jsonpify) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from Flask->flask_jsonpify) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.6/dist-packages (from Flask->flask_jsonpify) (2.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10->Flask->flask_jsonpify) (1.1.1)
# Building wheels for collected packages: flask-jsonpify
#   Building wheel for flask-jsonpify (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/ea/a9/40/ac47ad604861c1a40499042d30c22cdb7d1fa1abf426597788
# Successfully built flask-jsonpify
# Installing collected packages: flask-jsonpify
# Successfully installed flask-jsonpify-1.5.0
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.
#
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/en_core_web_md -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/en_core_web_md
#
#     You can now load the model via spacy.load('en_core_web_md')

# %% [markdown]
# # Library Import & Data Loading

# %%
# Libraries 
import pandas as pd
from rake_nltk import Metric, Rake
from textblob import TextBlob
from textblob.np_extractors import ConllExtractor
from textblob.sentiments import NaiveBayesAnalyzer
import numba

# %%
data = pd.read_csv("cleaned_bank_cust_complaints_med.csv")

# %%
data.head(5)
# Out:
#                                              Product  ... category_id
# 0  Credit reporting, credit repair services, or o...  ...           0
# 1  Credit reporting, credit repair services, or o...  ...           0
# 2  Credit reporting, credit repair services, or o...  ...           0
# 3  Credit reporting, credit repair services, or o...  ...           0
# 4  Credit reporting, credit repair services, or o...  ...           0
#
# [5 rows x 3 columns]

# %%
data_mini = data[:10000]

# %%
len(data_mini)
# Out:
# 10000

# %%
import spacy # (I have version 2.0.18)

# %%
nlp = spacy.load('en')

# %%
@numba.jit()
def docObject(eachValue):
  return nlp(eachValue)

# %%
# %timeit data_mini['Consumer_complaint_narrative_spacy_object'] = data_mini['Consumer_complaint_narrative'].apply(docObject)
# Out:
# CPU times: user 14min 41s, sys: 6min 10s, total: 20min 52s
# Wall time: 10min 37s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# %time data_mini['Consumer_complaint_narrative_spacy_object'] = data_mini['Consumer_complaint_narrative'].apply(docObject)
# Out:
# CPU times: user 17min 13s, sys: 6min 29s, total: 23min 43s
# Wall time: 12min 5s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Cleaning, Sentiment, Topics, NounPhrase & NounAdjectivePair

# %%
# Text Cleaning 
import string

def TextCleaning(eachValue):
  try:
    return eachValue.translate(str.maketrans('', '', string.punctuation)).lower()
  except AttributeError:
    return []

# %%
data_mini['CleanTranslate'] = data_mini.Consumer_complaint_narrative.apply(TextCleaning)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
numba.jit()
def GetSentiment(eachValue):
  try:
    return float("{0:.2f}".format(TextBlob(eachValue).sentiment.polarity))
  except TypeError:
    return []

# %%
def GetSentimentSubjectivity(eachValue):
  try:
    return float("{0:.2f}".format(TextBlob(eachValue).sentiment.subjectivity))
  except TypeError:
    return []

# %%
def GetNounPhrase(eachValue):
  try:
    return TextBlob(eachValue, np_extractor=extractor).noun_phrases
  except TypeError:
    return []

# %%
extractor = ConllExtractor()

# %%
# %time data_mini['NounPhrase'] = data_mini.CleanTranslate.apply(GetNounPhrase)
# Out:
# CPU times: user 29 s, sys: 159 ms, total: 29.2 s
# Wall time: 29.2 s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# %time data_mini['TextSentiment']  = data_mini.CleanTranslate.apply(GetSentiment)
# Out:
# CPU times: user 14.8 s, sys: 16.2 ms, total: 14.9 s
# Wall time: 14.9 s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_mini[['CleanTranslate','TextSentiment','NounPhrase']].head(10)
# Out:
#                                       CleanTranslate  ...                                         NounPhrase
# 0  i am a victim of identity theft my personal in...  ...  [identity theft, personal information, xxxx xx...
# 1  transunion xxxx xxxx all show inquiries to bus...  ...                             [transunion xxxx xxxx]
# 2  the summer of xxxx2018 i was denied a mortgage...  ...  [mortgage loan due, xxxx xxxx credit card, acc...
# 3  xxxx xxxx experian all show inquiries to busin...  ...                               [xxxx xxxx experian]
# 4  there are many mistakes appear in my report wi...  ...                                                 []
# 5  there are many mistakes appear in my report wi...  ...                                                 []
# 6  there are many mistakes appear in my report wi...  ...                                                 []
# 7  there are many mistakes appear in my report wi...  ...                                                 []
# 8  there are many mistakes appear in my report wi...  ...                                                 []
# 9  there are many mistakes appear in my report wi...  ...                                                 []
#
# [10 rows x 3 columns]

# %%
def ExtractTopic(eachValue):
  try:
    r = Rake(ranking_metric=Metric.DEGREE_TO_FREQUENCY_RATIO, min_length=2, max_length=4) # Uses stopwords for english from NLTK, and all puntuation characters.

    r.extract_keywords_from_text(eachValue)

    return r.get_ranked_phrases()
  except TypeError:
    return []

# %%
# %time data_mini['Topics_DFR'] = data_mini.CleanTranslate.apply(ExtractTopic)
# Out:
# CPU times: user 7.05 s, sys: 256 ms, total: 7.3 s
# Wall time: 7.31 s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def ExtractTopic_degree(eachValue):
  try:
    r = Rake(ranking_metric=Metric.WORD_DEGREE, max_length=4) # Uses stopwords for english from NLTK, and all puntuation characters.

    r.extract_keywords_from_text(eachValue)

    return r.get_ranked_phrases()
  except TypeError:
    return []

# %%
data_mini['Topics_Deg'] = data_mini.CleanTranslate.apply(ExtractTopic_degree)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_mini[['CleanTranslate', 'NounPhrase', 'Topics_DFR', 'Topics_Deg']].sample(5)
# Out:
#                                          CleanTranslate  ...                                         Topics_Deg
# 3820  this is regarding the purchase of item on xxxx...  ...  [xxxx xxxx credit card, xxxx xxxx charge card,...
# 2712  to whom it may concern i ahve received a lette...  ...  [conc ern due process, wells fargo informing, ...
# 2082  today xxxx2019 i tried to call my bank  bank o...  ...  [bank bank, xxxx years old, put xxxx dollars, ...
# 7054  i made a purchase with my credit union credit ...  ...  [discover card discover stated, xxxx xxxx xxxx...
# 6212  i applied for a chase united explorer card in ...  ...  [since called severa times, chase united explo...
#
# [5 rows x 4 columns]

# %%
data_mini.CleanTranslate.iloc[239]
# Out:
# 'with midland credit that is a third party company who purchases debits owed that has no contract with me i had a card with xxxx  and there was charges that i hadnt made after reporting this directly to the company i now have xxxx off my credit due to it was resolved i closed my account and some how midland credit purchased this old account and i have no contract with this company to even collect this amount i closed down my account after the fraud purchases where resolved now i have them threaten to garnish wages and they dont have a contract with myseld which happens to xxxx xxxx xxxx i would like for them to stop reporting on my credit as the account is closed due to my request and the charges have being resolved please provide me with a contract that i have with you as you are just a third party who purchased this old account that has being closed'

# %%
numba.jit()
def GetNounAdjectivePair(eachValue):
  try:
#     doc = nlp(eachValue)
    noun_adj_pairs = []
    for i,token in enumerate(eachValue):
        if token.pos_ not in ('NOUN','PROPN','VERB'):
            continue
        for j in range(i+1,len(eachValue)):
            if doc[j].pos_ == 'ADJ':
                noun_adj_pairs.append((token.text,doc[j].text))
#                 print(type(token.text))
#                 print(type(doc[j].text))
                break
    return noun_adj_pairs
  except TypeError:
    return []

# %%
#nlp = spacy.load("en_core_web_lg")
# %time data_mini['NounAdjectivePair'] = data_mini.Consumer_complaint_narrative_spacy_object.apply(GetNounAdjectivePair)
# Out:
# CPU times: user 15min 44s, sys: 6min 1s, total: 21min 46s
# Wall time: 11min 6s
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type(data_mini.iloc[0]['Consumer_complaint_narrative_spacy_object'])
# Out:
# spacy.tokens.doc.Doc

# %%
data_mini.head(5)
# Out:
#                                              Product  ...                                  NounAdjectivePair
# 0  Credit reporting, credit repair services, or o...  ...  [(am, my), (victim, my), (identity, my), (thef...
# 1  Credit reporting, credit repair services, or o...  ...  [(transunion, that), (xxxx, that), (xxxx, that...
# 2  Credit reporting, credit repair services, or o...  ...  [(summer, xxxx), (xxxx2018, xxxx), (was, xxxx)...
# 3  Credit reporting, credit repair services, or o...  ...  [(xxxx, experian), (show, that), (inquiries, t...
# 4  Credit reporting, credit repair services, or o...  ...  [(are, many), (mistakes, my), (appear, my), (r...
#
# [5 rows x 10 columns]

# %%
data.to_csv("SurveyTextData_Final.csv")

# %% [markdown]
# # Detail Analysis on Topics & Entities

# %% [markdown]
# ## Unique Topics - Frequency, Strength & Similarity

# %% [markdown]
# ###Frequency & Strength

# %%
def getUniqueTopicsFrequency(DfColumn_Topics, DfColumn_NP):
  AllTopicList = [item for sublist in list(DfColumn_Topics) for item in sublist]
  AllNPList = [item for sublist in list(DfColumn_NP) for item in sublist]
  UniqueTopicList = list(set(AllTopicList))
  UniqueNPList = list(set(AllNPList))
  CombinedList = AllTopicList + AllNPList
  TopicFrequency = collections.Counter(CombinedList)
  print(TopicFrequency)
  df = pd.DataFrame.from_dict(TopicFrequency, orient='index').reset_index()
#   df['Topic'] = df.index
  df.columns = df.columns.map(str)
  df['Strength%'] = (df['0']/len(CombinedList))*100
  df.rename(columns = {'0':'TotalCountAllAnswer', 'index':'ImportantTopic'}, inplace=True)
#   df['Strength%'] = (df[0]/TotalUniqueTopic)*100   ## Divide by total Answers 
  return df.sort_values(by=['TotalCountAllAnswer'], ascending=False),UniqueTopicList

# %%
import collections
ImportantTopicsDF, TopicList = getUniqueTopicsFrequency(data['Topics_DFR'], data['NounPhrase'] )
# Out:
# Counter({'spicy taste good': 135, 'savory taste good': 114, 'sour taste good': 93, 'sweetness taste good': 79, 'salty taste good': 58, 'spicy taste': 53, 'garlic taste good': 35, 'viscositys good': 34, 'garlic taste': 33, 'salty taste': 28, 'spicy taste strong': 28, 'chilli smells strong': 26, 'sour taste': 24, 'textures soft': 19, 'real chilli': 19, 'garlic smells': 16, 'chilli smells good': 16, 'garlic smell': 12, 'colour need': 12, 'garlic smells good': 11, 'garlic smells strong': 9, 'savory taste': 9, 'little bit': 9, 'garlic taste strong': 8, 'sauce need': 7, 'savoury taste': 7, 'garlic smell strong': 6, 'chilli smell fresh': 6, 'light red colour': 6, 'red colour': 6, 'chilli smells strong good': 6, 'chilli taste strong': 6, 'chilli taste real': 6, 'viscosity need': 6, 'sweetness need': 6, 'little bit more': 6, 'sweetness taste strong': 5, 'chilli sauce': 5, 'light red': 5, 'sour sweet taste good': 5, 'colour needs': 5, 'viscosity isnt good enough': 5, 'spicy tatse good': 4, 'sauce taste strong': 4, 'vicositys good': 4, 'light colour': 4, 'sauce smells good': 4, 'savory taste good overall': 4, 'real chilli taste strong': 4, 'savory sweetness': 4, 'savory taste strong': 4, 'chilli taste good': 4, 'sour sweet': 4, 'spicy stays long': 4, 'sauce taste good': 4, 'teh spicy taste good': 4, 'sweetness taste': 4, 'dark colour': 4, 'garlic need': 4, 'spicy taste need': 4, 'sour need': 4, 'garlic smell need': 4, 'texture need': 4, 'garlic taste need': 4, 'feel nauseous': 3, 'light red colours attractive': 3, 'appearance colours bright': 3, 'tastes unique': 3, 'taste good': 3, 'colours bright': 3, 'appearance colours light red': 3, 'viscosity added': 3, 'bit watery': 3, 'bit sour': 3, 'sauce smell': 3, 'good savory taste good': 3, 'good garlic taste good': 3, 'sour spicy taste': 2, 'fried rice': 2, 'colours nice': 2, 'savory salty taste good': 2, 'spicy sauce taste strong': 2, 'sauces light redthe garlic': 2, 'salty sour sweet': 2, 'spicy sauce taste good': 2, 'real chilli taste good': 2, 'chilli smell strong': 2, 'sauces soft': 2, 'salty sweet': 2, 'chilli smell strong good': 2, 'saty taste good': 2, 'spicy taste strong good': 2, 'sour taste strong': 2, 'texture isnt': 2, 'goodthe colour': 2, 'real chilli smells strong': 2, 'savoryy taste good': 2, 'doesnt sting': 2, 'sweetness taste good soft': 2, 'spicy taste good fresh': 2, 'sour taste strong overall': 2, 'chilli taste fresh': 2, 'spicy taste delicious': 2, 'garlic taste savory': 2, 'really good': 2, 'chilli smells natural': 2, 'viscosity taste good soft': 2, 'chilli smells fresh': 2, 'swetness taste good': 2, 'garlic taste good delicious': 2, 'chilli tomato': 2, 'salty taste strong': 2, 'chilli smells': 2, 'good amd': 2, 'appearance colour': 2, 'spicy taste garlic': 2, 'sweetness saty': 2, 'sour sweet savort': 2, 'real chilli taste': 2, 'spicy chilli taste': 2, 'spicys strong': 2, 'spicy sour': 2, 'chilli taste': 2, 'real chillis strong': 2, 'sipcy taste': 2, 'tomato taste good': 2, 'svory taste good': 2, 'garlics good': 2, 'savory adn': 2, 'sour taste good adn': 2, 'spicy taste strong freshgood': 2, 'sour spicy saty': 2, 'garlic taste stronge': 2, 'bright enough': 2, 'sauce isnt spicy enough': 2, 'spicy chilli': 2, 'first time': 2, 'spicy taste stronger': 2, 'fresh spicy taste': 2, 'unique taste overall': 2, 'goodthe garlic taste good': 2, 'chilly smell fresh': 2, 'strong spicy sensation': 2, 'garlic taste strong good': 2, 'sweetess taste good': 2, 'light red coloue': 2, 'spicy taste stong good': 2, 'looks fresh': 2, 'soups appearance': 2, 'spicy taste goof': 2, 'sourthe sweetness': 2, 'spicy taste good strong': 2, 'spicy taste awesome': 2, 'real chilli smells good': 2, 'strongthe garlic smell': 2, 'chilli smell': 2, 'chilli taste real garlic': 2, 'chilli taste spicy': 2, 'teh combination': 2, 'teh spicy taste strong': 2, 'spicy taste real': 2, 'bright adn attractive': 2, 'sweet adn': 2, 'light orange colour': 2, 'salty sweet taste': 2, 'spicy taste like': 2, 'taste spicy': 2, ...

# %%
ImportantTopicsDF.head(10)
# Out:
#           ImportantTopic  TotalCountAllAnswer  Strength%
# 22      spicy taste good                  135   8.297480
# 17     savory taste good                  114   7.006761
# 11       sour taste good                   93   5.716042
# 10  sweetness taste good                   79   4.855562
# 34      salty taste good                   58   3.564843
# 3            spicy taste                   53   3.257529
# 18     garlic taste good                   35   2.151199
# 14       viscositys good                   34   2.089736
# 88          garlic taste                   33   2.028273
# 5            salty taste                   28   1.720959

# %% [markdown]
# ### Noun-Adjective Break ---- Entity & Their Attributes

# %%
def getNoun_Entity(eachValue):
  try:
    doc = nlp(eachValue)
    Noun = []
#     for chunk in doc.noun_chunks:
#       Noun.append(chunk.text)
    for token in doc:
      if token.pos_ == 'NOUN':
        Noun.append(token.text)
    return Noun
  except TypeError:
    return []
    
  

def getAllAdjective(eachValue):
  try:
    doc = nlp(eachValue)
    Noun = []
    for token in doc:
      if token.pos_ == 'ADJ':
        Noun.append(token.text)
    return Noun
  except TypeError:
    return []

# %%
nlp = spacy.load("en_core_web_sm")
ImportantTopicsDF['ImportantEntity'] = ImportantTopicsDF['ImportantTopic'].apply(getNoun_Entity)
ImportantTopicsDF['EntityAttributes'] = ImportantTopicsDF['ImportantTopic'].apply(getAllAdjective)
ImportantTopicsDF['TopicSentiment'] = ImportantTopicsDF['ImportantTopic'].apply(GetSentiment)
ImportantTopicsDF['TopicSubjectivity'] = ImportantTopicsDF['ImportantTopic'].apply(GetSentimentSubjectivity)
# ImportantTopicsDF['POSTAG'] = ImportantTopicsDF['ImportantTopic'].apply(getPOSTAG)

# %% [markdown]
# ### Similarity (Needs Optimization. very Slow)

# %%
global TopicList
global ImportantTopicsDF

# %%
numba.jit()
def getSimilarity_topic(eachValue):
  SimilarityDict = {}
  SimilarityList = []
  for eachTopic in TopicList:
    try:
      SimilarityValue = float("{0:.2f}".format(nlp(eachValue).similarity(nlp(eachTopic))))
      if SimilarityValue > 0.90 and SimilarityValue < 1:
        StrengthValue = float("{0:.2f}".format(ImportantTopicsDF.loc[ImportantTopicsDF['ImportantTopic'] == eachTopic]['Strength%'].values[0]))
        SentimentValue = float("{0:.2f}".format(TextBlob(eachTopic).sentiment.polarity))
        SimilarityList.append([(eachTopic,SimilarityValue), ('Strength', StrengthValue ), ('sentiment', SentimentValue) ])
    except:
      SimilarityList =[]
  SimilarityDict[eachValue] = SimilarityList
  print (SimilarityDict)
  return SimilarityDict

# def apply_myfunc_to_DF(df): return df.apply((lambda row: getSimilarity_topic(*row)), axis=1)

# %%
import numpy as np
# from multiprocessing import cpu_count, Parallel
# from joblib import Parallel, delayed
from multiprocessing import Pool
import scipy.sparse as sp
import multiprocessing
import swifter

num_partitions = 10
num_cores = multiprocessing.cpu_count()

 
cores = cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want

@numba.jit()
def parallelize(data, func):
#     a,b,c,d,e,f,g,h,i,j = np.array_split(data, num_partitions)
    a = np.array_split(data, num_partitions)
    pool = Pool(num_cores)
#     df = pd.concat(pool.map(func, [a,b,c,d,e,f,g,h,i,j ]))
    df = sp.vstack(pool.map(func, a), format='csr')
    pool.close()
    pool.join()
    return df
  
numba.jit()
def ParallelizeDFOperation(ImportantTopicsDF):
  ImportantTopicsDF['TopicSimilarity'] = ImportantTopicsDF['ImportantTopic'].swifter.apply(getSimilarity_topic)
  return ImportantTopicsDF
  
data = parallelize(ImportantTopicsDF, ParallelizeDFOperation)
# Out:
# {'real chilli taste strong': [[('real chilli taste good', 0.97), ('Strength', 0.4), ('sentiment', 0.45)]]}
# {'spicy taste good': [[('spicy taste strong', 0.95), ('Strength', 2.0), ('sentiment', 0.43)], [('spicy sauce taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)], [('viscosity taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.93), ('Strength', 8.42), ('sentiment', 0.7)], [('spicy sauce taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('salty taste good', 0.91), ('Strength', 4.81), ('sentiment', 0.7)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('spicy taste delicious', 0.94), ('Strength', 0.4), ('sentiment', 1.0)], [('spicy taste good fresh', 0.93), ('Strength', 0.4), ('sentiment', 0.5)], [('spicy taste strong good', 0.93), ('Strength', 0.4), ('sentiment', 0.57)], [('swetness taste good', 0.91), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'real chilli taste strong': [[('real chilli taste good', 0.97), ('Strength', 0.4), ('sentiment', 0.45)]]}
# {'spicy taste good': [[('spicy taste strong', 0.95), ('Strength', 2.0), ('sentiment', 0.43)], [('spicy sauce taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)], [('viscosity taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.93), ('Strength', 8.42), ('sentiment', 0.7)], [('spicy sauce taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('salty taste good', 0.91), ('Strength', 4.81), ('sentiment', 0.7)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('spicy taste delicious', 0.94), ('Strength', 0.4), ('sentiment', 1.0)], [('spicy taste good fresh', 0.93), ('Strength', 0.4), ('sentiment', 0.5)], [('spicy taste strong good', 0.93), ('Strength', 0.4), ('sentiment', 0.57)], [('swetness taste good', 0.91), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'spicy taste good': [[('spicy taste strong', 0.95), ('Strength', 2.0), ('sentiment', 0.43)], [('spicy sauce taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)], [('viscosity taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.93), ('Strength', 8.42), ('sentiment', 0.7)], [('spicy sauce taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('salty taste good', 0.91), ('Strength', 4.81), ('sentiment', 0.7)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('spicy taste delicious', 0.94), ('Strength', 0.4), ('sentiment', 1.0)], [('spicy taste good fresh', 0.93), ('Strength', 0.4), ('sentiment', 0.5)], [('spicy taste strong good', 0.93), ('Strength', 0.4), ('sentiment', 0.57)], [('swetness taste good', 0.91), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'real chilli taste strong': [[('real chilli taste good', 0.97), ('Strength', 0.4), ('sentiment', 0.45)]]}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=16, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'spicy taste good': [[('spicy taste strong', 0.95), ('Strength', 2.0), ('sentiment', 0.43)], [('spicy sauce taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)], [('viscosity taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.93), ('Strength', 8.42), ('sentiment', 0.7)], [('spicy sauce taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('salty taste good', 0.91), ('Strength', 4.81), ('sentiment', 0.7)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('spicy taste delicious', 0.94), ('Strength', 0.4), ('sentiment', 1.0)], [('spicy taste good fresh', 0.93), ('Strength', 0.4), ('sentiment', 0.5)], [('spicy taste strong good', 0.93), ('Strength', 0.4), ('sentiment', 0.57)], [('swetness taste good', 0.91), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'real chilli taste strong': [[('real chilli taste good', 0.97), ('Strength', 0.4), ('sentiment', 0.45)]]}
# {'sour taste good': [[('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('sour taste strong', 0.95), ('Strength', 0.4), ('sentiment', 0.14)]]}
# {'sour taste strong overall': [[('sour taste strong', 0.94), ('Strength', 0.4), ('sentiment', 0.14)]]}
# {'savory taste good': [[('savory taste strong', 0.96), ('Strength', 0.4), ('sentiment', 0.43)], [('savory taste good soft', 0.94), ('Strength', 0.2), ('sentiment', 0.4)], [('viscosity taste good', 0.94), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good overall', 0.94), ('Strength', 0.4), ('sentiment', 0.35)], [('spicy taste good', 0.93), ('Strength', 12.22), ('sentiment', 0.7)], [('savory salty taste good', 0.95), ('Strength', 0.4), ('sentiment', 0.7)], [('salty taste good', 0.92), ('Strength', 4.81), ('sentiment', 0.7)], [('garlic taste good', 0.94), ('Strength', 2.0), ('sentiment', 0.7)], [('sweettness taste good', 0.93), ('Strength', 0.2), ('sentiment', 0.7)], [('saty taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('swetness taste good', 0.94), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'savory sweetness': [[('sweetness savory', 0.95), ('Strength', 0.2), ('sentiment', 0.0)]]}
# {'good garlic taste good': []}
# {'sweetness taste good': [[('sweetness taste good soft', 0.93), ('Strength', 0.4), ('sentiment', 0.4)], [('sweetness taste strong', 0.96), ('Strength', 0.4), ('sentiment', 0.43)], [('saty taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('swetness taste good', 0.95), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'goodthe colour': []}
# {'salty taste good': [[('savory taste good', 0.92), ('Strength', 8.42), ('sentiment', 0.7)], [('spicy taste good', 0.91), ('Strength', 12.22), ('sentiment', 0.7)], [('savory salty taste good', 0.94), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'spicy taste good fresh': [[('savory taste good soft', 0.92), ('Strength', 0.2), ('sentiment', 0.4)], [('spicy taste good', 0.93), ('Strength', 12.22), ('sentiment', 0.7)], [('spicy taste strong good', 0.92), ('Strength', 0.4), ('sentiment', 0.57)]]}
# {'viscositys good': []}
# {'savory taste strong': [[('spicy taste strong', 0.93), ('Strength', 2.0), ('sentiment', 0.43)], [('savory taste good soft', 0.91), ('Strength', 0.2), ('sentiment', 0.4)], [('savory taste good', 0.96), ('Strength', 8.42), ('sentiment', 0.7)], [('savory taste good overall', 0.92), ('Strength', 0.4), ('sentiment', 0.35)], [('garlic taste strong savory', 0.91), ('Strength', 0.2), ('sentiment', 0.43)], [('savory salty taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('garlic taste strong', 0.93), ('Strength', 0.8), ('sentiment', 0.43)]]}
# {'textures soft': []}
# {'sweetness taste good soft': [[('savory taste good soft', 0.94), ('Strength', 0.2), ('sentiment', 0.4)], [('savory taste good overall', 0.91), ('Strength', 0.4), ('sentiment', 0.35)], [('sweetness taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('sweetness taste good', 0.93), ('Strength', 7.01), ('sentiment', 0.7)], [('viscosity taste good soft', 0.93), ('Strength', 0.4), ('sentiment', 0.4)], [('swetness taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'chilli smells strong': [[('chilli smells good', 0.94), ('Strength', 1.0), ('sentiment', 0.7)], [('chilli smells strong good', 0.91), ('Strength', 1.0), ('sentiment', 0.57)], [('chilli smells natural', 0.93), ('Strength', 0.2), ('sentiment', 0.1)]]}
# {'doesnt sting': []}
# {'spicy taste strong': [[('savory taste strong', 0.93), ('Strength', 0.4), ('sentiment', 0.43)], [('spicy taste good', 0.95), ('Strength', 12.22), ('sentiment', 0.7)], [('spicy sauce taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)], [('garlic taste strong', 0.91), ('Strength', 0.8), ('sentiment', 0.43)], [('spicy taste delicious', 0.93), ('Strength', 0.4), ('sentiment', 1.0)], [('spicy taste strong good', 0.94), ('Strength', 0.4), ('sentiment', 0.57)]]}
# {'vicositys good': []}
# {'garlic taste good': [[('savory taste good soft', 0.93), ('Strength', 0.2), ('sentiment', 0.4)], [('viscosity taste good', 0.92), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.94), ('Strength', 8.42), ('sentiment', 0.7)], [('savory taste good overall', 0.92), ('Strength', 0.4), ('sentiment', 0.35)], [('garlic taste good delicious', 0.94), ('Strength', 0.4), ('sentiment', 0.85)], [('spicy taste good', 0.92), ('Strength', 12.22), ('sentiment', 0.7)], [('garlic taste strong savory', 0.91), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic taste strong', 0.95), ('Strength', 0.8), ('sentiment', 0.43)], [('sour taste good', 0.92), ('Strength', 8.62), ('sentiment', 0.27)], [('viscosity taste good soft', 0.92), ('Strength', 0.4), ('sentiment', 0.4)], [('sweettness taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)], [('saty taste good', 0.91), ('Strength', 0.4), ('sentiment', 0.7)], [('swetness taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'savoryy taste good': [[('viscosity taste good', 0.92), ('Strength', 0.2), ('sentiment', 0.7)], [('swetness taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'spicy taste': []}
# {'light colour': []}
# {'garlic smell strong': [[('garlic taste strong savory', 0.91), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic taste strong', 0.93), ('Strength', 0.8), ('sentiment', 0.43)]]}
# {'chilli smell strong good': [[('chilli smell strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)]]}
# {'chilli smells strong good': [[('chilli smells strong', 0.91), ('Strength', 2.61), ('sentiment', 0.43)], [('chilli smells good strong', 0.96), ('Strength', 0.2), ('sentiment', 0.57)]]}
# {'savory taste good overall': [[('savory taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)], [('sweetness taste good soft', 0.91), ('Strength', 0.4), ('sentiment', 0.4)], [('savory taste good soft', 0.95), ('Strength', 0.2), ('sentiment', 0.4)], [('viscosity taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.94), ('Strength', 8.42), ('sentiment', 0.7)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('viscosity taste good soft', 0.93), ('Strength', 0.4), ('sentiment', 0.4)], [('swetness taste good', 0.91), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'chilli smells good': [[('chilli smells natural', 0.94), ('Strength', 0.2), ('sentiment', 0.1)], [('chilli smells strong', 0.94), ('Strength', 2.61), ('sentiment', 0.43)]]}
# {'spicy taste delicious': [[('spicy taste strong', 0.93), ('Strength', 2.0), ('sentiment', 0.43)], [('spicy taste good', 0.94), ('Strength', 12.22), ('sentiment', 0.7)]]}
#
# {'garlic smells strong': [[('garlisk smells strong', 0.91), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic smells good', 0.95), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'really good': []}
# {'really good': []}
# {'garlic taste strong': [[('savory taste strong', 0.93), ('Strength', 0.4), ('sentiment', 0.43)], [('spicy taste strong', 0.91), ('Strength', 2.0), ('sentiment', 0.43)], [('savory taste good soft', 0.91), ('Strength', 0.2), ('sentiment', 0.4)], [('garlic taste good delicious', 0.91), ('Strength', 0.4), ('sentiment', 0.85)], [('garlic taste strong savory', 0.95), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic taste good', 0.95), ('Strength', 2.0), ('sentiment', 0.7)], [('garlic smell strong', 0.93), ('Strength', 1.2), ('sentiment', 0.43)], [('sour taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.14)]]}
#
# {'really good': []}
# {'sauce taste strong': [[('spicy sauce taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)]]}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'sauce taste strong': [[('spicy sauce taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)]]}
# {'really good': []}
# {'sauce taste strong': [[('spicy sauce taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)]]}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'swetness taste good': [[('sweetness taste good soft', 0.93), ('Strength', 0.4), ('sentiment', 0.4)], [('viscosity taste good', 0.95), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.94), ('Strength', 8.42), ('sentiment', 0.7)], [('savory taste good overall', 0.91), ('Strength', 0.4), ('sentiment', 0.35)], [('spicy taste good', 0.91), ('Strength', 12.22), ('sentiment', 0.7)], [('sweetness taste good', 0.95), ('Strength', 7.01), ('sentiment', 0.7)], [('garlic taste good', 0.93), ('Strength', 2.0), ('sentiment', 0.7)], [('sweettness taste good', 0.93), ('Strength', 0.2), ('sentiment', 0.7)], [('saty taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('savoryy taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'sauce taste strong': [[('spicy sauce taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)]]}
# {'garlic taste good delicious': [[('savory taste good soft', 0.94), ('Strength', 0.2), ('sentiment', 0.4)], [('garlic taste strong savory', 0.91), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic taste strong', 0.91), ('Strength', 0.8), ('sentiment', 0.43)], [('garlic taste good', 0.94), ('Strength', 2.0), ('sentiment', 0.7)], [('viscosity taste good soft', 0.93), ('Strength', 0.4), ('sentiment', 0.4)]]}
# {'spicy tatse good': []}
# {'chilli smell fresh': [[('chilli taste fresh', 0.91), ('Strength', 0.4), ('sentiment', 0.3)]]}
# {'salty taste': []}
# {'garlic smells': []}
# {'sour taste': []}
# {'viscosity taste good soft': [[('sweetness taste good soft', 0.93), ('Strength', 0.4), ('sentiment', 0.4)], [('savory taste good soft', 0.96), ('Strength', 0.2), ('sentiment', 0.4)], [('viscosity taste good', 0.94), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good overall', 0.93), ('Strength', 0.4), ('sentiment', 0.35)], [('garlic taste good delicious', 0.93), ('Strength', 0.4), ('sentiment', 0.85)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('sweettness taste good', 0.91), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'red colour': [[('light red colour', 0.93), ('Strength', 0.4), ('sentiment', 0.2)]]}
# {'sour spicy taste': []}
# {'real chilli': []}
# {'fried rice': []}
# {'light red colours attractive': [[('light red colours good', 0.95), ('Strength', 0.2), ('sentiment', 0.37)]]}
# {'savory salty taste good': [[('savory taste strong', 0.92), ('Strength', 0.4), ('sentiment', 0.43)], [('savory taste good', 0.95), ('Strength', 8.42), ('sentiment', 0.7)], [('salty taste good', 0.94), ('Strength', 4.81), ('sentiment', 0.7)]]}
# {'chilli tomato': []}
# {'spicy sauce taste strong': [[('spicy taste strong', 0.92), ('Strength', 2.0), ('sentiment', 0.43)], [('spicy sauce taste good', 0.98), ('Strength', 0.4), ('sentiment', 0.7)], [('spicy taste good', 0.91), ('Strength', 12.22), ('sentiment', 0.7)], [('sauce taste strong', 0.92), ('Strength', 0.8), ('sentiment', 0.43)]]}
# {'garlic taste': [[('garlic taste savory', 0.92), ('Strength', 0.4), ('sentiment', 0.0)]]}
# {'sauces soft': []}
# {'spicy taste strong good': [[('spicy taste strong', 0.94), ('Strength', 2.0), ('sentiment', 0.43)], [('savory taste good soft', 0.91), ('Strength', 0.2), ('sentiment', 0.4)], [('spicy taste good', 0.93), ('Strength', 12.22), ('sentiment', 0.7)], [('spicy taste good fresh', 0.92), ('Strength', 0.4), ('sentiment', 0.5)]]}
# {'light red colour': [[('red colour', 0.93), ('Strength', 0.6), ('sentiment', 0.0)]]}
# {'chilli taste fresh': [[('chilli smell fresh', 0.91), ('Strength', 0.4), ('sentiment', 0.3)]]}
# {'sweetness taste strong': [[('sweetness taste good soft', 0.91), ('Strength', 0.4), ('sentiment', 0.4)], [('sweetness taste good', 0.96), ('Strength', 7.01), ('sentiment', 0.7)]]}
# {'garlic smells good': [[('spicy smells good', 0.92), ('Strength', 0.2), ('sentiment', 0.7)], [('garlic smells strong', 0.95), ('Strength', 0.8), ('sentiment', 0.43)]]}
# {'sauces light redthe garlic': []}
# {'appearance colours bright': []}
# {'spicy sauce taste good': [[('spicy taste good', 0.93), ('Strength', 12.22), ('sentiment', 0.7)], [('spicy sauce taste strong', 0.98), ('Strength', 0.4), ('sentiment', 0.43)]]}
#
# {'saty taste good': [[('viscosity taste good', 0.92), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.92), ('Strength', 8.42), ('sentiment', 0.7)], [('sweetness taste good', 0.92), ('Strength', 7.01), ('sentiment', 0.7)], [('garlic taste good', 0.91), ('Strength', 2.0), ('sentiment', 0.7)], [('sweettness taste good', 0.92), ('Strength', 0.2), ('sentiment', 0.7)], [('swetness taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'real chilli taste good': [[('real chilli taste strong', 0.97), ('Strength', 0.4), ('sentiment', 0.32)]]}
# {'sour taste strong': [[('sour taste strong overall', 0.94), ('Strength', 0.4), ('sentiment', 0.09)], [('garlic taste strong', 0.92), ('Strength', 0.8), ('sentiment', 0.43)], [('sour taste good', 0.95), ('Strength', 8.62), ('sentiment', 0.27)]]}
#
# {'real chilli taste good': [[('real chilli taste strong', 0.97), ('Strength', 0.4), ('sentiment', 0.32)]]}
# {'appearances colours bright': [[('sauces colours bright', 0.94), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'real chilli taste good': [[('real chilli taste strong', 0.97), ('Strength', 0.4), ('sentiment', 0.32)]]}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'appearances colours bright': [[('sauces colours bright', 0.94), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'real chilli taste good': [[('real chilli taste strong', 0.97), ('Strength', 0.4), ('sentiment', 0.32)]]}
# {'appearances colours bright': [[('sauces colours bright', 0.94), ('Strength', 0.2), ('sentiment', 0.7)]]}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'chilli smell strong': [[('chilli smell strong good', 0.91), ('Strength', 0.4), ('sentiment', 0.57)]]}
# {'appearances colours bright': [[('sauces colours bright', 0.94), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'good viscosity taste good': []}
# {'realthe taste': []}
# {'good sweet savory sour salty taste good': []}
# {'good red colour': []}
# {'fresh sweetness taste good': []}
# {'theh light red appearance colours attractive': []}
# {'good garlic taste goodthe chilli': []}
# {'spicy taste strong garlic taste': []}
# {'soft light appearance colours good': []}
# {'strong light red colour': []}
# {'good savory taste good': []}
# {'attractive sour salty sweetness taste good': []}
# {'garlic taste savory': [[('garlic taste strong savory', 0.92), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic taste', 0.92), ('Strength', 0.4), ('sentiment', 0.0)]]}
# {'colour isnt pale': []}
# {'sauces colours light red': []}
# {'lumpy good': []}
#
# {'sweetness savory': [[('savory sweetness', 0.95), ('Strength', 0.4), ('sentiment', 0.0)]]}
# {'salty sweet': [[('salty sour sweet', 0.94), ('Strength', 0.2), ('sentiment', 0.1)]]}
# {'sour salty': [[('salty sour sweet', 0.91), ('Strength', 0.2), ('sentiment', 0.1)]]}
# {'salty sweet': [[('salty sour sweet', 0.94), ('Strength', 0.2), ('sentiment', 0.1)]]}
# {'sppearances bright': []}
# {'savoury taste': []}
# {'salty sweet': [[('salty sour sweet', 0.94), ('Strength', 0.2), ('sentiment', 0.1)]]}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'goodthe viscositys good': []}
# {'salty sweet': [[('salty sour sweet', 0.94), ('Strength', 0.2), ('sentiment', 0.1)]]}
# {'viscosityys good': []}
# {'sauce looks bright': [[('sauce looks modern', 0.93), ('Strength', 0.2), ('sentiment', 0.2)]]}
# {'sauces colours bright': [[('appearances colours bright', 0.94), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'sauce isnt watery good': []}
# {'salty sour sweetness': []}
# {'tastes unique': []}
# {'appearance colours light red': [[('light appearance colours good', 0.91), ('Strength', 0.2), ('sentiment', 0.55)]]}
# {'looks good': []}
# {'good enough doesnt make': []}
# {'nauseous garlic smell': []}
#
# {'spicy savory taste good soft': []}
# {'spicy savory taste good soft': []}
# {'spicy savory taste good soft': []}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'spicy savory taste good soft': []}
# {'sauces colours bright tthe chilli': []}
# {'delicious salty taste good': []}
# {'good light red colour': []}
# {'delicious spicy taste good': []}
# {'garlic seasoning taste good tthe chill': []}
# {'delicious salty sour sweetness': []}
# {'chilli sauce': []}
# {'light red appearance colours attractive': []}
# {'good salty taste good': []}
# {'fresh sweettness taste good': []}
# {'light red appearance colours good': []}
# {'spicy sour taste good': []}
# {'strong savory taste good': []}
# {'good garlic taste strong savory': []}
#
# {'viscosity taste good': [[('savory taste good', 0.94), ('Strength', 8.42), ('sentiment', 0.7)], [('savory taste good overall', 0.91), ('Strength', 0.4), ('sentiment', 0.35)], [('spicy taste good', 0.91), ('Strength', 12.22), ('sentiment', 0.7)], [('garlic taste good', 0.92), ('Strength', 2.0), ('sentiment', 0.7)], [('viscosity taste good soft', 0.94), ('Strength', 0.4), ('sentiment', 0.4)], [('sweettness taste good', 0.95), ('Strength', 0.2), ('sentiment', 0.7)], [('saty taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('savoryy taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('swetness taste good', 0.95), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'sauces attractive': []}
# {'chilli smells realthe taste': []}
# {'sauces attractive': []}
# {'soursweet savory': []}
# {'sauces attractive': []}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'still strong': []}
# {'sauces attractive': []}
# {'garlic taste goodthe chilli': []}
# {'colours nice': []}
# {'sauces bright make': []}
# {'sauce smells good good': [[('sauce smells good', 0.93), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'chilli smells fresh': [[('chilli smells natural', 0.92), ('Strength', 0.2), ('sentiment', 0.1)]]}
# {'garlic taste strong savory': [[('savory taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('savory taste good soft', 0.93), ('Strength', 0.2), ('sentiment', 0.4)], [('garlic taste savory', 0.92), ('Strength', 0.4), ('sentiment', 0.0)], [('garlic taste good delicious', 0.91), ('Strength', 0.4), ('sentiment', 0.85)], [('garlic taste strong', 0.95), ('Strength', 0.8), ('sentiment', 0.43)], [('garlic taste good', 0.91), ('Strength', 2.0), ('sentiment', 0.7)], [('garlic smell strong', 0.91), ('Strength', 1.2), ('sentiment', 0.43)]]}
# {'salty sour sweet': [[('salty sweet', 0.94), ('Strength', 0.2), ('sentiment', 0.35)], [('sour salty', 0.91), ('Strength', 0.2), ('sentiment', -0.15)]]}
# {'feel nauseous': []}
# {'sauce colours bright': []}
# {'garlic smell': []}
# {'light appearance colours good': [[('light red colours good', 0.93), ('Strength', 0.2), ('sentiment', 0.37)], [('appearance colours light red', 0.91), ('Strength', 0.2), ('sentiment', 0.2)]]}
#
# {'garlisk smells strong': [[('garlic smells strong', 0.91), ('Strength', 0.8), ('sentiment', 0.43)]]}
# {'texture isnt': []}
# {'softnesss good': []}
# {'real chilli smells strong': []}
# {'colours bright': []}
# {'chilli smells natural': [[('chilli smells good', 0.94), ('Strength', 1.0), ('sentiment', 0.7)], [('chilli smells strong', 0.93), ('Strength', 2.61), ('sentiment', 0.43)], [('chilli smells fresh', 0.92), ('Strength', 0.2), ('sentiment', 0.3)]]}
# {'taste good': []}
# {'light red colours good': [[('light red colours attractive', 0.95), ('Strength', 0.6), ('sentiment', 0.4)], [('light appearance colours good', 0.93), ('Strength', 0.2), ('sentiment', 0.55)]]}
# {'smells fresh': []}
#
# {'bit strong': []}
# {'bit strong': []}
# {'bit strong': []}
# HBox(children=(IntProgress(value=0, description='Pandas Apply', max=15, style=ProgressStyle(description_width=…
# {'bit strong': []}
# {'sweettness taste good': [[('viscosity taste good', 0.95), ('Strength', 0.2), ('sentiment', 0.7)], [('savory taste good', 0.93), ('Strength', 8.42), ('sentiment', 0.7)], [('garlic taste good', 0.91), ('Strength', 2.0), ('sentiment', 0.7)], [('viscosity taste good soft', 0.91), ('Strength', 0.4), ('sentiment', 0.4)], [('saty taste good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)], [('swetness taste good', 0.93), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'sauce looks modern': [[('sauce looks bright', 0.93), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'viscositys thick': []}
# {'textures softt': []}
# {'chilli smells good strong': [[('chilli smells strong good', 0.96), ('Strength', 1.0), ('sentiment', 0.57)]]}
# {'colours thick': []}
# {'savoury taste us enough': []}
# {'sauce smells good': [[('sauce smells good good', 0.93), ('Strength', 0.2), ('sentiment', 0.7)]]}
# {'savory taste good soft': [[('savory taste strong', 0.91), ('Strength', 0.4), ('sentiment', 0.43)], [('sweetness taste good soft', 0.94), ('Strength', 0.4), ('sentiment', 0.4)], [('savory taste good', 0.94), ('Strength', 8.42), ('sentiment', 0.7)], [('savory taste good overall', 0.95), ('Strength', 0.4), ('sentiment', 0.35)], [('garlic taste good delicious', 0.94), ('Strength', 0.4), ('sentiment', 0.85)], [('garlic taste strong savory', 0.93), ('Strength', 0.2), ('sentiment', 0.43)], [('garlic taste strong', 0.91), ('Strength', 0.8), ('sentiment', 0.43)], [('garlic taste good', 0.93), ('Strength', 2.0), ('sentiment', 0.7)], [('viscosity taste good soft', 0.96), ('Strength', 0.4), ('sentiment', 0.4)], [('spicy taste good fresh', 0.92), ('Strength', 0.4), ('sentiment', 0.5)], [('spicy taste strong good', 0.91), ('Strength', 0.4), ('sentiment', 0.57)]]}
# {'spicy smells good': [[('garlic smells good', 0.92), ('Strength', 0.4), ('sentiment', 0.7)]]}
# {'spicy savory': []}
# {'spicy sensations statisfied': []}
# {'colours dark red': []}
# {'sting light red appearance colour': []}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-fbfc9aa4e17f> in <module>()
#      28   return ImportantTopicsDF
#      29
# ---> 30 data = parallelize(ImportantTopicsDF, ParallelizeDFOperation)
#
# <ipython-input-139-fbfc9aa4e17f> in parallelize(data, func)
#      19     pool = Pool(num_cores)
#      20 #     df = pd.concat(pool.map(func, [a,b,c,d,e,f,g,h,i,j ]))
# ---> 21     df = sp.vstack(pool.map(func, a), format='csr')
#      22     pool.close()
#      23     pool.join()
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/construct.py in vstack(blocks, format, dtype)
#     497
#     498     """
# --> 499     return bmat([[b] for b in blocks], format=format, dtype=dtype)
#     500
#     501
#
# /usr/local/lib/python3.6/dist-packages/scipy/sparse/construct.py in bmat(blocks, format, dtype)
#     543     """
#     544
# --> 545     blocks = np.asarray(blocks, dtype='object')
#     546
#     547     if blocks.ndim != 2:
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: cannot copy sequence with size 16 to array axis with dimension 8

# %%
import pickle
TopicListFN = "TopicListDump.dat"
with open(TopicListFN, "wb") as f:
    pickle.dump(TopicList, f)

# %%
data.head(5)

# %% [markdown]
# ### Similarity of High Strength Topic - Given a Topic ; Return all Similar Topics or  Threshold for Highest Strength Topics

# %% [markdown]
# ####Threshold Logic

# %% [markdown]
# #####Pickel Dump of TopicList

# %%
import pickle
filehandler = open("TopicList.dat","wb")
pickle.dump(TopicList,filehandler)

# %% [markdown]
# #####Logic

# %%
global TopicList
global ImportantTopicsDF


def getSimilarity_topic(eachValue):
  SimilarityDict = {}
  SimilarityList = []
  SortedNumberValue = sorted( [(x,i) for (i,x) in enumerate(ImportantTopicsDF['Strength%'])], reverse=True )[:SortNumber][SortNumber-1][0]
  if ImportantTopicsDF['Strength%'][(ImportantTopicsDF['ImportantTopic'] == eachValue)].values[0] >= SortedNumberValue:
#     print ("Inside Important Topic", eachValue)
    for eachTopic in TopicList:
      SimilarityValue = float("{0:.2f}".format(nlp(eachValue).similarity(nlp(eachTopic))))
      if SimilarityValue > 0.90 and SimilarityValue < 1:
        StrengthValue = float("{0:.2f}".format(ImportantTopicsDF.loc[ImportantTopicsDF['ImportantTopic'] == eachTopic]['Strength%'].values[0]))
        SentimentValue = float("{0:.2f}".format(TextBlob(eachTopic).sentiment.polarity))
        SimilarityList.append([(eachTopic,SimilarityValue), ('Strength', StrengthValue ), ('sentiment', SentimentValue) ])
#         print (SimilarityList)
  SimilarityDict[eachValue] = SimilarityList
#   print (SimilarityDict)
  return SimilarityDict

import numpy as np
from multiprocessing import Pool
import scipy.sparse as sp
import multiprocessing
import swifter

num_partitions = 5
num_cores = multiprocessing.cpu_count()

 
def parallelize_dataframe(df, func):
    df_split = np.array_split(df, num_partitions)
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df
  
def ParallelizeDFOperation(ImportantTopicsDF):
  global SortNumber
  SortNumber = 10
  ImportantTopicsDF['TopicSimilarity'] = ImportantTopicsDF['ImportantTopic'].apply(getSimilarity_topic)
  return ImportantTopicsDF
  
ImportantTopicsDF = parallelize_dataframe(ImportantTopicsDF, ParallelizeDFOperation)

# %%
ImportantTopicsDF.to_csv("Survey_Similarity.csv")

# %% [markdown]
# ####SingleTopic Logic  - Not Complete

# %% [markdown]
# # Production Service  -> Important Topic Frequency, Strength, Sentiment & Entities -> Working

# %% [markdown]
# ## Server

# %%
import pandas as pd
df = pd.read_csv("AmazonReviewBig.csv")

# %%
df.head()
# Out:
#    0                                          Translate
# 0  1  Very nice Items. Fits my needs and very fast s...
# 1  2                                    very good phone
# 2  3                                     thank you good
# 3  4                 Very good phones worth what I paid
# 4  5  I owned a galaxy before this and I miss featur...

# %%
# %%writefile server.py

#!/usr/bin/env python
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))

import collections
from flask import Flask
import pandas as pd
from rake_nltk import Metric, Rake
import spacy
from textblob import TextBlob
from flask import Flask, request, render_template
import pandas as pd
import string
import json
from textblob.np_extractors import ConllExtractor
from flask_jsonpify import jsonpify

app = Flask(__name__)

def readData(path):
    # Read NPZ and Transform to Datafram. Single Question Responses. Sample is on 51 Records
    return pd.read_csv(path)


def GetSentiment(eachValue):
  try:
    return float("{0:.2f}".format(TextBlob(eachValue).sentiment.polarity))
  except TypeError:
    return []

def TextCleaning(eachValue):
  try:
    return eachValue.translate(str.maketrans('', '', string.punctuation)).lower()
  except AttributeError:
    return "Dummy"
 

def GetSentimentSubjectivity(eachValue):
  try:
    return float("{0:.2f}".format(TextBlob(eachValue).sentiment.subjectivity))
  except TypeError:
    return []

def GetNounPhrase(eachValue):
  try:
    return TextBlob(eachValue, np_extractor=extractor).noun_phrases
  except TypeError:
    return []

def ExtractTopic(eachValue):
  try:
    r = Rake(ranking_metric=Metric.DEGREE_TO_FREQUENCY_RATIO, min_length=2, max_length=4) # Uses stopwords for english from NLTK, and all puntuation characters.

    r.extract_keywords_from_text(eachValue)

    return r.get_ranked_phrases()
  except TypeError:
    return []


def GetNounAdjectivePair(eachValue):
    try:
        doc = nlp(eachValue)
        noun_adj_pairs = []
        for i,token in enumerate(doc):
            if token.pos_ not in ('NOUN','PROPN','VERB'):
                continue
            for j in range(i+1,len(doc)):
                if doc[j].pos_ == 'ADJ':
                    noun_adj_pairs.append((token.text,doc[j].text))
                    break
        return noun_adj_pairs
    except TypeError:
        return []


def getSentTopicNP(dataframe):
    dataframe['CleanTranslate'] = dataframe.Translate.apply(TextCleaning)
    dataframe['NounPhrase'] = dataframe.CleanTranslate.apply(GetNounPhrase)
    dataframe['TextSentiment']  = dataframe.CleanTranslate.apply(GetSentiment)
    dataframe['Topics_DFR'] = dataframe.CleanTranslate.apply(ExtractTopic)
    dataframe['NounAdjectivePair'] = dataframe.CleanTranslate.apply(GetNounAdjectivePair)
    return dataframe
  
  
def getFinalTopicDf(ImportantTopicsDF):
  ImportantTopicsDF['ImportantEntity'] = ImportantTopicsDF['ImportantTopic'].apply(getNoun_Entity)
  ImportantTopicsDF['ImportantVerbEntity'] = ImportantTopicsDF['ImportantTopic'].apply(getVerb_Entity)
  ImportantTopicsDF['EntityAttributes'] = ImportantTopicsDF['ImportantTopic'].apply(getAllAdjective)
  ImportantTopicsDF['TopicSentiment'] = ImportantTopicsDF['ImportantTopic'].apply(GetSentiment)
  ImportantTopicsDF['TopicSubjectivity'] = ImportantTopicsDF['ImportantTopic'].apply(GetSentimentSubjectivity)
#   ImportantTopicsDF['TextSentiment']  = ImportantTopicsDF.Translate.apply(GetSentiment)
  return ImportantTopicsDF
  
def getUniqueTopicsFrequency(DfColumn_Topics, DfColumn_NP):
  AllTopicList = [item for sublist in list(DfColumn_Topics) for item in sublist]
  AllNPList = [item for sublist in list(DfColumn_NP) for item in sublist]
  UniqueTopicList = list(set(AllTopicList))
  UniqueNPList = list(set(AllNPList))
  CombinedList = AllTopicList + AllNPList
  TopicFrequency = collections.Counter(CombinedList)
#   print(TopicFrequency)
  df = pd.DataFrame.from_dict(TopicFrequency, orient='index').reset_index()
#   df['Topic'] = df.index
  df.columns = df.columns.map(str)
  df['Strength%'] = (df['0']/len(CombinedList))*100
  df.rename(columns = {'0':'TotalCountAllAnswer', 'index':'ImportantTopic'}, inplace=True)
#   df['Strength%'] = (df[0]/TotalUniqueTopic)*100   ## Divide by total Answers 
  return df.sort_values(by=['TotalCountAllAnswer'], ascending=False),UniqueTopicList 

def getVerb_Entity(eachValue):
  try:
    doc = nlp(eachValue)
    Noun = []
#     for chunk in doc.noun_chunks:
#       Noun.append(chunk.text)
    for token in doc:
      if token.pos_ == 'VERB':
        Noun.append(token.text)
    return Noun
  except TypeError:
    return []
    
def getNoun_Entity(eachValue):
  try:
    doc = nlp(eachValue)
    Noun = []
#     for chunk in doc.noun_chunks:
#       Noun.append(chunk.text)
    for token in doc:
      if token.pos_ == 'NOUN':
        Noun.append(token.text)
    return Noun
  except TypeError:
    return []
  

def getAllAdjective(eachValue):
  try:
    doc = nlp(eachValue)
    Noun = []
    for token in doc:
      if token.pos_ == 'ADJ':
        Noun.append(token.text)
    return Noun
  except TypeError:
    return []


def loadSpacyModel(ModelName):
    return spacy.load(ModelName)

def Dataframe2JsonObject(dataframe):
#     df_list = dataframe.values.tolist()
#     JSONP_data = jsonpify(df_list)
#     return JSONP_data
    return dataframe.to_json(orient='records')

@app.route('/')
def SurveyAnalysis():
    global extractor
    extractor = ConllExtractor()
    ModelName = 'en_core_web_lg'
    global nlp
    nlp = loadSpacyModel(ModelName)
#     data = readData('SurveyTextData_subset.csv')
    data = readData('SurveyTextData_subset.csv')
    getSentTopicNPDF = getSentTopicNP(data)
    ImportantTopicsDF, TopicList = getUniqueTopicsFrequency(data['Topics_DFR'], data['NounPhrase'] )
    
    
    return Dataframe2JsonObject(getFinalTopicDf(ImportantTopicsDF))

if __name__ == '__main__':
    # nlp = spacy.load("en_core_web_sm")
    app.run(threaded=True)

# import threading
# threading.Thread(target=app.run, kwargs={'host':'0.0.0.0','port':80}).start()
# Out:
# Overwriting server.py

# %% [markdown]
# ##MultiProcess Server Run

# %%
import os
import subprocess
import sys
import time
import socket
# Start a subprocess that runs the Flask server
p = subprocess.Popen([sys.executable, "-m", "flask", "run"], env=dict(**os.environ, FLASK_APP="server.py"), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Start two subthreads that forward the output from the Flask server to the output of the Jupyter notebook
def forward(i, o):
    while p.poll() is None:
        l = i.readline().decode('utf-8')
        if l:
            o.write("[SERVER] " + l)

import threading
threading.Thread(target=forward, args=(p.stdout, sys.stdout)).start()
threading.Thread(target=forward, args=(p.stderr, sys.stderr)).start()
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))
# sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# Let's give the server a bit of time to make sure it has started
time.sleep(2)
# Out:
# 172.28.0.2
# [SERVER]  * Serving Flask app "server.py"
# [SERVER]  * Environment: production
# [SERVER]    WARNING: This is a development server. Do not use it in a production deployment.
# [SERVER]    Use a production WSGI server instead.
# [SERVER]  * Debug mode: off
# [SERVER] Usage: python -m flask run [OPTIONS]
# [SERVER]
# [SERVER] Error: Could not import "server".

# %% [markdown]
# ##Request

# %%
import requests
# r = requests.get("http://172.28.0.2/")
r = requests.get(" http://127.0.0.1:5000/")
print(r.status_code)
print(r.encoding)
print(r.apparent_encoding)
print(r.text)
# Out:
# 200
# utf-8
# ascii
# [{"ImportantTopic":"spicy taste good","TotalCountAllAnswer":61,"Strength%":12.2244488978,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["spicy","good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"sour taste good","TotalCountAllAnswer":43,"Strength%":8.6172344689,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["sour","good"],"TopicSentiment":0.27,"TopicSubjectivity":0.35},{"ImportantTopic":"savory taste good","TotalCountAllAnswer":42,"Strength%":8.4168336673,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["savory","good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"sweetness taste good","TotalCountAllAnswer":35,"Strength%":7.0140280561,"ImportantEntity":["sweetness"],"ImportantVerbEntity":["taste"],"EntityAttributes":["good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"salty taste good","TotalCountAllAnswer":24,"Strength%":4.8096192385,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["salty","good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"viscositys good","TotalCountAllAnswer":23,"Strength%":4.6092184369,"ImportantEntity":[],"ImportantVerbEntity":["viscositys"],"EntityAttributes":["good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"textures soft","TotalCountAllAnswer":14,"Strength%":2.8056112224,"ImportantEntity":["textures"],"ImportantVerbEntity":[],"EntityAttributes":["soft"],"TopicSentiment":0.1,"TopicSubjectivity":0.35},{"ImportantTopic":"chilli smells strong","TotalCountAllAnswer":13,"Strength%":2.6052104208,"ImportantEntity":["chilli"],"ImportantVerbEntity":["smells"],"EntityAttributes":["strong"],"TopicSentiment":0.43,"TopicSubjectivity":0.73},{"ImportantTopic":"spicy taste strong","TotalCountAllAnswer":10,"Strength%":2.004008016,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["spicy","strong"],"TopicSentiment":0.43,"TopicSubjectivity":0.73},{"ImportantTopic":"garlic taste good","TotalCountAllAnswer":10,"Strength%":2.004008016,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["garlic","good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"spicy taste","TotalCountAllAnswer":6,"Strength%":1.2024048096,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["spicy"],"TopicSentiment":0.0,"TopicSubjectivity":0.0},{"ImportantTopic":"garlic smell strong","TotalCountAllAnswer":6,"Strength%":1.2024048096,"ImportantEntity":["smell"],"ImportantVerbEntity":[],"EntityAttributes":["garlic","strong"],"TopicSentiment":0.43,"TopicSubjectivity":0.73},{"ImportantTopic":"chilli smells strong good","TotalCountAllAnswer":5,"Strength%":1.002004008,"ImportantEntity":["chilli","good"],"ImportantVerbEntity":["smells"],"EntityAttributes":["strong"],"TopicSentiment":0.57,"TopicSubjectivity":0.67},{"ImportantTopic":"chilli smells good","TotalCountAllAnswer":5,"Strength%":1.002004008,"ImportantEntity":["chilli"],"ImportantVerbEntity":["smells"],"EntityAttributes":["good"],"TopicSentiment":0.7,"TopicSubjectivity":0.6},{"ImportantTopic":"garlic smells strong","TotalCountAllAnswer":4,"Strength%":0.8016032064,"ImportantEntity":["garlic"],"ImportantVerbEntity":["smells"],"EntityAttributes":["strong"],"TopicSentiment":0.43,"TopicSubjectivity":0.73},{"ImportantTopic":"garlic taste strong","TotalCountAllAnswer":4,"Strength%":0.8016032064,"ImportantEntity":["taste"],"ImportantVerbEntity":[],"EntityAttributes":["garlic","strong"],"TopicSentiment":0.43,"TopicSubjectivity":0.73},{"ImportantTopic":"sauce taste strong","TotalCountAllAnswer":4,"Strength%":0.8016032064,"ImportantEntity":["sauce","taste"],"ImportantVerbEntity":[],"EntityAttributes":["strong"],"TopicSentiment":0.43,"TopicSubjectivity":0.73},{"ImportantTopic":"spicy tatse good","TotalCountAllAnswer":4,"Strength%":0.8016032064,"ImportantEntity":["tatse"],"ImportantVerbEntity":[],"EntityAttributes":["spicy","good"],"T ...
# [SERVER] 127.0.0.1 - - [25/Apr/2019 10:53:55] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ## Request 2 Dataframe

# %%
import pandas as pd
pd.DataFrame.from_dict(eval(r.text), orient='columns').head()
# Out:
#   EntityAttributes ImportantEntity        ImportantTopic ImportantVerbEntity  \
# 0    [spicy, good]         [taste]      spicy taste good                  []
# 1     [sour, good]         [taste]       sour taste good                  []
# 2   [savory, good]         [taste]     savory taste good                  []
# 3           [good]     [sweetness]  sweetness taste good             [taste]
# 4    [salty, good]              []      salty taste good             [taste]
#
#    Strength%  TopicSentiment  TopicSubjectivity  TotalCountAllAnswer
# 0  12.224449            0.70               0.60                   61
# 1   8.617234            0.27               0.35                   43
# 2   8.416834            0.70               0.60                   42
# 3   7.014028            0.70               0.60                   35
# 4   4.809619            0.70               0.60                   24

# %%
# !ps -fA | grep python
# Out:
# root          31      11  2 18:29 ?        00:00:01 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --MappingKernelManager.root_dir="/content"
# root         144      31 11 18:29 ?        00:00:01 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-1d33ff92-aadf-4b2c-92c8-3a2b555c2a3b.json
# root         166     144  0 18:30 ?        00:00:00 /bin/bash -c ps -fA | grep python

# %%
# !kill 2251
# Out:
# /bin/bash: line 0: kill: (2251) - No such process

# %%
import pandas as pd
df = pd.read_csv("AmazonReviewBig_Test.csv")

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc1 = nlp("good")
doc2 =nlp("nice")
doc1.similarity(doc2)
# Out:
# 0.8133191041632585

# %%
from gensim.models import Word2Vec
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/ssh.py:34: UserWarning: paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress
#   warnings.warn('paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress')

# %%
sentences = df['ImportantTopic'].tolist()

# %%
import gensim
model = gensim.models.Word2Vec([sentences],min_count=1,size=32)

# %%
print (model.most_similar(positive=['great condition'], negative=[], topn=2))
# Out:
# [('straight talk matt', 0.6311078071594238), ('simple task im', 0.5678778886795044)]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
X = model[model.wv.vocab]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=5)
kmeans.fit(X)
 
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
 
# print ("Cluster id labels for inputted data")
# print (labels)
# print ("Centroids data")
# print (centroids)
 
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
 
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')
 
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -3.3837767
# Silhouette_score:
# 0.022312539

# %%
words = list(model.wv.vocab)
for i, word in enumerate(words):  
    print (word + ":" + str(labels[i]))
# Out:
# new phone:4
# sim card:2
# great phone:0
# good condition:4
# great condition:4
# perfect condition:0
# home button:1
# apple store:4
# great product:3
# works great:2
# good phone:4
# battery life:1
# iphone 4:3
# iphone 4s:1
# excellent condition:4
# great price:1
# new iphone:0
# excellent product:0
# brand new:4
# verizon phone:1
# nice phone:0
# phone came:3
# great shape:3
# good product:1
# great deal:0
# cell phone:1
# new one:3
# first iphone:2
# serial number:4
# like new:0
# good price:4
# straight talk:2
# works perfectly:4
# good deal:1
# brand new phone:2
# old phone:1
# phone works great:0
# used phone:3
# full charge:3
# would recommend:1
# good shape:4
# new battery:2
# long time:4
# cant use:0
# excellent phone:4
# original box:1
# unlocked phone:0
# money back:0
# verizon store:4
# works fine:0
# dont know:1
# sprint phone:3
# full refund:1
# great purchase:1
# original packaging:2
# first time:1
# refurbished phone:4
# quick delivery:1
# replacement phone:4
# iphone 5:0
# worked great:1
# works well:4
# phone would:1
# big deal:0
# phone arrived:1
# tmobile sim card:0
# water damage:0
# works good:1
# phone works:3
# new condition:1
# pristine condition:2
# power button:3
# old iphone:1
# good quality:3
# working fine:0
# awesome phone:3
# customer service:4
# would like:1
# next day:1
# wi fi:2
# original charger:1
# sim card slot:0
# highly recommend:2
# previous owner:1
# excelente producto:4
# didnt work:1
# working great:4
# great value:0
# product description:2
# great item:4
# good iphone:0
# amazon warehouse:2
# doesnt work:0
# looked brand new:3
# looks like:4
# good purchase:1
# dont buy:2
# working well:2
# apple iphone:1
# wrong phone:1
# speaker phone:0
# timely manner:3
# even though:4
# full battery:2
# return window:0
# great buy:3
# works like:3
# perfect phone:2
# nice iphone:0
# smart phone:2
# wall charger:3
# works perfect:3
# daughter loves:1
# gsm phone:2
# worked fine:2
# looked like:0
# delivery time:1
# mint condition:2
# excelent product:4
# birthday gift:0
# reasonable price:4
# apple product:4
# first day:1
# sprint network:1
# working good:1
# new iphone 4s:2
# 5 stars:0
# looks great:1
# great service:3
# good way:2
# working perfectly:0
# minor scratches:2
# second phone:3
# android phone:3
# iphone 5c:4
# wont work:2
# new sim card:3
# apple phone:4
# verizon network:3
# international sim card:4
# little slow:3
# teenage son:0
# gsm network:2
# use phone:0
# apple products:3
# first phone:2
# total waste:4
# best phone:4
# great experience:2
# work properly:0
# phone number:4
# make sure:2
# really like:1
# 2 months:4
# great seller:0
# fast delivery:3
# backup phone:3
# apple charger:4
# extra charger:1
# son loves:4
# original accessories:2
# sprint store:2
# last week:2
# really good:4
# fast shipping:0
# longer works:3
# good job:3
# iphone came:4
# phone works fine:1
# white iphone:4
# touch screen:3
# att phone:3
# whole time:2
# face time:2
# wasnt able:0
# airplane mode:4
# cant return:0
# could use:3
# didnt want:0
# never buy:0
# cant get:2
# last phone:0
# 3 months:3
# good buy:1
# arrived quickly:4
# decent phone:4
# looks brand new:4
# phone brand new:3
# otter box:4
# single scratch:0
# central america:0
# phone thanks:2
# came exactly:1
# first one:0
# wrong charger:4
# time brand new:0
# same day:3
# whole experience:2
# new device:1
# good thing:3
# mophie case:4
# perfect shape:2
# dead battery:0
# didnt come:0
# phone back:0
# old one:0
# one thing:0
# phone works perfectly:4
# teenage daughter:3
# horrible experience:2
# phone activated:3
# micro sim:1
# micro sim card:2
# refurbished iphone:2
# phone today:1
# hard time:4
# phone worked:1
# extremely happy:2
# didnt know:3
# two months:4
# hard reset:2
# voice mail:0
# original phone:1
# 2 weeks:3
# charger cable:0
# stopped working:1
# power brick:0
# short time:4
# wouldnt charge:4
# big scratch:0
# apple iphone 4s:1
# bad product:3
# complete waste:4
# good afternoon:2
# first apple phone:3
# phone looks great:2
# verizon iphone:0
# first smart phone:1
# main reason:2
# amazing condition:4
# nice phone works great:2
# would definitely recommend:0
# much better:4
# usb cable:0
# would work:4
# head phone:2
# love everything:0
# 2 days:1
# happy camper:1
# middle button:2
# front camera:4
# excellent shape:0
# volume button:0
# looks new:3
# last time:3
# would buy:1
# ear buds:0
# home button doesnt work:0
# compatibility issue:4
# reputable seller:0
# home screen:0
# two weeks:3
# three weeks:3
# worked like:3
# working properly:4
# even better:3
# locked phone:2
# great smartphone:3
# im happy:2
# everything ok:4
# portable charger:1
# product arrived:3
# wifi network:0
# christmas gift:4
# minor scratch:1
# screen protector:1
# nice product:2
# good service:3
# product came:1
# use speaker:3
# good conditions:3
# phone died:3
# top button:4
# factory unlocked:3
# like brand new:1
# new screen:0
# mobile phone:3
# phone 4:0
# dont want:4
# battery doesnt hold:2
# whole day:0
# looks good:0
# good item:1
# cant connect:2
# wouldnt turn:2
# different seller:0
# phone looks brand new:4
# 2 years:3
# worked well:3
# apple fan:2
# amazon warehouse deals:4
# charger cord:1
# whole lot better:1
# didnt like:0
# phone used:1
# used iphone:1
# other phone:4
# still locked:1
# pleasantly surprised:1
# wifi antenna:4
# wuthout box:1
# well worth:2
# wifi signal:2
# look new:2
# great phone works:1
# credit card:0
# good morning:2
# defective phone:1
# 1 month:4
# disappointing purchase:0
# old iphone 4:0
# excellent seller:0
# flash light:4
# excellant condition:1
# ios 7:2
# local chip:1
# time works great:3
# something wrong:2
# amazon item:0
# quality product:4
# works great love:2
# would give:0
# didnt expect:1
# phone seems:4
# next time:3
# regular phone:4
# wouldnt load:4
# apple logo:4
# good batey:3
# iphone 6:4
# 6 months:1
# awesome condition:0
# good backup phone:0
# right away:2
# good option:1
# good physical condition:1
# brand new iphone:3
# 32 gb iphone:1
# different sim card:3
# doesnt hold:3
# stolen phone:4
# replacement iphone:0
# go back:2
# new product:4
# absolutely love:0
# return policy:4
# bought 2:3
# phone literally:3
# low price:2
# better condition:2
# black iphone:2
# ios 9:0
# new charger:0
# described thank:0
# everything works:4
# phone stopped working:0
# great condition works:4
# phone home button:1
# really love:1
# factory reset:3
# problems activating:0
# fair price:4
# many times:4
# poor quality:2
# christmas present:4
# two days:4
# sym card:3
# little use:4
# fully charged:1
# finally got:0
# black case:2
# terrific product:2
# shakey meaning:2
# muy bueno:3
# apples product warranty:2
# good work:1
# center button:2
# product information:4
# sim tool:2
# new tksss:4
# text part:0
# google voice:4
# hot spot availability:4
# hard reset several times:0
# come back:1
# extremely pleased:2
# good customer service:2
# phone didnt work:3
# battery failure:3
# cheap deal:1
# sons first phone:4
# new phone thanks:2
# imei number:0
# item description:1
# didnt get:1
# first time phone:0
# phone looked:0
# little leary:0
# cell phones:1
# perfect condition thanks:0
# good sale:4
# great replacement:0
# yellow hue:2
# user device:1
# excellent physical condition:3
# 5 star:4
# correct color:0
# must say:2
# great iphone:3
# new contract:3
# good case:3
# workthe home key:0
# finleynext time ill:1
# doedit product works:3
# useless hope:1
# multiple carrierstmobile verizon:3
# 100 perfect condition:1
# purchase iphone 5:1
# works like new:4
# wont turn:2
# front screen:1
# warranty replacement:0
# good battery life:4
# wall plug:0
# great investmentstarter:3
# simple mobile prepaid carrier:0
# car charger:1
# cellular data network tab:4
# phone met:4
# charge cable:1
# sign weariness:1
# stratches bad condition unacceptable:4
# good quality phone:4
# arrived promptly:2
# iphone person:0
# plain box:1
# bad deal:2
# prepaid phone:0
# cell service:1
# great price phone:2
# return date:0
# one month:2
# fourth time:2
# description said:4
# work right:3
# would say:2
# front side:0
# primary phone:1
# good item thanks amazon:1
# support system:1
# black phone:3
# police returnso bad:2
# phone works great love:1
# started using:2
# amazon site:4
# work fine:0
# 90 day warranty:3
# picture love:2
# great value check:3
# sim cardweak:3
# verizon wireless phoneim:2
# gsm network phone:4
# real phone:4
# little girl happy:1
# 10 yr old grandson:1
# mom n:2
# work perfectly:0
# phone iswith:0
# right amount:2
# great phone love:1
# wrong chargeri:2
# fancy box:4
# wireless adapter:0
# black list:0
# accurate description:0
# sound quality:2
# mophie juice pack:2
# locked verizon phone:0
# same phone:3
# excellent item:0
# verizon compatible phone:1
# purchase phone:4
# reported stolen:1
# ear piece:4
# bad thing:3
# recently bought:3
# bad battery:0
# dont need:4
# diagnostic test:1
# would highly recommend:4
# verizon account:2
# amazing deal:4
# excellent value:4
# another iphone:2
# excellent condition works great:0
# dont mind:2
# happy customer:1
# work well:3
# phone looks like new:0
# original one:2
# phone thank:4
# recovery mode:4
# first month:2
# main screen:4
# phone thinking:2
# att service:0
# 2 phones:3
# used iphone 4:0
# start using:1
# lock button:3
# another phone:4
# great customer service:2
# send back:3
# phone works well:2
# major issue:3
# also came:1
# cant hear:3
# buy another one:3
# apple support:0
# seller said:0
# new purchase:2
# make phone calls:1
# bad reviews:0
# one year:2
# other end:4
# looks like new:4
# satisfied customer:3
# 45 days:1
# get one:4
# iphone 3:1
# wont let:3
# love amazon:0
# last iphone:3
# prepaid contract:1
# battery lifehow:1
# virgin mobile iphone:1
# attmy opinion:0
# cant workout:4
# big problem:4
# apple iphone 5c:4
# electric connector:1
# verizonthe phone:3
# big strain:2
# local phone store:4
# iphone battery:2
# slow system:4
# month boooooooo:3
# starkey aid:2
# 30 day warranty:0
# inoperative plase:1
# date iphone 4s:1
# great quality phone:2
# wifi router:2
# bday gift:0
# unit today:2
# excelent cell phone:4
# verizon sim card:3
# gift card:2
# little sister:3
# cannot get:0
# internal wire packaging:0
# good music:4
# performance difference:3
# 1st iphone:3
# time perfect love:3
# good jobpsit:0
# new old iphone:4
# everyday device:0
# previous owner itune login:1
# poor battery backup:1
# memoryslow processing:1
# good excelent:4
# cell phone service provider:1
# new iphone 7s:4
# temporal use:1
# really need:3
# cannot use:0
# fast ship:2
# good reception:0
# 16 gb:2
# poor son:1
# nice scratch:4
# phone company:1
# full return:4
# call someone:0
# delivered quickly:3
# much rafael gonzález:0
# appropriate fot:4
# bottom part:1
# 32gb iphone:0
# welcome screen:1
# significant inconvenience:2
# 7 months:2
# mic wifi works:1
# old acer phone:1
# low quality:3
# refurbished model:1
# sim card slot side:3
# current carrier:1
# great 1st iphone:0
# didnt realize:1
# details dealfisher seller:4
# cell plan:1
# key thingy:1
# newest one memory 16gb:3
# windows phone power user:2
# cant claim return:3
# old cellphone 108030p good:1
# huge waste:1
# button right issleepshut:1
# good afternoon amazon:0
# upthe bad news:1
# refurbished one:2
# iphone 44s:4
# looked fine:0
# much amazon:0
# use screen:4
# good news:2
# normal product:3
# couldnt use:2
# much money:3
# apple apple:0
# im satisfied:4
# okay phone:0
# 100 satisfied:1
# standby time:3
# 5 full charge:2
# 5 full discharge:1
# contract company:2
# purchase service:2
# 3 weeks:0
# worst amazon purchase:3
# first apple device:3
# seller since:3
# meid number:0
# overall quality:3
# import model:3
# sprint service:2
# defective product:0
# auxiliary cord:4
# fine except:0
# little disappointed:1
# byop sim card:3
# contract phone:4
# micro sim kit:4
# regular size:0
# home key:0
# criteria excellent service:4
# first owner:2
# local simcard work exсellent:0
# total refund:3
# future purchases:4
# round wit:3
# verizon prepaid plan:3
# cannot hear:3
# wrong usb cable:3
# product bad wifi:1
# wifi source:3
# professional filmography:4
# expectation coz:2
# bad experience:4
# old cable:1
# iphone problem:3
# home buttom:4
# seller problem:0
# rating scale:3
# cheap charger:1
# small crack:2
# rubber cable:1
# camera lens:0
# almost dead:3
# wrong kind:2
# daughter birthday gift:1
# works perfectly fine:4
# thorough inspection:0
# internal storage:0
# prpaid verizon:4
# excellent price:4
# externa storage ports:1
# internet wifi:1
# reasonable pricing:2
# slacker radio:4
# terrible product battery life:2
# crisp clear color:2
# bad state:1
# phone entry slot:3
# 2 hours:2
# home button stopped working:2
# really happy:1
# package arrived:3
# im glad:3
# post office:1
# sure everything:4
# download certain app:3
# work final determination:2
# equipment testing:4
# metro store:0
# dayvery narrow screen:2
# wrong charger port:0
# good need:2
# excelent product excellent condition:1
# lot less:1
# daily basis:4
# great phonegood price:0
# small scratch:2
# works great thank:2
# ever since:2
# earphone portion:1
# local apple store:0
# first call:1
# hold charge:2
# atrocious total waste:0
# false advertisement phone:2
# apo adressafghanistan:2
# good camera:4
# verizon compatible deceptive description:1
# iphone 5s:3
# superb alltogether:2
# many things:3
# iphone great description:3
# great phone easy:1
# sprint verizon:0
# visible damage:1
# used one:4
# videos music keyboard clicks:4
# speedy order:2
# great phone great price:4
# great phone today:4
# buen producto:4
# failure wifi:4
# dont use:0
# im using:3
# dont even know:3
# great phonebut:0
# siliconehard plastic combo case:3
# rattle noise:4
# control center:0
# month hype:1
# sim card opening:3
# extra money:2
# battery charge:4
# dont think:0
# angrythis phone:1
# 1 week:3
# iphone great product:2
# hardware glitch:1
# google wifi issues:4
# good stuff:2
# never got:4
# current price:3
# long process:1
# didnt need:3
# solid performance:2
# use battery:1
# good phones good cost:3
# factory unlock:4
# every thing:2
# bin nothing:4
# loose screen:0
# head phone chip charger:4
# 4g lte plan:3
# new brand iphone:1
# bad batery:3
# really disappointed:1
# slowomg purchase:2
# installed micro chip:4
# cdma verizon:3
# iphone speed:0
# phone 4s:0
# problems getting:1
# dont like:1
# every time:0
# within 2 days:4
# still working:1
# amazon said:4
# would recommend buying:1
# battery seems:4
# unlocked phones:4
# hardware problem:1
# iphone 4 32gb:0
# little worried:1
# wasnt unlock:0
# good value:3
# would use:2
# cant beat:4
# two stars:0
# low sound:2
# volume control:0
# gracias excelente:1
# battery dies:0
# home button sticks:2
# dont understand:1
# absolutely loves:1
# wont charge:4
# seller described:3
# buyer beware:0
# user friendly:4
# well however:1
# would definitely buy:3
# phone looks:3
# bad karma:2
# other person:1
# phone looked new:4
# same thing:0
# real iphone:3
# 2 stars:4
# data plan:4
# looked great:1
# full price:2
# repair shop:4
# service provider:0
# android smart phone:4
# birthday present:3
# used like new:0
# first week:3
# phone calls:0
# phone wouldnt:0
# latin america:0
# hours without:2
# 5 weeks:0
# iphone works:2
# used cell phone:3
# brand new iphone 4s:3
# hes happy:0
# false advertising:1
# dont work:1
# everything came:2
# brand new one:2
# completely unlocked:0
# bright side:1
# research properlyhowever:3
# 8gb iphone:2
# works excellent:2
# keep telling:2
# fabulous condition:2
# empty package:4
# apple company:3
# good shapethank:1
# second one:4
# pretty good:0
# good reliable phone:2
# super long battery life:1
# found one:2
# memory card:0
# original low quality parts:1
# delivery date:2
# junk amozon:1
# mini usb port:0
# ina good package:4
# main number:1
# everything worked:2
# old tracfone:0
# tmobile carrier:4
# head phones:0
# defective battery:1
# call sprint:2
# phone right:1
# share facetime:0
# hardware issue:1
# nano sim:3
# daughters phone:1
# social circle:1
# phone serial number:3
# nonoem charger:3
# longtime iphone user:1
# great starter phone:1
# extraordinary price:3
# bad condition:4
# good time:4
# cheap product:3
# elderly woman:3
# beta testing:4
# first review:4
# second time:1
# plastic sleeve:4
# total fraud:2
# white box charge wall:0
# works beautifully:1
# different phone:3
# much easier:0
# phone works good:3
# 30pin cable:3
# crisp sound:3
# teenage son high quality:4
# either way:3
# iphone 4 box:1
# wi fi tab works:1
# emergency backup power:1
# 30pin connector:2
# high speed internet:0
# bad drop:1
# wont hold:1
# drop protection:1
# local sim card:3
# wifi tab:4
# former carrier:0
# use iphone:2
# new sim:2
# 5 star rating:3
# iphone work good:1
# backup power:1
# one slight problem:4
# risk damage:2
# mophie plan:4
# wife cost less:3
# os software upgrades:2
# battery caseif:0
# sim slot available:4
# 30 days:4
# nice communication:0
# lexington sc:1
# problem thank:0
# normal hardware problem:3
# lukkilukki dealer:3
# sprint account:1
# wasnt unlocked like:0
# droid x2:0
# great battery pack:3
# white one:4
# 3 stars:4
# friday night:2
# new iphoneand:1
# crappy phone:0
# return phone:2
# regular insertionor removal:2
# 32 gb phone:3
# nice first phone:1
# sim card slot pindid:0
# old model:1
# old 4s:1
# description perfect condition:0
# certified refurbished:0
# good qualitythe charger:3
# called apple:4
# unnoticeable device:0
# free case:2
# someone else:2
# week later:1
# proper connection:3
# would die:3
# product fall short:3
# low battery:0
# working phone:3
# existing verizon account:3
# actually bought:4
# daughter love:1
# ipod touch:1
# could find:2
# wont stay charged:0
# good seller:2
# seller due:2
# 32 gb:1
# great device:2
# poor college student:2
# white phone:1
# point form:1
# graduation gift:0
# page description:0
# motorola droid:4
# use apple:2
# particular phone:3
# got one:2
# work great:2
# second hand:1
# amazing product:4
# arrived exactly:1
# kool new design:3
# total disappointment:1
# android charger:4
# external mophie:2
# small portion:1
# box dosnt:0
# useful addition:3
# great work:0
# new model:1
# positive experience:1
# big fan:3
# smartphone world:2
# another one:4
# phone part:0
# nearest apple store:4
# siri love:2
# crappy cricket lg 90:0
# good packaging:2
# one speaker works:1
# 2030 battery life:0
# good aquisition:4
# excellent seller recommendable 100:4
# son wanted:4
# stop working:4
# good things:3
# warehouse deals:4
# usb connector:1
# att store:0
# reliable phone:3
# sim slot:0
# wasnt new:2
# onoff button:0
# usb charger:0
# factory box:3
# samsung galaxy s3:4
# new iphone 5:1
# wrong carrier:4
# description says:1
# could get:2
# nice thing:4
# battery discharge:2
# small size:3
# first time use:4
# minimal use:2
# within 3 hours:1
# starter iphone:3
# weird buzzhum:4
# local verizon store:1
# current phone:1
# wireless network:2
# huge deal:2
# friggen week:4
# ear piece doesnt work:4
# battery consumption:4
# verizon iphone verizon:3
# perfect iphone:1
# phone dint work:4
# initial concern:0
# 3g phone:0
# charging port:1
# need eventhough:3
# phone bulkier:2
# silent mode:4
# use cellular service:0
# one big complaint:3
# telephone conversation:4
# cant swap sims:2
# windows 10 mobile siri:0
# best buy:4
# first got:2
# old cell phone:2
# phone could:0
# front speaker:3
# cortana microsoft phones:3
# 32gb phone:1
# schoolsthey use facetime:3
# think twice:4
# phone cause:3
# works like brand new:1
# other iphone:1
# brand new factory:3
# still didnt work:4
# wife loves:4
# phone use:4
# new iphone 4:0
# may get:0
# good evening:4
# headphone jack:0
# bad iphone:3
# excellent condition works:2
# cant hold:4
# phone online:0
# work cant:1
# stay connected:2
# 5 min:2
# would love:0
# well pleased:4
# get hot:3
# previous phone:0
# one day:4
# high quality:3
# box sealed:2
# charging cable:0
# good piece:4
# phone condition:2
# activation number:0
# back camera:1
# thing wrong:1
# wont connect:1
# bought two:4
# iphone 4s 16gb:2
# described phone:0
# ios 92:4
# device works:3
# stolen one:3
# tried calling:3
# took forever:2
# came sooner:2
# home page:1
# time zone:2
# used iphone 4s:4
# described works great:3
# great phone came:2
# item came:4
# longest time:2
# im trying:3
# lot better:2
# beautiful phone:1
# cool phone:4
# went back:4
# ear speaker:0
# problem ive:3
# shipping time:0
# working ok:1
# absolutely wonderful:0
# goodits hangingseems like software:4
# one problem:3
# device recommended:1
# problem getting:4
# factory refurbished phone:3
# return date otherwise:1
# mind last phone:0
# really never worked properly:1
# get around:4
# works okay:0
# good items:4
# specifically asked:0
# working wonderfully:0
# verizon wireless phone:0
# 5 hours:2
# much bought another one:4
# didnt use:1
# one looks:2
# year liked:3
# apple tech:2
# phone without:1
# battery wont stay charged:1
# high prices:4
# verizon however:0
# negative reviews:4
# due date:3
# like new condition:4
# apple box:4
# great deliviry:3
# metro pcs:4
# battery lasts:0
# weekend phone works:3
# other line:3
# old phone went:0
# bad esn:1
# thank u:3
# iphone box:4
# easy setup:1
# easy setup prompts:1
# phone delivered:2
# awesome seller:3
# broken phone:1
# husband loves:2
# tried everything:0
# excellent service:4
# never go back:3
# genuine product:0
# always used:1
# complete accessories:2
# used item:4
# best iphone:1
# great deliviry got:1
# 3 days:3
# use sim card:1
# phone didnt:0
# receive calls:4
# speakers dont work:3
# such great deal:1
# fully satisfied:2
# works pretty good:3
# english:2
# weekend phone works perfectly:0
# recently purchased:0
# lovely phone:4
# unlocked iphone:4
# didnt receive:2
# say im:2
# refurbish phone:1
# 1st time:4
# email account:0
# quite slow:1
# product recommended thank:4
# straight talk works great:3
# buy another:1
# 24 hours:1
# may want:3
# everything seems:3
# full functional:4
# extremely disappointed:2
# week ago:2
# loud exterior:2
# battery would:2
# shipping im using:1
# slightly glitchy:0
# randomly turn:4
# pretty impressed:4
# much worse:0
# seller said works great:0
# go plan:3
# battery connector:4
# screen freezes:2
# perfect shape works:1
# couldnt afford:4
# sound doesnt work properly:3
# sons phone:4
# weeks ago:4
# sims card:2
# hear back:2
# 64 gb:4
# make sure everything:2
# called cricket wireless:0
# amazon customer service:3
# start button:1
# anything totally disappointed:2
# reset holding:2
# activation kit:2
# people cant hear:4
# app store:4
# torch would turn:3
# battery went:3
# put cricket wireless:2
# awesome price:2
# didnt meet:3
# 10 mins:0
# highly recommended:3
# difficulty connecting:0
# charger base:2
# charge doesnt complete:0
# quit working:4
# wasnt even theres:0
# product said:4
# receive without:2
# worked normal:2
# z guarantee:0
# well strongly recommended:1
# more expensive version:2
# default screen:1
# new sim chip without:0
# much hassle:3
# iphone 4s unlocked:0
# exactly unlock:1
# setup like:1
# plain white box:2
# phone indicates:0
# everyone else:0
# interested buyers:3
# 16gb iphone 5syea:3
# recertified guaranteed:2
# new product perfect:4
# voice messages:3
# packaged like:0
# still using:1
# grandson test:2
# awesome phone awesome seller:4
# week late:3
# wide array:4
# phone using itunes:3
# working waste:2
# quick service:3
# warranty period:1
# customers living room:0
# imei verification:2
# another hard reset:0
# well made:2
# fully unlocked:2
# battery still:3
# brand new phone works great:0
# phone never rang:3
# first game:0
# own replacement:0
# trouble getting:1
# daughters iphone 5c:2
# pantech phone:1
# cheap usb cable:1
# got phone:1
# cel right:0
# text someone:0
# reboot screen:2
# home button malfunction:0
# battery doesnt lasts wifi:1
# numbers got changed:1
# 3 days great phone:2
# seller toothanksomaima:4
# camera roll:4
# complete seti:3
# download current iso:0
# right one sad cant use:2
# another example:4
# awful review:1
# low nobody:2
# little bit early:2
# charge included:1
# exquisite condition:2
# went straight:1
# battery quality:1
# samsung lg:4
# carrier service:0
# huge leap:2
# iphone nation:3
# usually call:2
# teenager wanting:0
# question seven:2
# voice mail called tmobile:1
# phone early:0
# good shopping:1
# bad product bad battery life:0
# available wifi:0
# text tone:2
# said check:1
# use seller:3
# without even contacting:0
# im going:0
# other iphone 4s:3
# person corrected number called:3
# home botton:1
# sim card isnt needed:4
# first gen droid:0
# works welli:4
# dies within:3
# one would support:2
# two moregood communication:0
# network evidently unlocked 4ss:2
# voice mail phone turned:0
# wrong iphone:2
# dont recommend buying anything:1
# nice case:3
# much memory:3
# due note:1
# unlocked sold:4
# phone shuts:1
# big pos sorry:4
# wont put:3
# 30 minutes:1
# earphoneear plug:0
# sad moment:4
# personal information:4
# verizon phone waited:1
# customers place:2
# way better:2
# goes well:4
# get texts:1
# screen indicates:2
# deletes texts:2
# allproduct work good:4
# phones battery:3
# previously owned:3
# new one besides:2
# perfect product:2
# doesnt even work:2
# package deal:3
# many time:0
# ordered black:4
# working order:0
# several months:3
# iphone form sjohnson236:2
# amazon seller:0
# gevey adapter:1
# working cell phone:2
# galaxy s3:4
# still attached:0
# frankinstien meaning:2
# aiogreat plan:3
# excellent condition venezuela:0
# third party vender60 bucksbecause:3
# third party vender:3
# excellent coondition:0
# desperately unfuntional:0
# front button:4
# exactly like:0
# works great better:2
# still use:3
# item said:4
# fantastic price:4
# 1star rating:4
# next ten10 days:4
# 14 year old son:3
# desperate need:2
# great us everyone know:0
# speakers doesnt work:3
# bad price:4
# described perfect:3
# handled properly:1
# faithful itouch btw:3
# sim cutter:2
# sim provider:3
# left totally alone:1
# clean product two thumbs:4
# better shape:2
# extra memory:2
# iphone arrived:0
# doesnt meet:2
# charger isnt working:3
# issues also ordered two:2
# supertough plastic:1
# 12hrs standby long:1
# short battery life:4
# loyal customer:0
# buy another one thank:1
# battery cells must:4

# %%
# df = pd.DataFrame.from_dict(eval(r.text), orient='columns')
df['ImportantEntity'] = df.ImportantEntity.astype(str)
df['EntityAttributes'] = df.EntityAttributes.astype(str)
df = df[df['EntityAttributes'] != "[]"]
# type(df['ImportantEntity'][0])
df[df['ImportantEntity'].str.contains("condition")]
# df[df['ImportantTopic'].str.contains("shipping")]
# df[df['ImportantVerbEntity'].str.contains("definitely")]
# Out:
#       Unnamed: 0           EntityAttributes               ImportantEntity  \
# 3              3                   ['good']                 ['condition']
# 4              4                  ['great']                 ['condition']
# 5              5                ['perfect']                 ['condition']
# 14            14              ['excellent']                 ['condition']
# 69            69                    ['new']                 ['condition']
# 70            70               ['pristine']                 ['condition']
# 239          239                ['amazing']                 ['condition']
# 280          280                   ['good']                ['conditions']
# 323          323              ['excellant']                 ['condition']
# 341          341                ['awesome']                 ['condition']
# 345          345       ['good', 'physical']                 ['condition']
# 359          359                 ['better']                 ['condition']
# 366          366                  ['great']                 ['condition']
# 409          409                ['perfect']       ['condition', 'thanks']
# 414          414  ['excellent', 'physical']                 ['condition']
# 426          426                ['perfect']                 ['condition']
# 441          441    ['bad', 'unacceptable']                 ['condition']
# 504          504     ['excellent', 'great']                 ['condition']
# 710          710  ['excelent', 'excellent']      ['product', 'condition']
# 844          844               ['fabulous']                 ['condition']
# 877          877                    ['bad']                 ['condition']
# 940          940                ['perfect']  ['description', 'condition']
# 1137        1137                    ['new']                 ['condition']
# 1363        1363              ['excellent']    ['condition', 'venezuela']
#
#                             ImportantTopic ImportantVerbEntity  Strength%  \
# 3                           good condition                  []   0.633187
# 4                          great condition                  []   0.486197
# 5                        perfect condition                  []   0.458738
# 14                     excellent condition                  []   0.285904
# 69                           new condition                  []   0.067842
# 70                      pristine condition                  []   0.066226
# 239                      amazing condition                  []   0.029075
# 280                        good conditions                  []   0.025844
# 323                    excellant condition                  []   0.022614
# 341                      awesome condition                  []   0.022614
# 345                good physical condition                  []   0.020999
# 359                       better condition                  []   0.020999
# 366                  great condition works           ['works']   0.020999
# 409               perfect condition thanks                  []   0.019383
# 414           excellent physical condition                  []   0.019383
# 426                  100 perfect condition                  []   0.019383
# 441   stratches bad condition unacceptable       ['stratches']   0.019383
# 504        excellent condition works great           ['works']   0.019383
# 710   excelent product excellent condition                  []   0.016153
# 844                     fabulous condition                  []   0.012922
# 877                          bad condition                  []   0.012922
# 940          description perfect condition                  []   0.012922
# 1137                    like new condition                  []   0.011307
# 1363         excellent condition venezuela                  []   0.009692
#
#       TopicSentiment  TopicSubjectivity  TotalCountAllAnswer
# 3               0.70               0.60                  392
# 4               0.80               0.75                  301
# 5               1.00               1.00                  284
# 14              1.00               1.00                  177
# 69              0.14               0.45                   42
# 70              0.00               0.00                   41
# 239             0.60               0.90                   18
# 280             0.70               0.60                   16
# 323             0.00               0.00                   14
# 341             1.00               1.00                   14
# 345             0.35               0.37                   13
# 359             0.50               0.50                   13
# 366             0.80               0.75                   13
# 409             0.60               0.60                   12
# 414             0.50               0.57                   12
# 426             1.00               1.00                   12
# 441            -0.70               0.67                   12
# 504             0.90               0.88                   12
# 710             1.00               1.00                   10
# 844             0.40               1.00                    8
# 877            -0.70               0.67                    8
# 940             1.00               1.00                    8
# 1137            0.14               0.45                    7
# 1363            1.00               1.00                    6

# %%
pd.DataFrame.from_dict(eval(r.text), orient='columns').to_csv("AmazonReviewBig_Test.csv",encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-30-42d66cfd13e1> in <module>()
# ----> 1 pd.DataFrame.from_dict(eval(r.text), orient='columns').to_csv("AmazonReviewBig_Test.csv",encoding = 'utf-8')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# --> 172             self._save()
#     173
#     174         finally:
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     286                 break
#     287
# --> 288             self._save_chunk(start_i, end_i)
#     289
#     290     def _save_chunk(self, start_i, end_i):
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         libwriters.write_csv_rows(self.data, ix, self.nlevels,
# --> 315                                   self.cols, self.writer)
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 36-37: surrogates not allowed

# %% [markdown]
# ## Kill Port, If Hangs <Flask Port>

# %%
# !ps -fA | grep python
# Out:
# root          34      24  0 06:16 ?        00:00:13 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --MappingKernelManager.root_dir="/content"
# root         132      34  0 06:17 ?        00:02:04 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-e9e029f6-8ac6-48c4-8441-0b67434c274f.json
# root        1896      34  0 10:38 ?        00:00:02 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-c9555fae-256a-4ece-86f0-8b964fcd5530.json
# root        2060    1896  6 10:41 ?        00:00:32 /usr/bin/python3 -m flask run
# root        2065    2060  0 10:41 ?        00:00:00 /usr/bin/python3 -Wignore:::pip._internal.cli.base_command -c from multiprocessing.semaphore_tracker import main;main(3)
# root        2208    1896  0 10:49 ?        00:00:00 /bin/bash -c ps -fA | grep python

# %%
# !kill 2060

# %% [markdown]
# # Production Service -> Threshold Topic Similarity -> Gets Top N Topics Similairty -> Working

# %% [markdown]
# ## Server

# %%
# %%writefile server_similarity.py

#!/usr/bin/env python
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))
from multiprocessing import Pool
import multiprocessing
import scipy.sparse as sp
import collections
from flask import Flask
import pandas as pd
from rake_nltk import Metric, Rake
import spacy
from textblob import TextBlob
from flask import Flask, request, render_template
import pandas as pd
import string
import json
from textblob.np_extractors import ConllExtractor
from flask_jsonpify import jsonpify
from multiprocessing import Pool
import scipy.sparse as sp
import numpy as np
import pickle
import swifter


app = Flask(__name__)


def getSimilarity_topic(eachValue):
  SimilarityDict = {}
  SimilarityList = []
  SortedNumberValue = sorted( [(x,i) for (i,x) in enumerate(ImportantTopicsDF['Strength%'])], reverse=True )[:SortNumber][SortNumber-1][0]
  if ImportantTopicsDF['Strength%'][(ImportantTopicsDF['ImportantTopic'] == eachValue)].values[0] >= SortedNumberValue:
#     print ("Inside Important Topic", eachValue)
    for eachTopic in TopicList:
      SimilarityValue = float("{0:.2f}".format(nlp(eachValue).similarity(nlp(eachTopic))))
      if SimilarityValue > 0.90 and SimilarityValue < 1:
        StrengthValue = float("{0:.2f}".format(ImportantTopicsDF.loc[ImportantTopicsDF['ImportantTopic'] == eachTopic]['Strength%'].values[0]))
        SentimentValue = float("{0:.2f}".format(TextBlob(eachTopic).sentiment.polarity))
        SimilarityList.append([(eachTopic,SimilarityValue), ('Strength', StrengthValue ), ('sentiment', SentimentValue) ])
#         print (SimilarityList)
  SimilarityDict[eachValue] = SimilarityList
#   print (SimilarityDict)
  return SimilarityDict

import numpy as np
from multiprocessing import Pool
import scipy.sparse as sp
import multiprocessing
import swifter

num_partitions = 4
num_cores = multiprocessing.cpu_count()

 
def parallelize_dataframe(df, func):
    df_split = np.array_split(df, num_partitions)
    pool = Pool(num_cores)
    df = pd.concat(pool.map(func, df_split))
    pool.close()
    pool.join()
    return df
  
def ParallelizeDFOperation(ImportantTopicsDF):
  global SortNumber
  SortNumber = 10
  ImportantTopicsDF['TopicSimilarity'] = ImportantTopicsDF['ImportantTopic'].apply(getSimilarity_topic)
  return ImportantTopicsDF
  

def callParallelDFOperationFunction():
  return ParallelizeDFOperation(ImportantTopicsDF)

def getTopicList(PicklePath):
  with open(PicklePath, "rb") as f:
    return pickle.load(f)
  
def readData(path):
    # Read NPZ and Transform to Datafram. Single Question Responses. Sample is on 51 Records
    return pd.read_csv(path)
  
def loadSpacyModel(ModelName):
    return spacy.load(ModelName)

def Dataframe2JsonObject(dataframe):
#     df_list = dataframe.values.tolist()
#     JSONP_data = jsonpify(df_list)
#     return JSONP_data
    return dataframe.to_json(orient='records')

def getTopicListfromDF(Dataframe):
  return Dataframe['ImportantTopic'].tolist()

@app.route('/')
def SurveyClusterNTopic():
    global ImportantTopicsDF
    ImportantTopicsDF = readData('AmazonReviewOutput.csv')
    global TopicList
    TopicList = getTopicListfromDF(ImportantTopicsDF)
    
    
    global nlp
    ModelName = 'en_core_web_md'
    nlp = loadSpacyModel(ModelName)
    
    global num_partitions
    num_partitions = 4
    global num_cores
    
    global SortNumber
    SortNumber = 5
    global ParallelizeDFOperation
    num_cores = multiprocessing.cpu_count()
#     data = parallelize(ImportantTopicsDF, ParallelizeDFOperation)
    ImportantTopicsDF = parallelize_dataframe(ImportantTopicsDF, ParallelizeDFOperation)
    return Dataframe2JsonObject(ImportantTopicsDF)
if __name__ == '__main__':
    # nlp = spacy.load("en_core_web_sm")
    app.run(threaded=True)
# Out:
# Overwriting server_similarity.py

# %% [markdown]
# ## Server Run

# %%
import os
import subprocess
import sys
import time
import socket
# Start a subprocess that runs the Flask server
p = subprocess.Popen([sys.executable, "-m", "flask", "run"], env=dict(**os.environ, FLASK_APP="server_similarity.py"), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Start two subthreads that forward the output from the Flask server to the output of the Jupyter notebook
def forward(i, o):
    while p.poll() is None:
        l = i.readline().decode('utf-8')
        if l:
            o.write("[SERVER] " + l)

import threading
threading.Thread(target=forward, args=(p.stdout, sys.stdout)).start()
threading.Thread(target=forward, args=(p.stderr, sys.stderr)).start()
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))
# sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# Let's give the server a bit of time to make sure it has started
time.sleep(2)
# Out:
# 172.28.0.2
# [SERVER]  * Serving Flask app "server_similarity.py"
# [SERVER]  * Environment: production
# [SERVER]    WARNING: Do not use the development server in a production environment.
# [SERVER]    Use a production WSGI server instead.
# [SERVER]  * Debug mode: off
# [SERVER]  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ## Request

# %%
import requests
# r = requests.get("http://172.28.0.2/")
r = requests.get(" http://127.0.0.1:5000/")
print(r.status_code)
print(r.encoding)
print(r.apparent_encoding)
print(r.text)
# Out:
# [SERVER] 172.28.0.2
# 200
# utf-8
# ascii
# [{"Unnamed: 0":0,"EntityAttributes":"['great']","ImportantEntity":"['tablet']","ImportantTopic":"great tablet","Strength%":1.7616972912,"TopicSentiment":0.8,"TopicSubjectivity":0.75,"TotalCountAllAnswer":93,"TopicSimilarity":{"great tablet":[[["good tablet",0.96],["Strength",0.64],["sentiment",0.7]],[["great little tablet",0.93],["Strength",0.19],["sentiment",0.31]],[["perfect tablet",0.92],["Strength",0.15],["sentiment",1.0]],[["excellent tablet",0.93],["Strength",0.11],["sentiment",1.0]],[["nice tablet",0.92],["Strength",0.08],["sentiment",0.6]],[["better tablet",0.91],["Strength",0.08],["sentiment",0.5]],[["fantastic tablet",0.95],["Strength",0.06],["sentiment",0.4]],[["best tablet",0.92],["Strength",0.04],["sentiment",1.0]],[["terrific tablet",0.93],["Strength",0.04],["sentiment",0.0]],[["great tablet use",0.94],["Strength",0.04],["sentiment",0.8]],[["great inexpensive tablet",0.92],["Strength",0.04],["sentiment",0.8]],[["tablet work great",0.94],["Strength",0.04],["sentiment",0.8]],[["awesome tablet",0.93],["Strength",0.04],["sentiment",1.0]],[["amazing tablet",0.93],["Strength",0.04],["sentiment",0.6]],[["well tablet",0.93],["Strength",0.02],["sentiment",0.0]],[["great tablet brought",0.94],["Strength",0.02],["sentiment",0.8]],[["back great tablet",0.93],["Strength",0.02],["sentiment",0.4]],[["great tablet other",0.94],["Strength",0.02],["sentiment",0.34]],[["one tablet",0.91],["Strength",0.02],["sentiment",0.0]],[["tablet works great",0.94],["Strength",0.02],["sentiment",0.8]],[["really good tablet",0.91],["Strength",0.02],["sentiment",0.7]]]}},{"Unnamed: 0":1,"EntityAttributes":"['good']","ImportantEntity":"['tablet']","ImportantTopic":"good tablet","Strength%":0.6440613753,"TopicSentiment":0.7,"TopicSubjectivity":0.6,"TotalCountAllAnswer":34,"TopicSimilarity":{"good tablet":[[["great tablet",0.96],["Strength",1.76],["sentiment",0.8]],[["great little tablet",0.91],["Strength",0.19],["sentiment",0.31]],[["excellent tablet",0.94],["Strength",0.11],["sentiment",1.0]],[["nice tablet",0.94],["Strength",0.08],["sentiment",0.6]],[["better tablet",0.95],["Strength",0.08],["sentiment",0.5]],[["fantastic tablet",0.91],["Strength",0.06],["sentiment",0.4]],[["best tablet",0.92],["Strength",0.04],["sentiment",1.0]],[["terrific tablet",0.91],["Strength",0.04],["sentiment",0.0]],[["good small tablet",0.93],["Strength",0.04],["sentiment",0.22]],[["great tablet use",0.92],["Strength",0.04],["sentiment",0.8]],[["tablet great",0.96],["Strength",0.04],["sentiment",0.8]],[["tablet work great",0.91],["Strength",0.04],["sentiment",0.8]],[["well tablet",0.94],["Strength",0.02],["sentiment",0.0]],[["pretty good tablet",0.94],["Strength",0.02],["sentiment",0.47]],[["much better tablet",0.91],["Strength",0.02],["sentiment",0.5]],[["one tablet",0.91],["Strength",0.02],["sentiment",0.0]],[["really good tablet",0.95],["Strength",0.02],["sentiment",0.7]]]}},{"Unnamed: 0":2,"EntityAttributes":"['great']","ImportantEntity":"['price']","ImportantTopic":"great price","Strength%":0.5304034855,"TopicSentiment":0.8,"TopicSubjectivity":0.75,"TotalCountAllAnswer":28,"TopicSimilarity":{"great price":[[["good price",0.95],["Strength",0.15],["sentiment",0.7]],[["awesome price",0.92],["Strength",0.04],["sentiment",1.0]],[["great price easy",0.93],["Strength",0.04],["sentiment",0.62]],[["price great deal",0.95],["Strength",0.04],["sentiment",0.8]],[["great price fantastic gift",0.91],["Strength",0.04],["sentiment",0.6]],[["fantastic price",0.94],["Strength",0.04],["sentiment",0.4]],[["nice price",0.91],["Strength",0.04],["sentiment",0.6]],[["nice best price",0.93],["Strength",0.02],["sentiment",0.8]]]}},{"Unnamed: 0":3,"EntityAttributes":"[]","ImportantEntity":"['battery', 'life']","ImportantTopic":"battery life","Strength%":0.454631559,"TopicSentiment":0.0,"TopicSubjectivity":0.0,"TotalCountAllAnswer":24,"TopicSimilarity":{"battery life":[[["good battery life",0.95],["Strength",0.08],["sentiment",0.7]],[["reading battery life",0.93],["Strength",0.04],["sentiment ...
# [SERVER] 127.0.0.1 - - [22/Apr/2019 10:24:24] "GET / HTTP/1.1" 200 -

# %%
pd.DataFrame.from_dict(eval(r.text), orient='columns').to_csv("AmazonReviewTopicSimilairty.csv")

# %% [markdown]
# #Production Service -> Topic Similairty  -> Not Working

# %% [markdown]
# ##Server

# %%
# %%writefile server_similarity.py

#!/usr/bin/env python
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))
from multiprocessing import Pool
import multiprocessing
import scipy.sparse as sp
import collections
from flask import Flask
import pandas as pd
from rake_nltk import Metric, Rake
import spacy
from textblob import TextBlob
from flask import Flask, request, render_template
import pandas as pd
import string
import json
from textblob.np_extractors import ConllExtractor
from flask_jsonpify import jsonpify
from multiprocessing import Pool
import scipy.sparse as sp
import numpy as np
import pickle
import swifter


app = Flask(__name__)

def readData(path):
    # Read NPZ and Transform to Datafram. Single Question Responses. Sample is on 51 Records
    return pd.read_csv(path)
  
def loadSpacyModel(ModelName):
    return spacy.load(ModelName)

def Dataframe2JsonObject(dataframe):
#     df_list = dataframe.values.tolist()
#     JSONP_data = jsonpify(df_list)
#     return JSONP_data
    return dataframe.to_json(orient='records')

def getSimilarity_topic(eachValue):
  SimilarityDict = {}
  SimilarityList = []
  for eachTopic in TopicList:
    try:
      SimilarityValue = float("{0:.2f}".format(nlp(eachValue).similarity(nlp(eachTopic))))
      if SimilarityValue > 0.90 and SimilarityValue < 1:
        StrengthValue = float("{0:.2f}".format(ImportantTopicsDF.loc[ImportantTopicsDF['ImportantTopic'] == eachTopic]['Strength%'].values[0]))
        SentimentValue = float("{0:.2f}".format(TextBlob(eachTopic).sentiment.polarity))
        SimilarityList.append([(eachTopic,SimilarityValue), ('Strength', StrengthValue ), ('sentiment', SentimentValue) ])
    except:
      SimilarityList =[]
  SimilarityDict[eachValue] = SimilarityList
#   print (SimilarityDict)
  return SimilarityDict

def parallelize(data, func):
#     a,b,c,d,e,f,g,h,i,j = np.array_split(data, num_partitions)
    a = np.array_split(data, num_partitions)
    pool = Pool(num_cores)
#     df = pd.concat(pool.map(func, [a,b,c,d,e,f,g,h,i,j ]))
    df = sp.vstack(pool.map(func, a), format='csr')
    pool.close()
    pool.join()
    return df
  
def ParallelizeDFOperation(ImportantTopicsDF):
  ImportantTopicsDF['TopicSimilarity'] = ImportantTopicsDF['ImportantTopic'].apply(getSimilarity_topic)
  return ImportantTopicsDF

def callParallelDFOperationFunction():
  return ParallelizeDFOperation(ImportantTopicsDF)

def getTopicList(PicklePath):
  with open(PicklePath, "rb") as f:
    return pickle.load(f)

@app.route('/')
def SurveyAnalysis():
    
    global TopicList
    TopicList = getTopicList("TopicListDump.dat")
    global ImportantTopicsDF
    ImportantTopicsDF = readData('ImportantTopicsDF.csv')
    
    global nlp
    ModelName = 'en_core_web_md'
    
    global num_partitions
    num_partitions = 4
    global num_cores
    
    global ParallelizeDFOperation
    num_cores = multiprocessing.cpu_count()
    data = parallelize(ImportantTopicsDF, ParallelizeDFOperation)
    
    
    return Dataframe2JsonObject(data)

if __name__ == '__main__':
    # nlp = spacy.load("en_core_web_sm")
    app.run(threaded=True)

# import threading
# threading.Thread(target=app.run, kwargs={'host':'0.0.0.0','port':80}).start()
# Out:
# Overwriting server_similarity.py

# %% [markdown]
# ## MultiProcess Server Run

# %%
import os
import subprocess
import sys
import time
import socket
# Start a subprocess that runs the Flask server
p = subprocess.Popen([sys.executable, "-m", "flask", "run"], env=dict(**os.environ, FLASK_APP="server_similarity.py"), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Start two subthreads that forward the output from the Flask server to the output of the Jupyter notebook
def forward(i, o):
    while p.poll() is None:
        l = i.readline().decode('utf-8')
        if l:
            o.write("[SERVER] " + l)

import threading
threading.Thread(target=forward, args=(p.stdout, sys.stdout)).start()
threading.Thread(target=forward, args=(p.stderr, sys.stderr)).start()
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))
# sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# Let's give the server a bit of time to make sure it has started
time.sleep(2)
# Out:
# 172.28.0.2
# [SERVER]  * Serving Flask app "server_similarity.py"
# [SERVER]  * Environment: production
# [SERVER]    WARNING: Do not use the development server in a production environment.
# [SERVER]    Use a production WSGI server instead.
# [SERVER]  * Debug mode: off
# [SERVER]  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ## Request

# %%
import requests
# r = requests.get("http://172.28.0.2/")
r = requests.get(" http://127.0.0.1:5000/")
print(r.status_code)
print(r.encoding)
print(r.apparent_encoding)
print(r.text)
# Out:
# [SERVER] 172.28.0.2
# 500
# ISO-8859-1
# ascii
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>500 Internal Server Error</title>
# <h1>Internal Server Error</h1>
# <p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>
# [SERVER] [2019-04-18 11:08:49,694] ERROR in app: Exception on / [GET]
# [SERVER] Traceback (most recent call last):
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 2292, in wsgi_app
# [SERVER]     response = self.full_dispatch_request()
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1815, in full_dispatch_request
# [SERVER]     rv = self.handle_user_exception(e)
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1718, in handle_user_exception
# [SERVER]     reraise(exc_type, exc_value, tb)
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/flask/_compat.py", line 35, in reraise
# [SERVER]     raise value
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1813, in full_dispatch_request
# [SERVER]     rv = self.dispatch_request()
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/flask/app.py", line 1799, in dispatch_request
# [SERVER]     return self.view_functions[rule.endpoint](**req.view_args)
# [SERVER]   File "/content/server_similarity.py", line 98, in SurveyAnalysis
# [SERVER]     data = parallelize(ImportantTopicsDF, ParallelizeDFOperation)
# [SERVER]   File "/content/server_similarity.py", line 65, in parallelize
# [SERVER]     df = sp.vstack(pool.map(func, a), format='csr')
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/scipy/sparse/construct.py", line 499, in vstack
# [SERVER]     return bmat([[b] for b in blocks], format=format, dtype=dtype)
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/scipy/sparse/construct.py", line 545, in bmat
# [SERVER]     blocks = np.asarray(blocks, dtype='object')
# [SERVER]   File "/usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py", line 538, in asarray
# [SERVER]     return array(a, dtype, copy=False, order=order)
# [SERVER] ValueError: cannot copy sequence with size 38 to array axis with dimension 9
# [SERVER] 127.0.0.1 - - [18/Apr/2019 11:08:49] "GET / HTTP/1.1" 500 -

# %% [markdown]
# ## Request 2 Dataframe

# %% [markdown]
# ## Kill Port

# %%
# !ps -fA | grep python
# Out:
# root          32      22  0 06:16 ?        00:00:05 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --MappingKernelManager.root_dir="/content"
# root         137      32  0 06:17 ?        00:00:24 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-aba16ff0-59c5-4cb7-a7a7-7d72427bcc62.json
# root         284     137  0 06:23 ?        00:00:00 /usr/bin/python3 -Wignore:::pip._internal.cli.base_command -c from multiprocessing.semaphore_tracker import main;main(56)
# root         594     137  0 07:38 ?        00:00:00 /bin/bash -c ps -fA | grep python
# root         596     594  0 07:38 ?        00:00:00 grep python

# %%
# !kill 563

# %% [markdown]
# # Experimental Codes

# %%
InportantTopicsDF.to_csv("InportantTopicsDF.csv")

# %%
InportantTopicsDF.head(5)
# Out:
#                    index  TotalCountAllAnswer  Strength%
# 22      spicy taste good                   67  16.301703
# 17     savory taste good                   60  14.598540
# 11       sour taste good                   49  11.922141
# 10  sweetness taste good                   41   9.975669
# 14       viscositys good                   34   8.272506

# %%
InportantTopicsDF

# %%
## For each Entity; groupby and then give sentiment ; taste - good(10), bad(2), strong(2)   -> Sentiment

# %%
flat_list = [item for sublist in list(data['Topics']) for item in sublist]

# %%
len(flat_list)
# Out:
# 1043

# %%
len(set(flat_list))
# Out:
# 342

# %%
import collections
counter=collections.Counter(flat_list)
print(counter)
# Out:
# Counter({'spicy taste good': 67, 'savory taste good': 60, 'sour taste good': 49, 'sweetness taste good': 41, 'viscositys good': 34, 'salty taste good': 30, 'chilli smells strong': 26, 'spicy taste': 23, 'garlic taste good': 20, 'textures soft': 19, 'garlic taste': 17, 'garlic smells': 16, 'chilli smells good': 16, 'salty taste': 14, 'spicy taste strong': 14, 'sour taste': 13, 'garlic smells good': 11, 'garlic smells strong': 9, 'garlic smell': 7, 'little bit': 7, 'real chilli': 6, 'chilli smells strong good': 6, 'colour need': 6, 'light red': 5, 'colour needs': 5, 'viscosity isnt good enough': 5, 'garlic taste strong': 4, 'light red colour': 4, 'red colour': 4, 'vicositys good': 4, 'sauce smells good': 4, 'sour sweet': 4, 'spicy stays long': 4, 'savory taste': 4, 'feel nauseous': 3, 'garlic smell strong': 3, 'chilli smell fresh': 3, 'light red colours attractive': 3, 'appearance colours bright': 3, 'tastes unique': 3, 'light colour': 3, 'sweetness taste strong': 3, 'taste good': 3, 'colours bright': 3, 'appearance colours light red': 3, 'chilli taste strong': 3, 'chilli taste real': 3, 'sour sweet taste good': 3, 'sweetness taste': 3, 'viscosity added': 3, 'sauce need': 3, 'viscosity need': 3, 'sweetness need': 3, 'bit watery': 3, 'bit sour': 3, 'spicy tatse good': 2, 'colours nice': 2, 'salty sour sweet': 2, 'sauces soft': 2, 'salty sweet': 2, 'sauce taste strong': 2, 'texture isnt': 2, 'real chilli smells strong': 2, 'doesnt sting': 2, 'savory taste good overall': 2, 'really good': 2, 'chilli smells natural': 2, 'chilli smells fresh': 2, 'real chilli taste strong': 2, 'savory sweetness': 2, 'savory taste strong': 2, 'chilli smells': 2, 'chilli taste good': 2, 'spicys strong': 2, 'spicy sour': 2, 'garlics good': 2, 'sauce taste good': 2, 'chilli sauce': 2, 'bright enough': 2, 'sauce isnt spicy enough': 2, 'teh spicy taste good': 2, 'looks fresh': 2, 'soups appearance': 2, 'real chilli smells good': 2, 'spicy taste like': 2, 'taste spicy': 2, 'smells good': 2, 'dark colour': 2, 'darker need': 2, 'spicy taste reduce': 2, 'garlic need': 2, 'savoury taste': 2, 'spicy taste need': 2, 'sour need': 2, 'garlic smell need': 2, 'texture need': 2, 'garlic taste need': 2, 'viscosity needs': 2, 'liitle bit': 2, 'dont really like': 2, 'good enough doesnt make': 1, 'savoury taste us enough': 1, 'garlic taste strong savory': 1, 'sauce smells good good': 1, 'sour spicy taste': 1, 'fried rice': 1, 'savory salty taste good': 1, 'spicy sauce taste strong': 1, 'sauces attractive': 1, 'light appearance colours good': 1, 'sauce colours bright': 1, 'sauces light redthe garlic': 1, 'spicy sauce taste good': 1, 'real chilli taste good': 1, 'chilli smell strong': 1, 'sauces bright make': 1, 'chilli smell strong good': 1, 'saty taste good': 1, 'garlic taste goodthe chilli': 1, 'still strong': 1, 'soursweet savory': 1, 'spicy taste strong good': 1, 'chilli smells realthe taste': 1, 'viscosity taste good': 1, 'looks good': 1, 'sour taste strong': 1, 'sauce isnt watery good': 1, 'sauce looks bright': 1, 'garlisk smells strong': 1, 'softnesss good': 1, 'goodthe colour': 1, 'colours dark red': 1, 'spicy sensations statisfied': 1, 'spicy savory': 1, 'spicy smells good': 1, 'savoryy taste good': 1, 'savory taste good soft': 1, 'colour isnt pale': 1, 'sweetness taste good soft': 1, 'colours thick': 1, 'chilli smells good strong': 1, 'spicy taste good fresh': 1, 'textures softt': 1, 'viscositys thick': 1, 'sour taste strong overall': 1, 'sauce looks modern': 1, 'sweettness taste good': 1, 'chilli taste fresh': 1, 'bit strong': 1, 'smells fresh': 1, 'light red colours good': 1, 'spicy taste delicious': 1, 'garlic taste savory': 1, 'viscosity taste good soft': 1, 'swetness taste good': 1, 'lumpy good': 1, 'appearances colours bright': 1, 'garlic taste good delicious': 1, 'sauces colours bright': 1, 'sour salty': 1, 'sauces colours light red': 1, 'salty sour sweetness': 1, 'viscosityys good': 1, 'sweetness savory': 1, 'chilli tomato': 1, 'sppearances bright': 1, 'g ...

# %%
df = pd.DataFrame.from_dict(counter, orient='index').reset_index()
df = df.sort_values(by=[0], ascending=False)

# %%
df.head(20)
# Out:
#                     index   0
# 22       spicy taste good  67
# 17      savory taste good  60
# 11        sour taste good  49
# 10   sweetness taste good  41
# 14        viscositys good  34
# 34       salty taste good  30
# 2    chilli smells strong  26
# 3             spicy taste  23
# 18      garlic taste good  20
# 20          textures soft  19
# 88           garlic taste  17
# 19          garlic smells  16
# 35     chilli smells good  16
# 5             salty taste  14
# 16     spicy taste strong  14
# 4              sour taste  13
# 111    garlic smells good  11
# 29   garlic smells strong   9
# 323            little bit   7
# 6            garlic smell   7

# %%
import string
nlp = spacy.load("en_core_web_lg")
import itertools
for a, b in itertools.combinations(set(flat_list), 2):
  a = a.translate(str.maketrans('', '', string.punctuation))
  b = b.translate(str.maketrans('', '', string.punctuation))
  doc1 = nlp(a)
  doc2 = nlp(b)
  if (doc1.similarity(doc2)) > 0.90:
    print (doc1.similarity(doc2), "--", a, "----", b)
# Out:
# 0.9398877440476473 -- soup needs ---- soup need
# 0.9097327742899014 -- real chilli smells good ---- chilli smells need
# 0.9468863610712461 -- real chilli smells good ---- real chilli smells fresh
# 0.9084437126782787 -- real chilli smells good ---- real chilli taste strong
# 0.9093422154720056 -- real chilli smells good ---- chilli taste real
# 0.9204865486419873 -- real chilli smells good ---- chilli smell strong good
# 0.9381872755771946 -- real chilli smells good ---- chilli smells strong good
# 0.962028227751544 -- real chilli smells good ---- real chilli smells strong
# 0.91712002401567 -- real chilli smells good ---- sauce smells good good
# 0.9661184575054693 -- real chilli smells good ---- real chilli smells
# 0.946597454450995 -- real chilli smells good ---- real chilli taste good
# 0.938187274397767 -- real chilli smells good ---- chilli smells good strong
# 0.9053381403485958 -- real chilli smells good ---- smells like chilli
# 0.9661183835609269 -- real chilli smells good ---- chilli smells real
# 0.9519456239993025 -- real chilli smells good ---- chilli smells good
# 0.9093422199381579 -- real chilli smells good ---- real chilli taste
# 0.901625130216512 -- real chilli smells good ---- sauce smells good
# 0.9221583097385623 -- chilli taste good ---- real chilli taste strong
# 0.9079288103453395 -- chilli taste good ---- garlic taste strong good
# 0.9395650298439004 -- chilli taste good ---- chilli taste real
# 0.9060440771223045 -- chilli taste good ---- sour taste good
# 0.9285887518877113 -- chilli taste good ---- tomato taste good
# 0.9026185951832396 -- chilli taste good ---- chilli smell strong good
# 0.9009003239660023 -- chilli taste good ---- chilli smells strong good
# 0.9493388175727624 -- chilli taste good ---- chilli taste strong
# 0.9118110841179178 -- chilli taste good ---- spicy taste good enough
# 0.9068500911641242 -- chilli taste good ---- chilli smells realthe taste
# 0.9083814279526901 -- chilli taste good ---- spicy taste good like
# 0.9579225029251167 -- chilli taste good ---- real chilli taste good
# 0.935107407564285 -- chilli taste good ---- garlic taste good
# 0.9009003228334495 -- chilli taste good ---- chilli smells good strong
# 0.9258949905841274 -- chilli taste good ---- spicy taste good
# 0.9473252754728392 -- chilli taste good ---- chilli taste
# 0.9351073818127753 -- chilli taste good ---- goodthe garlic taste good
# 0.9199991236290245 -- chilli taste good ---- chilli smells good
# 0.9250880298086703 -- chilli taste good ---- spicy sauce taste good
# 0.9159133028467955 -- chilli taste good ---- spicy chilli taste
# 0.9159133436999928 -- chilli taste good ---- chilli taste spicy
# 0.9206949740495026 -- chilli taste good ---- chilli taste real garlic
# 0.9395650344584894 -- chilli taste good ---- real chilli taste
# 0.9333048882204026 -- chilli taste good ---- chilli sauce taste like
# 0.9339739426015086 -- chilli taste good ---- chilli taste fresh
# 0.9334244384856091 -- chilli taste good ---- sauce taste good
# 0.9137370829634219 -- chilli taste good ---- spicy taste good fresh
# 0.9211857729062242 -- chilli taste good ---- garlic taste good delicious
# 0.9217179537484682 -- spicy smells naturally fresh ---- spicy smells good
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-36abe93e316c> in <module>()
#       5   a = a.translate(str.maketrans('', '', string.punctuation))
#       6   b = b.translate(str.maketrans('', '', string.punctuation))
# ----> 7   doc1 = nlp(a)
#       8   doc2 = nlp(b)
#       9   if (doc1.similarity(doc2)) > 0.90:
#
# /usr/local/lib/python3.6/dist-packages/spacy/language.py in __call__(self, text, disable)
#     344             if not hasattr(proc, '__call__'):
#     345                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 346             doc = proc(doc)
#     347             if doc is None:
#     348                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# /usr/local/lib/python3.6/dist-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /usr/local/lib/python3.6/dist-packages/thinc/api.py in begin_update(seqs_in, drop)
#     278         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
#     279         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad),
# --> 280                                          drop=drop)
#     281         if bp_layer is None:
#     282             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# /usr/local/lib/python3.6/dist-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /usr/local/lib/python3.6/dist-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      16
#      17     def begin_update(self, X, drop=0.):
# ---> 18         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      19         output = X+y
#      20         def residual_bwd(d_output, sgd=None):
#
# /usr/local/lib/python3.6/dist-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# /usr/local/lib/python3.6/dist-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      49
#      50     def begin_update(self, X, drop=0.):
# ---> 51         X, backprop_child = self.child.begin_update(X, drop=0.)
#      52         N, mu, var = _get_moments(self.ops, X)
#      53
#
# /usr/local/lib/python3.6/dist-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      67         W = self.W.reshape((self.nO * self.nP, self.nI))
#      68         drop *= self.drop_factor
# ---> 69         output__boc = self.ops.batch_dot(X__bi, W)
#      70         output__boc += self.b.reshape((self.nO*self.nP,))
#      71         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
import os
import subprocess
import sys
import time
import socket
# Start a subprocess that runs the Flask server
p = subprocess.Popen([sys.executable, "-m", "flask", "run"], env=dict(**os.environ, FLASK_APP="server.py"), stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Start two subthreads that forward the output from the Flask server to the output of the Jupyter notebook
def forward(i, o):
    while p.poll() is None:
        l = i.readline().decode('utf-8')
        if l:
            o.write("[SERVER] " + l)

import threading
threading.Thread(target=forward, args=(p.stdout, sys.stdout)).start()
threading.Thread(target=forward, args=(p.stderr, sys.stderr)).start()
import socket
print(socket.gethostbyname(socket.getfqdn(socket.gethostname())))
# sock.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# Let's give the server a bit of time to make sure it has started
time.sleep(2)

# %%
# reduce the dark colour of the sauce// need to be more spicy// the texture of the sauce need to be softer

import spacy

nlp = spacy.load("en_core_web_lg")
doc = nlp(u"reduce the dark colour of the sauce// need to be more spicy// the texture of the sauce need to be softer")

# %%
for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# reduce reduce VERB VB ROOT xxxx True False
# the the DET DT det xxx True False
# dark dark ADJ JJ amod xxxx True False
# colour colour NOUN NN dobj xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# sauce// sauce// NOUN NN pobj xxxx// False False
# need need VERB VBP dobj xxxx True False
# to to PART TO aux xx True False
# be be VERB VB xcomp xx True False
# more more ADJ JJR advmod xxxx True False
# spicy// spicy// ADP IN attr xxxx// False False
# the the DET DT det xxx True False
# texture texture NOUN NN attr xxxx True False
# of of ADP IN prep xx True False
# the the DET DT det xxx True False
# sauce sauce NOUN NN pobj xxxx True False
# need need VERB VBP dep xxxx True False
# to to PART TO aux xx True False
# be be VERB VB xcomp xx True False
# softer soft ADJ JJR acomp xxxx True False

# %%
noun_adj_pairs = []
for i,token in enumerate(doc):
    if token.pos_ not in ('NOUN','PROPN','VERB'):
        continue
    for j in range(i+1,len(doc)):
        if doc[j].pos_ == 'ADJ':
            noun_adj_pairs.append((token,doc[j]))
            break
noun_adj_pairs
# Out:
# [(reduce, dark),
#  (colour, more),
#  (sauce//, more),
#  (need, more),
#  (be, more),
#  (texture, softer),
#  (sauce, softer),
#  (need, softer),
#  (be, softer)]

# %%
data.columns
# Out:
# Index(['D3a', 'Translate', 'Topics', 'NounAdjectivePair', 'CleanTranslate'], dtype='object')

# %%
NounAdjectivePair = [item for sublist in list(data['NounAdjectivePair']) for item in sublist]

# %%
len(NounAdjectivePair)
# Out:
# 2048

# %%
NounAdjectivePair[0:20]
# Out:
# [('taste', 'enough'),
#  ('is', 'enough'),
#  ('taste', 'enough'),
#  ('is', 'enough'),
#  ('taste', 'sour'),
#  ('taste', 'enough'),
#  ('is', 'enough'),
#  ('sweetness', 'enough'),
#  ('is', 'enough'),
#  ('viscosity', 'enough'),
#  ('is', 'enough'),
#  ('colour', 'bright'),
#  ('is', 'bright'),
#  ('expected', 'good'),
#  ('taste', 'good'),
#  ('is', 'good'),
#  ('does', 'nauseous'),
#  ('make', 'nauseous'),
#  ('feel', 'nauseous'),
#  ('garlic', 'strong')]

# %%
len(list(set(NounAdjectivePair)))
# Out:
# 562

# %%
from collections import Counter

counts = Counter((NounAdjectivePair))
print(counts)
# Out:
# Counter({('taste', 'good'): 285, ('taste', 'strong'): 85, ('chilli', 'strong'): 55, ('smells', 'strong'): 55, ('sweetness', 'good'): 47, ('smells', 'good'): 47, ('garlic', 'strong'): 44, ('chilli', 'good'): 37, ('viscositys', 'good'): 35, ('is', 'good'): 34, ('are', 'good'): 29, ('is', 'strong'): 28, ('garlic', 'good'): 24, ('textures', 'soft'): 18, ('spicy', 'good'): 17, ('taste', 'sour'): 16, ('smell', 'strong'): 15, ('texture', 'soft'): 15, ('garlic', 'sour'): 15, ('viscosity', 'good'): 14, ('colour', 'bright'): 13, ('sauce', 'good'): 13, ('is', 'bright'): 12, ('is', 'soft'): 12, ('colours', 'bright'): 12, ('garlic', 'spicy'): 12, ('taste', 'spicy'): 12, ('sweetness', 'savory'): 12, ('smell', 'good'): 12, ('sweetness', 'sour'): 11, ('chilli', 'fresh'): 10, ('taste', 'garlic'): 10, ('chilli', 'sour'): 10, ('taste', 'real'): 10, ('good', 'good'): 9, ('spicy', 'strong'): 9, ('good', 'strong'): 9, ('are', 'strong'): 9, ('colour', 'good'): 8, ('is', 'light'): 8, ('be', 'darker'): 8, ('added', 'little'): 8, ('need', 'little'): 8, ('colour', 'attractive'): 7, ('is', 'attractive'): 7, ('is', 'watery'): 7, ('sauce', 'soft'): 7, ('light', 'red'): 7, ('is', 'spicy'): 7, ('taste', 'sweet'): 7, ('colour', 'darker'): 7, ('is', 'enough'): 6, ('does', 'nauseous'): 6, ('make', 'nauseous'): 6, ('feel', 'nauseous'): 6, ('smell', 'fresh'): 6, ('colours', 'attractive'): 6, ('sauce', 'bright'): 6, ('appearance', 'bright'): 6, ('sweetness', 'salty'): 6, ('smells', 'fresh'): 6, ('colours', 'red'): 6, ('colour', 'dark'): 6, ('is', 'dark'): 6, ('taste', 'enough'): 5, ('sauce', 'strong'): 5, ('taste', 'savory'): 5, ('looks', 'good'): 5, ('mouth', 'good'): 5, ('viscosity', 'watery'): 5, ('spicy', 'sour'): 5, ('smells', 'sour'): 5, ('garlic', 'real'): 5, ('chilli', 'real'): 5, ('sauce', 'spicy'): 5, ('colour', 'light'): 5, ('smell', 'sour'): 5, ('colour', 'red'): 5, ('be', 'spicy'): 5, ('need', 'darker'): 5, ('viscosity', 'little'): 5, ('colours', 'good'): 4, ('spicy', 'real'): 4, ('texture', 'rough'): 4, ('is', 'rough'): 4, ('sweetness', 'strong'): 4, ('be', 'red'): 4, ('sauce', 'light'): 4, ('are', 'enough'): 4, ('reduce', 'sour'): 4, ('smell', 'garlic'): 4, ('need', 'softer'): 4, ('be', 'softer'): 4, ('added', 'salty'): 4, ('taste', 'little'): 4, ('need', 'sour'): 4, ('colours', 'nice'): 3, ('garlic', 'savory'): 3, ('sauces', 'bright'): 3, ('sauce', 'attractive'): 3, ('tastes', 'unique'): 3, ('looks', 'bright'): 3, ('viscositys', 'strong'): 3, ('taste', 'its'): 3, ('good', 'sour'): 3, ('chilli', 'spicy'): 3, ('taste', 'salty'): 3, ('spicy', 'salty'): 3, ('chillis', 'strong'): 3, ('colour', 'nice'): 3, ('spicy', 'spicy'): 3, ('looks', 'fresh'): 3, ('is', 'interesting'): 3, ('taste', 'that'): 3, ('smell', 'spicy'): 3, ('is', 'red'): 3, ('need', 'brighter'): 3, ('added', 'spicy'): 3, ('added', 'sour'): 3, ('texture', 'softer'): 3, ('need', 'salty'): 3, ('bit', 'salty'): 3, ('needs', 'darker'): 3, ('sauce', 'dark'): 3, ('bit', 'watery'): 3, ('bit', 'sour'): 3, ('tatse', 'good'): 2, ('appearance', 'good'): 2, ('sweet', 'savory'): 2, ('sauces', 'soft'): 2, ('mouth', 'spicy'): 2, ('saty', 'good'): 2, ('appearance', 'attractive'): 2, ('good', 'savory'): 2, ('mouth', 'unique'): 2, ('sauce', 'watery'): 2, ('colour', 'pale'): 2, ('textures', 'good'): 2, ('taste', 'fresh'): 2, ('bit', 'strong'): 2, ('chilli', 'natural'): 2, ('smells', 'natural'): 2, ('smells', 'unique'): 2, ('taste', 'lumpy'): 2, ('good', 'lumpy'): 2, ('taste', 'bright'): 2, ('good', 'bright'): 2, ('good', 'garlic'): 2, ('seasoning', 'good'): 2, ('tomato', 'good'): 2, ('mouth', 'savory'): 2, ('sting', 'light'): 2, ('smells', 'real'): 2, ('spicys', 'strong'): 2, ('spicy', 'fresh'): 2, ('taste', 'soft'): 2, ('smell', 'soft'): 2, ('garlic', 'soft'): 2, ('garlics', 'good'): 2, ('is', 'nice'): 2, ('spicy', 'garlic'): 2, ('be', 'strong'): 2, ('sauces', 'good'): 2, ('food', 'unique'): 2, ('feel', 'fresh'): 2, ('sweetness', 'tasteful'): 2, ('mouth', 'fresh'): 2, ('mouth', 'sour'): 2, ('looks', 'spicy') ...

# %%
df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
df = df.sort_values(by=[0], ascending=False)

# %%
df
# Out:
#                     index    0
# 8           (taste, good)  285
# 22        (taste, strong)   85
# 16       (smells, strong)   55
# 15       (chilli, strong)   55
# 19      (sweetness, good)   47
# 32         (smells, good)   47
# 13       (garlic, strong)   44
# 41         (chilli, good)   37
# 23     (viscositys, good)   35
# 9              (is, good)   34
# 73            (are, good)   29
# 63           (is, strong)   28
# 72         (garlic, good)   24
# 27       (textures, soft)   18
# 17          (spicy, good)   17
# 2           (taste, sour)   16
# 14        (smell, strong)   15
# 158        (garlic, sour)   15
# 24        (texture, soft)   15
# 66      (viscosity, good)   14
# 31          (sauce, good)   13
# 5        (colour, bright)   13
# 143   (sweetness, savory)   12
# 198         (smell, good)   12
# 43      (colours, bright)   12
# 44        (garlic, spicy)   12
# 25             (is, soft)   12
# 82         (taste, spicy)   12
# 6            (is, bright)   12
# 161     (sweetness, sour)   11
# ..                    ...  ...
# 226         (sting, good)    1
# 225        (light, spicy)    1
# 224      (colours, spicy)    1
# 223            (s, spicy)    1
# 247            (can, red)    1
# 250    (appearances, red)    1
# 286   (vicositys, strong)    1
# 251          (is, savory)    1
# 285      (sweetess, good)    1
# 284      (blends, unique)    1
# 283   (dissolves, unique)    1
# 282       (stays, strong)    1
# 280    (sensation, fresh)    1
# 278        (feels, fresh)    1
# 277  (dissolves, natural)    1
# 275          (soups, red)    1
# 274        (soup, bright)    1
# 271     (vicositys, good)    1
# 269       (is, addictive)    1
# 268    (spicy, addictive)    1
# 266         (make, spicy)    1
# 263    (tomatoes, chilly)    1
# 261         (feels, good)    1
# 259     (good, lumpysoft)    1
# 258    (taste, lumpysoft)    1
# 257       (are, tasteful)    1
# 254          (soup, nice)    1
# 253          (soft, nice)    1
# 252      (textures, nice)    1
# 561         (be, lighter)    1
#
# [562 rows x 2 columns]

# %%
import string
nlp = spacy.load("en_core_web_lg")
import itertools
for a, b in itertools.combinations(set(NounAdjectivePair), 2):
  doc1 = nlp(" ".join(list(a)))
  doc2 = nlp(" ".join(list(b)))
  if (doc1.similarity(doc2)) > 0.90:
    print (doc1.similarity(doc2), "--", a, "----", b)
# Out:
# 0.9365073991899543 -- ('need', 'darker') ---- ('needs', 'darker')
# 0.9082355172906906 -- ('need', 'darker') ---- ('be', 'darker')
# 0.938455445932055 -- ('good', 'garlic') ---- ('garlic', 'enough')
# 0.9051077355808526 -- ('good', 'garlic') ---- ('garlic', 'strong')
# 1.0000000005207719 -- ('good', 'garlic') ---- ('garlic', 'good')
# 0.9101404422584927 -- ('good', 'garlic') ---- ('need', 'garlic')
# 0.9022057605549657 -- ('good', 'garlic') ---- ('be', 'garlic')
# 0.932361584062914 -- ('be', 'attractive') ---- ('can', 'attractive')
# 0.9182084090068708 -- ('be', 'attractive') ---- ('is', 'attractive')
# 1.0000000440557197 -- ('savory', 'good') ---- ('good', 'savory')
# 0.9277344031312746 -- ('savory', 'good') ---- ('savory', 'enough')
# 0.9403574486073365 -- ('make', 'sour') ---- ('want', 'sour')
# 0.9039130908833113 -- ('make', 'sour') ---- ('good', 'sour')
# 0.9080168541357858 -- ('make', 'sour') ---- ('be', 'sour')
# 0.9039130908833113 -- ('make', 'sour') ---- ('sour', 'good')
# 0.9337268080484242 -- ('make', 'sour') ---- ('need', 'sour')
# 0.9064014718372585 -- ('taste', 'garlic') ---- ('garlic', 'sweet')
# 0.9017444888003527 -- ('taste', 'garlic') ---- ('garlic', 'sipcy')
# 0.9017444888003527 -- ('taste', 'garlic') ---- ('garlic', 'garlic')
# 0.9048519004561696 -- ('taste', 'garlic') ---- ('garlic', 'spicy')
# 0.9017444888003527 -- ('taste', 'garlic') ---- ('garlic', 'stromh')
# 0.9053066605021932 -- ('taste', 'garlic') ---- ('garlic', 'fresh')
# 0.9055519719686794 -- ('taste', 'garlic') ---- ('smell', 'garlic')
# 0.915550330761846 -- ('taste', 'garlic') ---- ('garlic', 'tasty')
# 0.9017444888003527 -- ('taste', 'garlic') ---- ('strongthe', 'garlic')
# 0.9130339155023701 -- ('taste', 'garlic') ---- ('garlic', 'sour')
# 0.9048519004561696 -- ('taste', 'garlic') ---- ('spicy', 'garlic')
# 0.9276750029479882 -- ('spicy', 'spicy') ---- ('spicy', 'sour')
# 0.9229465281233765 -- ('spicy', 'spicy') ---- ('taste', 'spicy')
# 0.9004437039400883 -- ('spicy', 'spicy') ---- ('sweetness', 'spicy')
# 0.9243870940587778 -- ('spicy', 'spicy') ---- ('sauce', 'spicy')
# 1.0000000274018745 -- ('spicy', 'spicy') ---- ('viscositys', 'spicy')
# 0.9140496636672459 -- ('spicy', 'spicy') ---- ('spicy', 'fresh')
# 0.9203548183449999 -- ('spicy', 'spicy') ---- ('chilli', 'spicy')
# 0.9224527988521217 -- ('spicy', 'spicy') ---- ('spicy', 'salty')
# 0.9557042135108831 -- ('smells', 'real') ---- ('smell', 'real')
# 0.9176870925794434 -- ('mouth', 'spicy') ---- ('throat', 'spicy')
# 0.9223947123195098 -- ('mouth', 'spicy') ---- ('tongue', 'spicy')
# 0.9420678631596449 -- ('colour', 'nice') ---- ('colours', 'nice')
# 0.9426741587374271 -- ('colour', 'nice') ---- ('colour', 'good')
# 0.9999999810182733 -- ('garilc', 'salty') ---- ('sweetnes', 'salty')
# 0.9999999810182733 -- ('garilc', 'salty') ---- ('savort', 'salty')
# 0.9030442884059717 -- ('garilc', 'salty') ---- ('taste', 'salty')
# 0.9001321928701924 -- ('garilc', 'salty') ---- ('spicy', 'salty')
# 0.9283726117085204 -- ('reduce', 'garlic') ---- ('reduced', 'garlic')
# 0.9298671709349139 -- ('viscosity', 'enough') ---- ('viscosity', 'good')
# 0.9215876833310064 -- ('viscosity', 'enough') ---- ('viscosity', 'little')
# 0.9185201490598247 -- ('be', 'spicy') ---- ('make', 'spicy')
# 0.959209793037382 -- ('be', 'spicy') ---- ('being', 'spicy')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-167-210a45ac8dc1> in <module>()
#       4 for a, b in itertools.combinations(set(NounAdjectivePair), 2):
#       5   doc1 = nlp(" ".join(list(a)))
# ----> 6   doc2 = nlp(" ".join(list(b)))
#       7   if (doc1.similarity(doc2)) > 0.90:
#       8     print (doc1.similarity(doc2), "--", a, "----", b)
#
# /usr/local/lib/python3.6/dist-packages/spacy/language.py in __call__(self, text, disable)
#     344             if not hasattr(proc, '__call__'):
#     345                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 346             doc = proc(doc)
#     347             if doc is None:
#     348                 raise ValueError(Errors.E005.format(name=name))
#
# KeyboardInterrupt:

# %%
import pickle 

infile = open("data.pickle",'rb')
l = pickle.load(infile)

# %%
l
# Out:
# ['This product so far has not disappointed. My children love to use it and I like the ability to monitor control what content they see with ease.',
#  'great for beginner or experienced person. Bought as a gift and she loves it',
#  'Inexpensive tablet for him to use and learn on, step up from the NABI. He was thrilled with it, learn how to Skype on it already...',
#  "I've had my Fire HD 8 two weeks now and I love it. This tablet is a great value.We are Prime Members and that is where this tablet SHINES. I love being able to easily access all of the Prime content as well as movies you can download and watch laterThis has a 1280/800 screen which has some really nice look to it its nice and crisp and very bright infact it is brighter then the ipad pro costing $900 base model. The build on this fire is INSANELY AWESOME running at only 7.7mm thick and the smooth glossy feel on the back it is really amazing to hold its like the futuristic tab in ur hands.",
#  'I bought this for my grand daughter when she comes over to visit. I set it up with her as the user, entered her age and name and now Amazon makes sure that she only accesses sites and content that are appropriate to her age. Simple to do and she loves the capabilities. I also bought and installed a 64gig SD card which gives this little tablet plenty of storage. For the price I think this tablet is best one out there. You can spend hundreds of dollars more for additional speed and capacity but when it comes to the basics this tablets does everything that most people will ever need at a fraction of the cost.',
#  'This amazon fire 8 inch tablet is the perfect size. I purchased it for my husband so that he has a bigger screen than just his phone. He had gotten me one a few years ago so I knew it would be a good purchase.',
#  'Great for e-reading on the go, nice and light weight, and for the price point given, definitely worth the purchase.',
#  'I gave this as a Christmas gift to my inlaws, husband and uncle. They loved it and how easy they are to use with fantastic features!',
#  'Great as a device to read books. I like that it links with my borrowed library e-books. Switched from another popular tablet brand and I am happy with the choice I made. It took some time to get books from my previous non-Kindle reader, but finally figured out a way!',
#  'I love ordering books and reading them with the reader.',
#  'Not easy for elderly users cease of ads that pop up.',
#  'Excellent product. Easy to use, large screen makes watching movies and reading easier.',
#  'Wanted my father to have his first tablet and this is a very good value. He can watch movies and play a few games. Easy enough for him to use.',
#  'Simply does everything I need. Thank youAnd silk works wonders',
#  'Got it as a present and love the size of the screen',
#  'The kindle is easiest to use, graphics and screen crisp, clear, brilliant colors.',
#  'nice reader. almost perfect for what i want/need. good bargain',
#  'I really like this tablet. I would have given 5 stars but sometimes you have to push start several times after you unlock the screen and it is a little annoying.',
#  'Great video quality lots of fun apps fun for the whole family',
#  'Love love love my kindle fire 8.....this is what my 9 yr old granddaughter said when I bought this for her at Christmas..we have purchased kindled in the past but this one has been the best....love the fact that you can now use a memory card in it...that helps so much when you use it for books...games...music and viedos...thanks',
#  'Excellent tablet with nice screen. I wish Amazon would pre install the play store, this would have been perfect.',
#  'Preloaded with the reading app from Kindle but expandable with other apps. Perfect for travel. Carry your library, games and productivity apps in a small footprint.',
#  'Very happy with this product and easy to use..picture is clear, takes great pictures..',
#  'My grandchildren are home schooled and utilize the tables for many learning apps! They LOVE using them as it makes them feel "so grown up"! The tablets are a great leaning tool and they are receiving many benefits from them!',
#  'Great size, easy to carry for traveling. Need to spend more time Looking into apps for contact manegement, interactive calenders and most important, music storage and use.',
#  'I purchased this when my last tablet died. It meets all basic needs and the price was great.',
#  'Perfect for downloading and reading books !! Perfect size and has a nice, bright screen.',
#  "I was surprised when I learned of the capabilities of this device. Now my husband has more access to his desktop and I am doing things which I couldn't on his device.",
#  'I got it for my son. Its user friendly and durable.',
#  'The visual quality on the Fire 8 HD is amazing. It runs very fast and is easy to use, very durable.',
#  'If your looking for a affordable gift this is it!.',
#  'This is a great tablet for the price, would recommend it to anyone looking for a basic tablet.',
#  'Works great. Love the portability of books. Overall great product',
#  'I am still learning all the things I can do with my new Kindle Fire. It is so much better (lighter in weight and easier to use) than my old tablet.',
#  'Just the right size for reading books and playing some games.',
#  "I love everything about this tablet! The imaging is sharp and clear. It's fast and light weight. Love it!",
#  'Overall a nice product for traveling purposes Value for money',
#  'My children love this table great quality of pictures, excellent camera',
#  'I bought 3 tablets and my family was not disappointed.',
#  'Great tablet fast screen good size never gives me problem',
#  'Bought this for my 87 year old grandmother who wanted to be able to play games and read books from the library. My aunt lives with her and can help her use it so its perfect for that type of user. After playing with It, I would consider it for just about anyone other than a hardcore user that wants the latest and greatest tech. if you are tech saavy, you can do more with these Fire tablets than advertised.',
#  'This is exactly what the person wanted as a gift and she enjoys using it.',
#  'Does all basic functions of a tablet. Hardcore users may want an iPad.',
#  'Works great for a simple tablet. Not a huge fan of the silk browser but it could be worse! I am very happy with my purchase!',
#  "It's fast and easy to use. This is my second kindle fire .",
#  'More flexibility than a Kindle and bigger screen. Like it because I can surf the web and download and read books.',
#  'For the money you cannot beat this tablet. Full of features, picture quality is great, and very fast speed while using the internet.',
#  'Easy to use, solid build, sharp HP screen for movies. Who needs more?',
#  'Tablet is perfect for beginners who just want basic',
#  'this is my first tablet .. love it .. actually read my first e-book on it .. large screen, easy to read & play games .. fits nicely in my purse',
#  'This 8 inch Fire is definitely better than the cheaper 7 inch. It works fine enough for teens to play games and watch movies.',
#  'Great tablet for under $100. Does not have the highest specs, but gets the job done for lite tablet users.',
#  'I purchased the kindle fire because I needed a entertainment only device for long flights. This device is the perfect size for travel and easy to use and set up with your Amazon account. It is worth purchasing a Fire tablet if you are an Amazon Prime member. If not, I would not recommend it because the available apps are limited . My only complaint about this device is that if it freezes it is difficult to reset.',
#  'This fire tablet has long battery life. Reasonable fast',
#  'Got this for my wife and she loves it. She had the previous generation and this one is a giant keep forward.',
#  'Sleek packaging easy set up and great for anyone who wants a e reader with more to offer.',
#  'Best and most affordable option of all the Kindle devices available.',
#  'I did not want to get a new kindle but my old one would not charge or show a charge anymore. I could not depend on it for any length of time so I finally broke down and bought a new one. I am very happy with this one. I was afraid I would lose my music and photos since not all came from the Amazon store. However, everything I had on the old kindle transferred to the new one. I am still learning all about it but so far so good.',
#  'My daughter likes this tablet to play her online games!',
#  'Easy to figure out and used it extensively on my vacation.',
#  "Excellent tablet to leave at my easel and display reference photos. It's light enough to velcro to a articulating stand (so I can position the tablet right next to my canvas). It's cheap enough to not worry about. I love it, for the price.",
#  'I bought this wanting for books comics and movies and it has not disappoint ever since',
#  'My 4 year old Grandson loves his Kindle. He had to have one after his sister got one.',
#  'Easy to use. As a beginner I found this pad very good. Enjoy the kindle app.',
#  'This Kindle does what I need it to do. The camera could be better but overall I am pretty happy with my purchase.',
#  'Purchased this for my daughter to do more reading. It has so much more options for her if she wants.',
#  'this is a great tablet for the price. my kid loves it ,does alot reading on it.',
#  "I was really hoping that this would be faster than some other inexspensive tablets I've had. I mainly use it for email though and it does the job.",
#  "Bought as a Christmas gift for someone. I bought iPad as well. Will update when it's used.",
#  'Great tablet for the price. It is easy to navigate.',
#  'I believe that this will be very useful during my husbands recovery from foot surgery.',
#  'This is something that is useful if your looking for something to take along trips',
#  'This is a wonderful device. I love the extra capabilities and apps.',
#  'Decent tablet. Access to kindle and pretty much all your google apps.',
#  'I am very happy with this tablet. The worst thing is that my steals it all the time. Lol',
#  'A family member has vision problems. They had seen/used the Kindle of another family member - especially the ability to scale text. This device will make it possible to read, which she has had extreme difficulty doing.',
#  'Easy setup and connect to WIFI. Great viewing area. Easy to read in bright places.',
#  'I got this fire for my friend who wants to buy kindle..this serves both Kindle and Tab... very nice and very cheap..worth for what i paid.. I highly recommend this for beginners',
#  'Really enjoyed the price value of this tablet versus ipad',
#  'Amazing tablet with fast processor. It looks great... got good deal',
#  'We got this for our 5 year old and this is really great for the price. Works like a charm!!',
#  'I find it easy to use, but the kindle does not come with instructions, so you have to find your way around.',
#  "I bought this because I was tired of watching Youtube and Twitch on my phone. Excellent display sound is decent-not great but you can always buy a speaker. The negatives are-it is definitely a fingerprint magnet, and the Spectrum TV app is AWFUL-the app works fine on my phone, but for some reason on this tablet it freezes and is unusable. All things considered, for 65 bucks it's hard to be beat.",
#  "I love this tablet. The battery life last a long time. I use my Amazon Kindle Fire predominately for watching movies on Amazon Prime, Netflix's, and checking my emails. I also carry it to my appointments and meetings. It is a compact tablet, and not big and bulky. The playback of the movies are great, and the movies are HD. Great little tablet if you are looking for something to watch movies and checking emails. I would definitely recommend this tablet to friends and family members.",
#  'My daughter loves this kindle, she does so much with it,well worth the money.',
#  'Was looking for a tablet that was highly portable & could run my DIRECTTV app & stream videos. (Other electronics I have are much older versions). Salesman recommended this model to me based on personal experience. I am still learning all its functions but so far it seems easy to use & is doing what it promised to do.',
#  'This is my second Fire, the other one is now retired. I like having HD. Works just fine.',
#  "My wife bought this for me for my birthday. I enjoy reading biographys which usually have color photos. The regular Kindle make the pics black and white or they're aren't any. This allows me to see the color photos. I also love the night feature when I'm in bed reading. I no longer need a light on to read or need to hold a large book.",
#  'Thanks to a knowledgeable, low-pressure salesperson, I was ready to buy my first tablet. This one was the right price (on sale) and I have not been disappointed. Every few days I learn more ways to use it besides checking e-mails & checking out library books & audio books. It stays charged for days, even with regular use. I recommend it as an inexpensive and very satisfactory alternative to more expensive tablets.',
#  "It's a great tablet for the price. Don't expect it to be as fast more expensive ones. It's meant for casual use and it does a great job at that. For the price, you can't beat it. Get a nice large microsd card and you don't have to worry about space. It runs a little slow on certain things if you are multitasking but it's a simple tablet. I've run plenty of 720p videos without fail. It's great for ebooks or other files. Some more elaborate pdfs take a while to load if they have a lol of graphics. Battery life seems good for a small table too.The only real Issue I have is the Amazon App store being limited. It is an offshoot of Android but not all the same apps are available. There is a way around it but I wish they would just allow it access to Google Play or at least offer the same apps.So, it's a nice inexpensive table that works great. For the money, you will love it but don't get upset that is doesn't run as fast as a $500 tablet. That's not its job.",
#  'Bought it for my 10 yr old granddaughter. Does everything she wants it to do in a tablet.',
#  'Very easy to use tablet. Lots of apps and game available.',
#  "We love the FreeTime settings for kids on the newer Kindle Fires. I was able to create a login for each of our kids as well as myself and set limits to the amount of device time they are allowed daily (can set to more for weekends if desired). You can set the age restrictions for content also, to avoid inappropriate ads, etc. Once you've downloaded apps, you can choose which ones you want each child to have access to in their profile settings, so if one child is older you can allow them access to something their younger siblings shouldn't have. Basically, I like that I can set their access rights and know they're safe so I don't have to continually monitor every moment. By the way, FreeTime kids settings are available without having to subscribe to their FreeTime app access plan. :)",
#  'Great tablet, very clear picture. Would buy again.',
#  'Good reader which is why I bought it. Ads are annoying.',
#  "It's a mini computer packed in a handheld devise. Applications load quickly and I am able to get my work completed, while riding the commuter rail.",
#  "Nice for a smaller tablet. It's good for Internet surfing.",
#  'Purchased as a door prize gift given with a one year Amazon membership. The recipient loves it and says it performs very well. (As a past Amazon Fire user, now i-Pad graduate, I loved my Amazon Fire for more than 4 years without any problems. In fact, I just recycled it on to my son and it runs like a champ).',
#  'I have 4 other kinds of tables. This the best I have had. I can listen to music, read a book, listen to a book, or watch movies/tv shows.',
#  'Great product for the kids gaming apps parental controls to make sure you can monitor kids and prevent unwanted app purchases',
#  'I purchased 2 of these tablets for my 6 and 8 year old. They were a Black Friday special for $59. They are perfect for the apps and games they wanted.',
#  'Great product. Love the Amazon ecosystem. The Freetime subscription is a must',
#  'Needed something a bit larger than the 6+ to stream Netflix, this was perfect!',
#  "my husband bought this for me as a Christmas present. I couldn't understand why he bought it because I already have a Kindle Fire.Once I opened it and got it going, I loved all it could do plus the graphic is so much colorful than my older Kindle.",
#  'my grandson-8-loves this --the games and the books!',
#  "Great product and I'm very satisfied with it. I recommend it to other people.",
#  'I purchased this tablet for my niece for Christmas and she love it.',
#  'Easy to use, responds quickly, great screen brightness.',
#  'Great tablet but apps limited comparison of other tablets.',
#  'Works as we thought it should. NO PROBLEMS. Good buying experience.',
#  'We have the smaller one, and been great. This one is even better, because of the size.',
#  'I am a prime member & I love this tablet. Very user friendly especially if you are a prime member with amazon. Not real tech savvy so I need all the help I can get to keep things simple & automatic. Great clarity of picture/data. Have a 10" tablet and wasn\'t sure about downgrading size (old eyes) but was delighted to see it works fine at 8" instead of 10". Also, easier to take around in the smaller size. Highly recommend especially if you subscribe to Amazon and are a prime member. Great benefits!!',
#  'Got this for my wife. She loves the bigger screen and the better app management features that this one has over her earlier generation kindle. Definitely worth it!',
#  'Connects to home WiFi automatically. Many books, and many games. Actually functions like a computer tablet. E-mail is a breeze.',
#  "Bought this to replace no-name budget tablet for my daughter. She loves this as it is much faster and has a better display than her old tablet. This is a wonderful value as it is faster, has a better display and sound, is a name brand and cost about the same ... what's not to love about this product?",
#  'She loves this tablet. It works well unlike her "bargain" tablet which she tried to use previously and cost about the same. She likes the sound of it also! She enjoys the free games she downloaded and navigates the wev easily with it.',
#  "It's no iPad, but it's great for Netflix and some app games. I'm not worried about the kids getting their paws on it since it's relatively inexpensive.",
#  "Didn't have some of the features I was looking for. Returned it the next day. May be good for others",
#  "I bought this for my daughter and she loves it. It's speedy when loading books!",
#  'Purchased for my wife who reads a lot and truly enjoys the amazon fire.',
#  'A great Christmas gift, the kids love the gifts...',
#  'Daughter got this as a present. It was easy to set up and display is great. Features allow us to limit her time on games, web, etc. while allowing her unlimited time to read',
#  "I have enjoyed just learning how to use it. You're never too old to learn new things.",
#  'bought for husband and he was surprised it does the work he needs it for',
#  'This was a birthday present and it was ideal for a traveler to read ebooks on while on the rood',
#  'My teenage daughter enjoyed her three year old 7" Kindle for recreation but wanted a larger screen for word processing. Paired this with a Bluetooth keyboard and she was thrilled.',
#  'i Bought this around black friday for $60 hoping it would be awesome... it failed so hard i tried multiple different micro SD cards none of which were recognized and YES i formated them with every format i could think of ... Fat32, NTFS, Fat, Xfat... i even tried to have the tablet do it... didnt work... to make matters worse half the apps i wanted to use werent in the app store and i came to find out that it isnt linked to the normal google play store this tablet has its own app store which is missing many common apps... the main reason i bought this was to play clash of clans and i cant because it wasnt on the app store... i tried to also use aftermarket play stores to play COC but it didnt work... launched and played 1 time but didnt work or update after that... needless to say i returned it and bought a $250 samsung galaxy tab A 10.1 (2016 version) with S-pen and its WAYYYYY better... bottom line you get what you pay for... also hint the s-pen version has an extra 1 GB of ram over the non pen version... so you should get that if you can afford the extra $50...',
#  'The People I purchased this for during Christmas Holiday LOVED IT...',
#  "I purchased two of these for my kids, ages 12 and 10. Forget the IPod touch. For the price, this tablet can't be beat! They can download games, books and movies for free all included with my Amazon Prime membership. Awesome!!",
#  'my kids enjoy the Fire HD and they love the picture quality',
#  'Bought two of these tablets for my nieces for Christmas after we had originally bought the Amazon fire 7 inch which had a virus after 3 days of purchase and was unable to work good thing we played with it prior to giving as gift do to this being said I was very surprised on how well this tablet has held up to to not so careful 8 years olds playing with it daily we have had no problems screen is big enough for little hands to maneuver and see on was the highlight of there Christmas and still is would definitely recommend it',
#  'Really like the updates this product has in comparison to my first one',
#  'Functionality and ease of use are outstanding right out of the the box. Super clear screen and weight is minimum and is a joy to use.',
#  'This tablet is great for kids and adults who have little to no knowledge of computers. It handles easily and has plenty of storage',
#  'My god sister has been using these for years.What to read more!',
#  'The latest Amazon 8" HD tablet is a very good tablet for the price. The updated processor and extra memory (with expansion slot) allow for very good performance on all that we use this tablet for. Netflix, Hulu, browsing the internet, and doing e-mails all work very smoothly. Would recommend to anyone looking for a very cost effective tablet',
#  'totally worth the money, has all the apps I use on a daily basis!',
#  'Good tablet. Wife loves it and would recommend....',
#  'I use mine mainly for its bigger screen. I do all the same things i do on my phone..but love the big screen. I bought one for eaxh of my nieces too. And they both love theres. Making videos..playing music..reading books. They bith love them! Im happy i got them for all of us. And always reccomend them to my friends for their kids too.',
#  'Amazon Fire HD8 is a great product for the price. I picked it up for $69 during the holiday shopping season. Replacing a 1st gen Samsung Tab 2. This thing is sooo much faster. Perfect size for reading Kindle books , emails, and doing the social media thing.',
#  'It was a good gift for the price and had many features and options',
#  'Not as fancy as the ipad, but a fraction of the cost works well with android system and all apps like on our android phones, cant beat the price',
#  'My kids can play, read, watch movies and much more love it!!!',
#  'Great tablet for reading books, but the bluetooth is hard to get working and there are much better tablets for games and movies',
#  'I love this Kindle!! I am biased I think however I have had 3 previous ones I prefer Kindles to any other tablet',
#  'This is a great tablet for kids. I love that their time on the tablet can be restricted.',
#  'Easy to use. Good size. Great eReader. Not so expensive that I worry about my kids using it.',
#  'This Tablet was purchased for our Grandmother so she could play games and read books on.',
#  'Bought a few of these for Christmas gifts .Everyone is happy !Its a great device for the $$. Low price, and great quality as always from FIRE devices.',
#  'I purchased this item for my husband and he has liked reading Kindle books on it and the other features like Silk, etc. Light little tablet with good features.',
#  'Bought this for our year end holiday party raffle prize pool. Great price and people always have a use for an amazon tablet. Came with Kaspersky for free as well, which is a pretty generous complimentary add on.',
#  "My 6 yr old daughter got this tablet from Santa for Christmas. So far she loves it, a little too much perhaps.. I only use it to manage her account/permissions and so far haven't had any issues with it.. Software and HW not quite as refined as apple iPad products, but what can you expect at the lower price point.",
#  'my opinion its a good option for the cost. Not as great as Apple Ipad, but it costs so much less. Still can get good use',
#  "Has many educational apps I would definitely go into the settings if you're a mother like me who Is a very strict of what your children watch on TV or what games and apps they download I would definitely recommend setting the parental controls before giving it to them. In my personal opinion as a mother I feel it helps by setting the restrictions/content on It helps keep their mind away from the gutter Bcuz most apps and Internet websites have inappropriate sites children should not be watching. We can't control what they put on the Internet but we can control what our children watch and download they stay very occupied on educational apps ,read books most of these apps are free to I also recommend NOT putting a payment method option other than that my kids loved it",
#  'the hd feature is what sold me on this product, along with the fact its a lotmore streamline than the older version that I have',
#  'Very nice for light internet browsing, keeping on top of email, viewing videos, and reading e books, which I like to get free from the library. Good browser, good battery power, fast charge. Very relaxing to sit in a comfy chair and read or browse. Has given me hours of enjoyment and information for a minimal price.',
#  'I bought this for my wife to replace her old Kindle and she loves it. Much easier to read than an iPad and updated features make it a great purchase.',
#  'Great tablet and price. Ordering online easy. Not happy took so long to receive though.',
#  'Best tablet, good price, nice looking. Ordering on line was easy.',
#  "I got this for my mom for Christmas. Every time I visit, she shows me something else she can do with it. I'm so jealous, I hope I get one.",
#  "This is my fourth Kindle...upgrading each time. Mine goes everywhere with me and is used throughout the day. Wouldn't be without it.",
#  'We bought this for our son when he went to college. He is able to upload all of his books and other documents.',
#  'I purchased it for my mother-in-law and she loves it it was easier for her to use and understand',
#  'The Amazon Fire is amazing! Picture clarity and sound are excellent! I highly recommend this tablet! Love it!',
#  'Sharp picture and easy to use. And a fantastic price',
#  'I like this is great I bought it my friend he was pleased abount',
#  'I wanted a low cost but quality tablet and this one is a dream! Easy to navigate and excellent graphics.',
#  'This a great tablet for everyone. Plenty of memory for downloading. Great features all around.',
#  'I own two Nook tablets, another Kindle and a Samsung and this is the best one yet. Excellent battery life. Lets me check emails the Web and with Kindle. books can be switched from reads to listens. Also works better than the Nook with audiobooks.',
#  'I bought this tablet for my 4 year old daughter. Too many advertisements. I would rather pay more and not have a single ad.',
#  'This is a step up from what my son was using. He said it does well and easy to use.',
#  'This is a good tablet for kids who are starting off',
#  "I bought this for my 6 year old and it's perfect. Faster & clearer than older versions.",
#  'Awesome good size large enough for games and photos',
#  'Great gift easy to use and she loves being able to take it anywhere',
#  'I bought this to replace the 7 inch version I lost in the airport. I wanted the bigger screen and the higher resolutions. It is much when loading games in offline mode as well as videos I have downloaded from Amazon Prime to play on the plane when wifi is not available. That was a plus for me. And now that the updated Netflix app allows the same thing, I have plenty of videos. I can also play my .mp4 videos using VLC player that I load to a microSD card. Of course you have wifi and Bluetooth so great for surfing try he net or listening to music. The 8 in screen is perfect for lying in bed and watching my show. I highly recommend this.',
#  'Intuitive user interface, rapid online access through well designed features, light weight, ergonomic buttons for volume and power. Overall a thoroughly well designed, excellent priced device for web browsing and social media.',
#  'PURCHASED THIS WITH A STORE CREDIT AND LIKE IT A LOT. COMPARES WELL WITH MORE EXPENSIVE TABLETS..RECOMMENDED',
#  "great device for the price. good looking screen, quick and efficient. amazon app store isn't that bad either",
#  'Great gift for any age. Wish I bought two. I can do everything on this that I was doing on my ipad',
#  'Great budget tablet for web browsing. Also useful as an MP3 player and ebook reader.',
#  'I got 2 of these for my 8 yr old twins. My 11 yr old has one but this one is better. Perfect way to get them to read',
#  "This is a superb tablet for the price. It doesn't come with the Android operating system. It has Amazon's operating system. The battery last a good long time and apps run very fast. I would recommend this to anyone who wants a tablet.",
#  "My daughter love her new tablet, I use for a few days and it's pretty good",
#  'So very happy with the new kindle ! I highly recommend this product !',
#  'It may be cheap but this is a great tablet and works awesome.',
#  'My wife absolutely loves this tablet. It wad an early Christmas present',
#  'Bought for my 11 year old son and he absolutely loves it.',
#  'I bought this as a Christmas gift for my son. Very easy to use.',
#  'This product is very handy on the go. I can check emails and find work for my truck.',
#  'I am an Amazon Fan. Ive only had Amazon tablets so I cant compare them with any other brand. But, Amazon has great customer service, a lot of great apps. The HD 8 is a great tablet for watching movies, most games, and social media. Its not as good as the Kindle fire hdx. The speakers arent as good, the hdx has more of a surround sound, but the hd 8 is less expensive, has a place for a sims card for extra space, and has an ok front and rear facing camera. Overall its a great tablet for a great price.',
#  "I previously had bought an older model of these tablets for my children. I wasn't to happy with them. But this tablet is great, it has child safety features like wether you would like to have them surf the web to even limiting the amount of hours your child can use it. Very good tablet for what my kids will use it for which is mostly Netflix Hulu and even though there isn't you tube app there are alternate apps that acces you tube.",
#  'Got this tablet for Black Friday. Wow, 16 gigs, great screen, expandable memory, what a deal. Tablet is a must have for Amazon Prime members. It unlocks the door for all those great Prime perks; books, shows, and shopping. Pairs to Alexa. Great screen for books! Buy it already!',
#  'Bought it on black Friday for 60$ .Value for money tablet. It lags at heavy tasks and also apps are reloaded when 2-3 apps are opened at same time. But at this price it is expected. Go for it if budget is <100$.',
#  'overall this is a good tablet. it is best with those who have Prime Amazon and the ability to watch Amazon video. a good price for a good tablet but has limitations based on the operating system. for video watching and basic use a good choice',
#  'I love the size and portability of this. Keeps me in touch and having fun.',
#  "Nice tablet and couldn't beat the Black Friday price",
#  "I'm sorry I didn't buy it sooner! Very easy to use. Love it.",
#  'It feels a bit more rugged than my original Fire tablet, and I believe it is an excellent value.',
#  'Good tablet for basic needs. Screens resolution is pretty good. Mostly using for reading and sometimes for watching movies/shows. Great feature is the possibility to use the card to expand the memory. Good product for great price!',
#  'Bought as a gift for my 86 yr old mom to stalk her kids and grandkids on FB. She mastered it in a few.minutes with minimal instruction. Now I have to watch my posts.',
#  'For a cheaper price this does more than my kindle- love having this tablet',
#  'Had a smaller version. Love the bigger screen. Use this product more than a computer.',
#  'I bought 2 of the kindles for my grandsons. They love them! Had them charged and set up right away. No issues at this point.',
#  'Easy to use bought for our 5 year old, found a case which allows him to keep it safe.',
#  'Great 8 inches tablet with and amazing storage for apps.',
#  "Santa dropped this off for our 4th grader along with expanded memory. he uses it for Netflix and Youtube as well as Minecraft and other Apps. Why spend hundreds on something for basic kids needs? I'm sure this will last him a few years and is well worth the price.",
#  'Got this tablet for my 3 year old son and he can not put it down. It is so much to do. So many learning games. I love this product',
#  'This tablet runs smooth with all amazon apps, the internet runs at a steady frame rate and it had a decent sized screen.',
#  'This is a good device for entertainment and entry level tasks. I think it can do a lot for the price.',
#  'Nice price for the new model with Alexa built in and expandable storage!',
#  'I have enjoyed the new Kindle,however, was extremely disappointed that it does not have an HDMI port like the old version did.',
#  'this product is really awesome for kids to play in all sorts.We can use a strong case and let kids play in it .',
#  'i like the features it has and it is easy to navigate.',
#  'This is perfect my kids to do their school work on and have fun as well.',
#  'Great gift for my dad. Clear picture and easy set up',
#  'Love my kindle! Works better than expected! Kindle is much faster than my old tablet!',
#  "I have never owned a tablet. Wanted an I-Pad like most, but couldn't afford the sticker price. This one fit my needs perfect. I mainly just use it for web surfing and streaming video. No complaints so far! I would recommend this device.",
#  'also great for listening to music and also for movies',
#  'The screen picture is crisp and bright. I will use this tablet for many things.',
#  'small and powerful... great adult toy for a reader',
#  'This was purchased as a Christmas present for my aunt who lives with us. For the price, I thought it would be a good option for her since she doesn\'t want to drop the cash on an iPad.For comparison, the closest thing I have is an 8" insignia tablet with similar screen resolution, storage, and features that was released at the same time. The Fire tablet impresses me! It is more responsive than the existing android tablet I have.This tablet runs FireOS which is Amazon\'s customized version of Android. Typically I do not like custom Android, preferring to have as close to a vanilla system as possible. I am not bothered by that with the Fire. If you need them the parental controls are second to none! The Amazon app store is extensive, although not as extensive as the Google Play store. Still you should be able to find pretty much everything you need there.This is not a flagship device, but performs incredibly for the price. I will most likely be purchasing one soon for myself.',
#  'I was hoping to use Google launcher with this tablet but it is really locked down and you cannot change the launcher or the lock screen. Still cheap and fine for watching movies.',
#  'Great tablet for reading and also surfacing the web, along with your favorite social media apps!',
#  'The price is low because Amazon uses their adds to subsidize the price. The actual tablet works well. The biggest negative is that you can only install apps from the Amazon store. There are many Android Apps available in the google store that are not available in the Amazon store.I primarily use the tablet for bible gateway, dish anywhere, play some games, read the newspaper, and Facebook. In the future I want to try to use it with my local library.',
#  'Screen is very clear and battery last a long time. Very good substitute if you can afford a iPad.',
#  'The tablet works fine. It is responsive with good resolution. It is too tied to Amazon. It requires too many hoops to get apps such as Zinio to work. Until Amazon loosens its grip, I recommend only at a very good price.',
#  'A Great value for the money you can save instead of a Ipad from Apple.',
#  'Fun and reliable. Good quality for the money. Easy to use.',
#  'Great for reading - nice image, easy on the eyes and lightweight.',
#  'Bought this for my 10 year old daughter for Christmas! She LOVES it!!! A great alternative to a pricey iPad Mini!!! She uses it for watching Netflix, YouTube and we use it for homeschool. We are very happy with our purchase!!!',
#  'I got this tablet on sale for my wife and she loves it',
#  'So far so good with the kindle fire hd. still need to play with it to see how to maximize our use.',
#  "We love Kindle Fire, we purchase it for an older couple and it's easy to work.",
#  'The Amazon Fire is a great tablet with awesome graphics. I use it mainly for surfing the web and have had no issues with it.',
#  'Purchased for my nephew for Christmas. Used it everyday. Very good product and screen size is perfect for him.',
#  'Great tablet for the price. My granddaughter loves how user friendly it is.',
#  'got this for my nieces aged 6-13 they loved it and so did their parents really keeps them occupied',
#  "This was a gift for mom. She enjoys that it's easy to use and has good picture and sound quality. The price was also great",
#  'Was wanting a bigger screen, which it is, trying to get use to different applications, so far seems easy.',
#  'The Amazon fire is simply amazing I would not buy anything else.',
#  "Didn't want to go to the sites amazon wanted me to.",
#  "We bought this for our three daughters! Got a kid proof case and added free time for a low monthly fee and couldn't be happier! So much better than worrying about them breaking my phone or iPad!",
#  "I love my Kindle. I won't be without one. I've even bought an extra one, just in case. I believe it's the best tablet on the market.",
#  'Bought one to replace the smaller (non HD) version. Lot faster and picture is noticeably better. Would recommend for anyone not wanting to spend the extra $50 or so on the big names.',
#  "Could not have asked for a better tablet for the money. I wasn't looking for anything extreme. Just wanted it to look nice and do it's job for games and browsing. Well it does that and more. Gave it to our son for Christmas and now I want one myself. We are going to buy another for my mother in law. Lightweight, simple layout. Snappy. Can't go wrong.",
#  'It was a perfect gift for my godson. He loved it! Definitely would recommend this product.',
#  'I can do a lot of things on my Kindle I used to rely on the computer for.',
#  'Excellent resource for children video streaming by Wifi using mobile hotspot with kids.',
#  'The kindle fire tablets are great for the price. They have solid performance in battery life and processing power. The only downside is that the Operating System is a different variation of Android, so there could be some incompatibilities.',
#  'best choice under 100$ in marketamazon is the best!!!',
#  'I really didnt expect how its going to work.but its very good.gifted to my friend',
#  "Bought this as a gift for my mom and this was to replace her original Kindle Fire. She's have had a month now and is loving and no problems with it.",
#  'This was a request from our 7 yr old granddaugter who had always asked her older sister if she could share hers due to we bought this same tablet/size a few yrs earlier. Loved the security/parental control options.Starfall a favorite educational app were told is a must have. Really enjoy Pics/Viber due to their in a different state. Also some games on a time limit. Size and resolution are perfect.',
#  'This is the best device I have found for my e-books. I know it can be used for a lot more, but it is my library in my hand.',
#  "I bought this tablet to be pretty much exclusively an e-reader. It's actually cheaper than most of the kindles. For that limited use, it works fine. I don't think I would want to use it as a general purpose table (too slow!). Makes a fine e-reader though. As for recommending this to a friend, I would, but would make sure they knew what I use it for.",
#  "I bought this as a Christmas present for my sister and she LOVES it. It's easy to use, lightweight and doesn't seem to have a lot of bugs or glitches. It's a good source of entertainment for when she's at work but has down-time. She passes the time reading ebooks, browsing the web and playing games.",
#  'I originally purchased a Kindle paperwhite but returned it the next day and purchased this one. Very easy to read on, watch movies, and listen to music.',
#  'Works well. Easy to use. Battery seems to be good. Would buy again.',
#  "Ticks all the boxes I was looking for at a price I was happy to pay. One caveat that I (or the Best Buy and Geek Squad crews) was unaware of: there is a glitch in the keyboard that prevents it from working properly. Kindle/Amazon are aware of the glitch and will download a third-party keyboard fix to replace the keyboard that's built in to the unit until they are able to fix the problem. I made Geek Squad aware of it and they should know about it now.",
#  'Amazon MayDay functionality is not available and this was unexpected. Other services and functionality as expected',
#  'Perfect tablet to take anywhere you go and lighter than my IPad.',
#  'Easy to use tablet for every day use. Additional apps can help increase productivity for work and daily use.',
#  "This tablet does all I need a tablet to do. Reason why it's my 3rd one.",
#  'Bought this tablet for my fiancée daughter, after getting it home and set up, I decided to keep it for myself. Great screen and works great with my pair of Amazon echos. I love it and highly recommend it.',
#  'This is my first Amazon e-reader-tablet and the second e-reader I have. It is easy to use once you get through the initial hoops. I like the free games and the fact that I new can load books from my computer to the tablet. And one thing, I am not in the market for a tablet but for a bigger e-reader. It is a lot better than the Nook that I have. I love this product',
#  "Bought as a gift for parents who aren't tech savy but were able to use it with ease",
#  "I have Bought several versions of this tablet for my kids over the years and have been ever impressed with it. I first got one for my son, the my oldest daughter to replace her children's tablet, which was worthless, this tablet gives you everything you could want and allows you to control what your kids access on it and even lets you see what they download onto it. if you want to set a time when it shuts off at night you can, when they can play games or use Netflixs you can...great product!",
#  'Great gift for a younger person who wants a tablet',
#  'The fire is great. The size is really nice. Not to big. The clarity is really good.',
#  'This inexpensive tablet does everything I want it to do. I can read my books and magazines and keeps tabs on my kids and grandkids on Facebook. Very easy to use and crystal clear pictures and video.',
#  'Great entry level tablet for kids or anyone that will not be heavily using a tablet. The 16 GB, is too small but can add an SD card. Beware only comes with 6GB of the 16 for your apps. Comes with bunch of preloaded Amazon apps.',
#  'This tablet is great. I loved the color and all the features it has. I will be buying more for my daughters. Great purchase',
#  'What I expected. A better then budget tablet ata good price. Bought for the integration with Alexa and it works well, more info about your Alexa request will show up automatically on the tablet.',
#  "It's a excellent tablet for my kid she downloaded games and watch cartoons",
#  'I was looking for a Good tablet under $100..this delivered..getting used to Amazon apps LOL',
#  'Excellent ratio quality price. Lightweight. Good resolution and easy to use.',
#  "After long review decided to buy the Fire Tablet as a gift for a great frienday. She loves it! It's the perfect size and has all the features she was looking for in a tablet. Happy Birthday!",
#  "Love everything about my Kindle. I'm a long-term Amazon Prime member.",
#  'Great tablet for the price. My father in law likes the easy use of the tablet.',
#  'The Fire is an excellent table for many basic tasks.',
#  'Not a good product short battery life i can only use for 20 minutes',
#  'I was looking for something to read on and this fit the bill for the right price.Great screen clarity, good adjustment too. Works well and the battery life is great. Size is nice too. Big enough for 1 hand if needed.',
#  'This is a great tablet for books, games and web browsing. It is very user friendly, -and I would definitely recommend this product!',
#  'I enjoy to use the reader and like the idea that I can go to the internet from the Kindle.',
#  'I thought that this tablet was junk but it has surpassed my expectations',
#  "I wasn't really expecting much, however I was pleasantly surprised.It feels solid, responsive, screen is good.For the price its a bargain!!",
#  'Good if you want something inexpensive and Will do the minimum very well.',
#  'I like this ipads for my baby and me too,special and super ok thanks byee',
#  'I found it to be very versatile and enjoyable benefiting from a touch screen.',
#  'Ipad killer! A fierce tablet at a convinient price!',
#  'bought as a gift she loves it all kinds of apps easy to use and even easyer with amazon prime',
#  "I bought it as the display for my Echo. Turning on Voicecast routes information to the tablet with the voice reaponse. It'S been exactly what I hoped it would be and the price was right.",
#  'This tablet is exactly what I was looking for to take on trips. The kids can watch their movies and videos, or I can read from my kindle library. Perfect size.',
#  'I bought this as a gift for my son and I know he will love it he has the old kindle fire as likes it a lot',
#  'My mom had an old one, she was so excited to get this one.',
#  'Works great and is fast. Great for reading and internet use',
#  "This Kindle is so overloaded with apps that I will never use. Despite what one of Best Buys' associates said, you cannot remove any of the Amazon apps. The apps take up too much of the memory. I have an I Pad and love but bought this as a backup for work. Unfortunately, it bogs down. I also don't like that Amazon wants access to too much info to set up email, so I won't use this for emails either. I will likely sell it on Craig's List for less than half of what I paid for it.",
#  "Fine for reading, ...haven't used it for anything else yet",
#  "I have been using a Kindle Fire for a couple of years. It was a good tablet, until the screen went black. Best Buy replaced it and I couldn't have been more pleased. I enjoy reading on my Kindle Fire HD more than ever. Try it and you'll buy it!",
#  'A viable substitute for the more expensive I Pad especially for kids wanting a tablet. You can download books, games, email and access the internet. Parental controls are easily enabled.',
#  'blueray is just twhat I was I was looking for great for watching movies thank you',
#  'Love best buy and I shop at Best Buy I always buy my TV for me and my kids I buy my kids tablets at Best Buy Love Best Buy',
#  'Got this for my mom for her birthday, and she absolutely loves it. Great tablet for the price point, good tablet overall.',
#  'I love all of them. I would recommend going to Best Buy and buying a kindle fire before they are sold out!',
# ...
#  "We bought one of these for my daughter to help with her learning. There are so many possibilities with this. It's way cheaper than an Ipad and does basically the same thing.",
#  "I absolutely love my Fire tablet. Great size, lots of space and a great reader. I can't recommend this product enough.",
#  "I like this tablet, its thin, light and easy to use. It's great for kids and adults as well.",
#  "Have been pleased with my purchase of the Fire HD8 as it's video quality is great when viewing ESPN3/Netflix/YouTube Tutorials.The ability to easily load and read my saved textbooks within the Amazon Kindle App is fantastic for a fraction of the price for an IPAD. : )",
#  'The first Fire HD8 we purchased died within 1 week of purchase. We had to go back and exchange it for a new one. Not a good sign so far.',
#  'I I bought this for a friend since she liked mine so much.It is a great way to check emails and read Kindle e-Books.I keep an SD card in mine and store my books on it. You can just drop this in your purse to read on the go.',
#  'Husband is a first time user, he is doing really well with it.. He has low vision problems and this made reading his favorite books a lot easier to read.',
#  "It's actually a very good product for a decent price. Not lightning fast but it is okay for everyday use.",
#  'Love customer service very knowledgeable and helpful',
#  'Very good tablet for the price economical and the ability to carry in backpack',
#  "I bought this Kindle for my husband's birthday. I have had a Kindle since 2013 and I used it mostly to read and check emails while travelling. My husband is not particularly a book reader, but he spends way too many hours alone, in his office, reading his face book messages. Now, with the new Kindle he actually multi-tasks, in the living room, on facebook, email, and internet, at least in proximity to me, so he might even join me in a conversation! I think his Kindle has much imporoved our 35 year marriage!",
#  'It is easy to use. It was cheap. Have not found anything about it that I do not like.',
#  'i really love this product because it lets me read books and surf the net',
#  'Love this tablet. Bought it to be my touch screen remote for my harmony hub, but use it for so much more now.',
#  'make sure you buy a micro sd card with at least 64 gb of memory. or you will have to constantly delete old items.',
#  "This is a good product but the one I bought stops working after three or four typed sentences and the Geek Squad guy told me when I brought it back that I had to go into settings and clear the data when it does that. WRONG ANSWER. That should never have to be done. He had no idea what he was doing and North Haven Best Buy didn't offer to fix or replace my Kindle. This is the third product I have had to go back and either return or exchange because it wasn't working properly or at all. One manager tried to excuse the store by asking me if I understand Best Buy doesn't actually manufacture these products. If that is the best they can do to explain why they, as the Point of Sale, keep selling defective products, the North Haven store has a big problem.",
#  'like the speed the 8 inch screen is great. Works well.',
#  'Up and coming new technology helps everyone to enjoy life more greatly',
#  'This is the perfect tablet for my purposes. Easy to use and the perfect size. Not too large and not too small.',
#  'This device is s really good piece of electronic. It is a good reader and also is very good for my 2 year old granddaughter to use.',
#  'For my son as a present for college books. 5 textbooks were 1/4 the price on kindle than if we bought them on Amazon, this is my third kindle. Other two still working great,',
#  'I bought this to replace a 7"fire hd tablet that broke. Amazon changed the operating system so it took me a while to figure it out. I set this up for my son with special needs. I tried to make it as simple as possible for him. It is a little bigger. The sound isn\'t as good as the previous fire tablet. It also seems very slippery. I got a rubber honeycomb type cover for it. That seems to help us to grip it better. Over all, it\'s a good tablet for a child. Just use parental controls, and get a good cover for it.',
#  'Reciever of this really likes and and says its a step up from the fire hd7, so I guess that is what counts.',
#  'My bf got me this as a birthday present from my son. It\'s just like my 7" although larger. I cannot tell the different between the regular and the HD and I game on it. I\'m not sure if it cost more, but wouldn\'t waste the money if it did.',
#  'Noticeable improvement over the fire 7 inch. If you\'re a first-time tablet owner then the fire 7 inch is a great device. But if you\'ve owned a tablet with higher specs, there is a noticeable improvement with the fire 8 inch . The Fire 8" has a better display and faster processing.',
#  'Very satisfied for $39.95 sales price. Way faster than I expected.',
#  'I purchased this for a small child to use. She is quite happy with it, however it was a little too slow for my taste.',
#  'My new Kindle is an upgrade from my 7 year old Kindle Fire. As to be expected the video quality is better along with faster performance and more features. I still use my old Kindle as it is still ticking but the "shiny new toy" is fun.',
#  "This is the second Fire tablet that I have purchased. The first I returned in after I was not able to load YouTube onto the tablet. Amazon's take on Android was just to unfriendly to make it work. With this new tablet, Amazon has heard my concern and now I'm enjoying this tablet. It's well built for a sub-$100 device, but won't stand up to a lot of abuse.",
#  'Reliable, price efficient device. Easy to use for all ages.',
#  'I can play games, surf the internet or watch movies. I can check my e-mail or just about do anything I can do on a regular computer.I strongly recommend it.',
#  "This is a terrific tablet at a great price. The quality is excellent, the price is right, it has tons of storage capacity. And oh, did I mention that it's cheap? (Cheap for a tablet, that is.)",
#  'Had a great experience with my Best Buy rep! Great Job!',
#  'Small, portable and very easy to use. I have not had any issues as of yet.',
#  'I purchased this product on a whim with a very limited purpose which was to study for an exam while in the middle seat on a long flight. I expected to hand it to my 10-year old after my exam. The surprise was that really enjoy the device and in particular I like the Amazon account integration: On my next flight I was delighted to find that the unit actually downloads my videos for offline viewing! The best part is that I upgraded the memory with a 64GB SD card so now my available content is awesome! Truth is that my first unit inexplicably failed but Best Buy replaced my unit right away and I expect great things with this new device! My son also uses it on long trips!!!',
#  'I bought the HD Fire 7 for my wife,I liked hers decided to buy the Fire HD 8 for myself I love it.Nice graphics easy to use.',
#  'Able to download music and movies free!!!!!!!!!!!!',
#  'I have used the Kindle mostly for reading. I have downloaded books from Amazon, some free some purchased, that I have heard about for years and now will read. I have also read Manga from the Internet. My use of the internet has also included looking up gardening hints, animal care, and dog breed characteristics.',
#  'Need to have some computer savvy. Wound be much more helpful if it came with a simple basic instructions.',
#  'This was a gift for my son and he loves it. It not only helps him with his homework but he could also play games on it!',
#  'You cannot top the value at this price point with any other tablet. The only reason I give it 4 stars instead of 5 is the limited app selection through the amazon app store. If this came with the google play store, I would give it a 5 in a heartbeat. Overall it is a great tablet at this price point. I would highly recommend it.',
#  "Great for my mom who isn't tech savvy. Luv it! :-)",
#  'Very smooth tablet no lag at all also good battery.',
#  'Love the kindle will continue to buy them for my family',
#  'awesomeness, love how i xan watch my xfinity movies',
#  'This tablet is not only a great price but exactly what I needed for quick Internet access and to download books !',
#  'I purchased the Amazon Fire HD 8 to replace my 2nd generation Kindle Fire. It works great and the colors are sharp.',
#  'The 8 is bigger and lighter weight than my old 7 and the battery life is longer. It also has more storage and a camera. Love it!',
#  'I lost my tablet in Germany and wanted a replacement fast. Best Buy, had both the 7 and 8 inch Kindle fires in stock, after reading the reviews, I decided to go with the 8 inch. Boy was I glad that I did, the larger viewing area, is great for watching movies and Netflix on the airplane. The 8 inch has stereo sound , unlike the 7 inch which has only mono. Overall I am really happy with this tablet',
#  "Pros - HD quality for low price. Works really well with my Amazon account to access multiple Amazon features with extreme ease. Couldn't be happier. I have iPads too which are extremely versatile but they came with a big price but not this tablet. Love it!",
#  "We bought this one and a black one for our kids. It's very durable and good price for the quality. For myself personally, I still prefer my iPad, but if on a budget, you won't regret the investment. It's so simple I sometimes struggle using it. The free time experience is awesome for little ones and I can set parameters, which is a huge bonus. For a first-time tablet user, this is a solid product.",
#  'A very good product by amazon. Considering the price, even better.',
#  "Good for watching movies, reading books and playing games but don't expect to do much more. Everything else can be a challenge and it can get laggy and once in a while it'll just shut down a program or completely reboot.",
#  'Excellent product. I would definitely purchase again.',
#  'After using this tablet for a while, I have found that I even prefer this size over my iPad Air. Easy to carry around and long battery life make this my preferred device. The screen is just the perfect size for my older eyes, the screen on the 7" fire is just too small and cramped, and it seemed a lot less responsive. I highly recommend this sweet tablet.',
#  'This was a BIRTHDAY GIFT for my LITTLE one and she LOVED it!',
#  'I purchased two of these as Christmas presents for my children. I had been researching child friendly tablets with robust controls to keep them away from undesirable content. I found the 7" Fire Kids Edition, but after looking over the specs and reviews, I found myself unsure of it. I was mostly interested in the FreeTime application, so I did some research on that and found that it was available on other Fire models also. I came across the new Fire HD8, which had more power, a better screen, and far better battery life at a very affordable price point. I gave them a shot and I\'m glad I did.I have the Fire HD8\'s locked into FreeTime mode, so the only activities that can be done are ones that I approve of, but if I want to, I can pick up either of them and unlock them to access Netflix/Amazon Prime or anything else I desire. I currently have reading goals set up that they must achieve before they are able to access videos or games, and those are limited to X amount of time per day. FreeTime also has a bedtime feature which disables/enables the use of the tablets during designated times, which is amazing.The hardware itself is exceptional. The screen resolution is excellent, it\'s very responsive, and the battery life is spectacular! They advertise up to 12 hours of battery life, and depending on screen brightness, ours last almost that long regularly. The only con I can think of is that the cameras are sub-par, but that\'s not what I purchased the tablets for, so it\'s a non-issue for myself.Some of the reviews I read cited that the internal storage was easily filled with FreeTime content, so I installed 128GB SD cards in them. I also purchased some rugged children\'s cases for them off of Amazon.This is probably one of the best purchases I have made in a long time. The sound of silent children reading all day is priceless!!!',
#  'I bought this tablet for my sister to replace her kindle. We love it except for the fact it would not connect to ATT internet. I suspect this was an ATT problem. The internet could not be authenticated. Since we have had problems with ATT for seven years, I am sure it was a problem with them! Once my sis read the instructions, she was good to go!',
#  'Great tablet for a kid enjoys very much would buy again',
#  'Overall, very impressed especially when compared to my iPad mini 4. This tablet does it all and makes for an excellent e-reader, while also boasting specifications that rival any iPad.',
#  'works great for us for video calling, for kids watching videos',
#  'My wife loved her gift. I made the right purchase.',
#  "I own two Amazon fire tablets with this one being the same as owned.. My sister in law wanted a tablet and since I owned one just like this one I figured it to be a good buy.. She just loves it, she is able to do her scheduling, read books and watch her news programs.. It's a great Alertanative to an iPad... great price and just as powerful for a lot less cost..",
#  "These Kindle Fire tablets simply can't be beat in terms of value and bang for your buck if you have an Amazon Prime account it would be a crime not to have a Fire tablet.Good strong build quality, very nice bright screen with a strong picture and good resolution. They are pretty responsive, have good battery life and can handle the abuse of letting your kids use it as well.",
#  'We bought this tablet for our son in college and he loves it.',
#  "This is my first tablet and it's going well so far. I purchased this for reading and streaming. There have been a few hiccups with regards to a streaming video buffering for a long time and sometimes I have trouble with response on commands, but overall, I'm happy. It's been a nice device to have for reading online material offline.",
#  'Replaced my hd fire 7 because broke screed. Very pleased with the large screen.',
#  "My only dislike is that being a Kindle, my Kindle books cannot be sorted into categories. It's harder to find new books I've downloaded some time ago when I have to search through all of them.",
#  'Purchased as a gift. The receiver loves it and said that it works nicely.',
#  'Purchased this for my 80 year old mother in law to replace her old cracked screen one. Everything was perfect easy to use and set up. She has zero problems using this for online and reading books.',
#  'Love it I sent one down to my family in Mexico they loved it',
#  'Bought this as a gift for my mother. She absolutely loves it. Easy to set up and use. and the price was right.',
#  'I am loving this tablet. My previous tablet was a 1st year Fire. This tablet is great for reading, games,facebook and emails.',
#  'This is my third Kindle and I have loved them all. I still have my first Kindle and use it. I just wore my Kindle Fire out with 5 + years use. I am very happy with everything my new one can do. No disappointments at all.',
#  'I got this for my husband for his birthday. He likes the light weight and the speakers and how powerful it is.',
#  'Got it for my Dad. Easy to use and he loves it. Good stepping stone for future producs',
#  'One of the best purchases or investments you could make for technology.',
#  'I bought it for kindle books and was amazed by its overall features. Its Kindle with features of a TAB.',
#  'I bought this primarily for reading, but, being a tablet it is able to do so much more! I can listen to music, download movies and check email. I love it! Way better than my Nook!',
#  'Great tablet for price! Fast, works great, great sound volume, great pixelation and screen size']
