# %%
# !pip install rake_nltk
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# ...

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
# Out:
#     Linking successful
#     /usr/local/lib/python2.7/dist-packages/en_core_web_lg -->
#     /usr/local/lib/python2.7/dist-packages/spacy/data/en_core_web_lg
#
#     You can now load the model via spacy.load('en_core_web_lg')

# %%
import nltk
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer

# %%
TextBlob("product is very expensive but not that simple to use. need to think about buying").sentiment
# Out:
# Sentiment(polarity=-0.325, subjectivity=0.6335714285714286)

# %%
TextBlob("product is very expensive but not that simple to use. need to think about buying",analyzer=NaiveBayesAnalyzer()).sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.6911332903833944, p_neg=0.30886670961660495)

# %%
TextBlob("I feel it works well, bit it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get starty and very handy for troubleshooting errors").sentiment
# Out:
# Sentiment(polarity=0.08016666666666668, subjectivity=0.6816666666666666)

# %%
TextBlob("I feel it works well, bit it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get started and very handy for troubleshooting errors",analyzer=NaiveBayesAnalyzer()).sentiment
# Out:
# Sentiment(classification='neg', p_pos=0.15376811449955138, p_neg=0.8462318855004509)

# %%
text = u"""I feel it works well, but it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get started and very handy for troubleshooting errors.I feel it works well, but it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get started and very handy for troubleshooting errors.I feel it works well, but it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get started and very handy for troubleshooting errors.I feel it works well, but it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get started and very handy for troubleshooting errors"""

# %%
text = "I feel it works well, but it is little expensive for our usage level. Other than that, the dashboard is intuitive, easy to get started and very handy for troubleshooting errors"
from rake_nltk import Metric, Rake
r = Rake() # Uses stopwords for english from NLTK, and all puntuation characters.

r.extract_keywords_from_text(text)
r.get_ranked_phrases()
# Out:
# ['works well',
#  'usage level',
#  'troubleshooting errors',
#  'little expensive',
#  'get started',
#  'intuitive',
#  'handy',
#  'feel',
#  'easy',
#  'dashboard']

# %%
import spacy
nlp = spacy.load("en_core_web_lg")
# Out:
# 0.49139180989418174

# %%
nlp(u"price").similarity(nlp(u""))
# Out:
# 0.1380859174478488

# %%
import spacy
nlp = spacy.load("en_core_web_md")

# %%
doc = nlp(u"little expensive")
noun_adj_pairs = []
for i,token in enumerate(doc):
    if token.pos_ not in ('NOUN','PROPN','VERB','ADV'):
        continue
    for j in range(i+1,len(doc)):
        if doc[j].pos_ == 'ADJ':
            noun_adj_pairs.append((token.text,doc[j].text))
#                 print(type(token.text))
#                 print(type(doc[j].text))
            break
  
noun_adj_pairs
# Out:
# [(u'little', u'expensive')]

# %%
doc2 = nlp(text)
for token in doc2:
    # Print the text and the predicted part-of-speech tag
    print(token.text, token.pos_)
# Out:
# (u'I', u'PRON')
# (u'feel', u'VERB')
# (u'it', u'PRON')
# (u'works', u'VERB')
# (u'well', u'ADV')
# (u',', u'PUNCT')
# (u'but', u'CCONJ')
# (u'it', u'PRON')
# (u'is', u'VERB')
# (u'little', u'ADV')
# (u'expensive', u'ADJ')
# (u'for', u'ADP')
# (u'our', u'ADJ')
# (u'usage', u'NOUN')
# (u'level', u'NOUN')
# (u'.', u'PUNCT')
# (u'Other', u'ADJ')
# (u'than', u'ADP')
# (u'that', u'DET')
# (u',', u'PUNCT')
# (u'the', u'DET')
# (u'dashboard', u'NOUN')
# (u'is', u'VERB')
# (u'intuitive', u'ADJ')
# (u',', u'PUNCT')
# (u'easy', u'ADJ')
# (u'to', u'PART')
# (u'get', u'VERB')
# (u'started', u'VERB')
# (u'and', u'CCONJ')
# (u'very', u'ADV')
# (u'handy', u'ADJ')
# (u'for', u'ADP')
# (u'troubleshooting', u'NOUN')
# (u'errors', u'NOUN')
# (u'.', u'PUNCT')
# (u'I', u'PRON')
# (u'feel', u'VERB')
# (u'it', u'PRON')
# (u'works', u'VERB')
# (u'well', u'ADV')
# (u',', u'PUNCT')
# (u'but', u'CCONJ')
# (u'it', u'PRON')
# (u'is', u'VERB')
# (u'little', u'ADV')
# (u'expensive', u'ADJ')
# (u'for', u'ADP')
# ...
