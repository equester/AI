# %%
import spacy
print (spacy.__version__)
# Out:
# 2.1.8

# %%
# !spacy validate
# Out:
# ✔ Loaded compatibility table
#
# ====================== Installed models (spaCy v2.1.8) ======================
# ℹ spaCy installation: /usr/local/lib/python3.6/dist-packages/spacy
#
# TYPE      NAME             MODEL            VERSION
# package   en-core-web-sm   en_core_web_sm   2.1.0   ✔
# link      en               en_core_web_sm   2.1.0   ✔

# %%
# !virtualenv -p python3 envname
# Out:
# /bin/bash: virtualenv: command not found

# %%
#get indonesian word2vec from fasttext
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.id.300.vec.gz
# Out:
# --2019-08-21 12:29:32--  https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.id.300.vec.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.20.6.166, 104.20.22.166, 2606:4700:10::6814:16a6, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.20.6.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1227018698 (1.1G) [binary/octet-stream]
# Saving to: ‘cc.id.300.vec.gz’
#
# cc.id.300.vec.gz    100%[===================>]   1.14G  37.7MB/s    in 33s
#
# 2019-08-21 12:30:06 (35.4 MB/s) - ‘cc.id.300.vec.gz’ saved [1227018698/1227018698]

# %%
# !gunzip cc.id.300.vec.gz

# %%
# !ls -l --block-size=G
# Out:
# total 2G
# -rw-r--r-- 1 root root 2G Jan 18  2019 cc.id.300.vec.gz
# drwxr-xr-x 1 root root 1G Aug  2 16:06 sample_data

# %%
# training id_vectors_wiki_lg from vectors obtained from fasttext using wget from one of the above cells. id_vectors_wiki_lg can be used for similarity only as of now. 
# !python -m spacy init-model id id_vectors_wiki_lg --vectors-loc cc.id.300.vec.gz
# Out:
# ✔ Successfully created model
# ⠙ Reading vectors from cc.id.300.vec.gztcmalloc: large alloc 2400002048 bytes == 0x5a8c000 @  0x7f9542d78001 0x7f95408ffde5 0x7f95409646f1 0x7f95409667cf 0x7f95409ff158 0x4f8925 0x4fa6c0 0x4f7a28 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d 0x4f98c7 0x4f6128 0x56fe24 0x57c2fe 0x4facb1 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x517a9a 0x4f858d 0x4f98c7 0x4f6128 0x4f7d60
# 2000000it [02:22, 14042.91it/s]
# ✔ Loaded vectors from cc.id.300.vec.gz
# ✔ Sucessfully compiled vocab
# 2010739 entries, 2000000 vectors

# %%
# !python3 -m spacy info id_vectors_wiki_lg
# Out:
# ✘ Can't find model meta.json
# /usr/local/lib/python3.6/dist-packages/spacy/data/id_vectors_wiki_lg/meta.json

# %%
import spacy
nlp = spacy.load('id_vectors_wiki_lg')

# %%
def most_similar(word):
  queries = [w for w in word.vocab if w.is_lower == word.is_lower and w.prob >= -15]
  by_similarity = sorted(queries, key=lambda w: word.similarity(w), reverse=True)
  return by_similarity[:10]

# [w.lower_ for w in most_similar(nlp.vocab[u'baik'])]
most_similar(nlp.vocab[u'baik'])
# Out:
# []

# %%
import gensim
#load word2vec model, here GoogleNews is used
% time model2 = gensim.models.KeyedVectors.load_word2vec_format('cc.id.300.vec.gz', binary=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# CPU times: user 8min 20s, sys: 4.69 s, total: 8min 24s
# Wall time: 8min 25s

# %%
model2.most_similar("apel")
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('apel-apel', 0.7748609185218811),
#  ('apelnya', 0.700954794883728),
#  ('Apel', 0.6883244514465332),
#  ('apel.', 0.6593513488769531),
#  ('ApelCuka', 0.6548508405685425),
#  ('ApelApel', 0.6361609697341919),
#  ('apelku', 0.6098775863647461),
#  ('Apelnya', 0.6068015098571777),
#  ('jeruk', 0.5988685488700867),
#  ('apelmu', 0.5861527323722839)]

# %%
nlp("Saya membeli iPhone Apple baru-baru ini").similarity(nlp("saya membeli ponsel android"))
# Out:
# 0.7509923956019483

# %%
vector1 = nlp(u"ngantuk").vector
most_similar = doc.vocab.vectors.most_similar(tvec.reshape(1,tvec.shape[0]))

# %%
# the models id_gsd-ud-train.json and id_gsd-ud-dev.json has been obtained from 
# google stanford dictiories universal dependencies (https://universaldependencies.org/) 
# Use spacy's converter to convert conll files from universal dependencies to json file
# !python -m spacy train id model3 id_gsd-ud-train.json id_gsd-ud-dev.json -v id_vectors_wiki_lg
# Out:
# Training pipeline: ['tagger', 'parser', 'ner']
# Starting with blank model 'id'
# Loading vector from model 'id_vectors_wiki_lg'
# tcmalloc: large alloc 2400002048 bytes == 0x40f38000 @  0x7efd422261e7 0x7efd3fdafca1 0x7efd3fe199c5 0x7efd3fe1a55e 0x7efd3feb3a6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f8ff9 0x7efca4522bc8 0x7efca453038d 0x57ec0c 0x4f88ba 0x4f98c7 0x7efca45207e0 0x7efca4522cdc 0x7efca452f1c3 0x562433 0x7efca57d972d 0x4f8925 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f7a28 0x4f876d

# %%
# !zip -r model_w2v_id.zip model_02
# Out:
#   adding: model_02/ (stored 0%)
#   adding: model_02/model3/ (stored 0%)
#   adding: model_02/model3/vocab/ (stored 0%)
#   adding: model_02/model3/vocab/lexemes.bin (deflated 73%)
#   adding: model_02/model3/vocab/strings.json (deflated 64%)
#   adding: model_02/model3/vocab/key2row (deflated 15%)
#   adding: model_02/model3/vocab/vectors (deflated 9%)
#   adding: model_02/model3/tagger/ (stored 0%)
#   adding: model_02/model3/tagger/tag_map (deflated 59%)
#   adding: model_02/model3/tagger/cfg (deflated 11%)
#   adding: model_02/model3/tagger/model (deflated 7%)
#   adding: model_02/model3/parser/ (stored 0%)
#   adding: model_02/model3/parser/moves (deflated 46%)
#   adding: model_02/model3/parser/cfg (deflated 43%)
#   adding: model_02/model3/parser/model (deflated 8%)
#   adding: model_02/model3/accuracy.json (deflated 32%)
#   adding: model_02/model3/meta.json (deflated 48%)
#   adding: model_02/model3/tokenizer (deflated 74%)
#   adding: model_02/model3/ner/ (stored 0%)
# ...

# %%
# !ls -lrth
# Out:
# total 16G
# -rw-r--r--  1 root root 4.2G Jan 18 15:38 cc.id.300.bin.gz
# -rw-r--r--  1 root root 755M Jan 18 17:08 wiki.id.vec
# drwxr-xr-x  1 root root 4.0K Jun 18 16:14 sample_data
# drwxr-xr-x  3 root root 4.0K Jul  3 09:56 id_vectors_wiki_lg
# -rw-r--r--  1 root root 234K Jul  3 10:00 Arthur_detected.csv
# -rw-r--r--  1 root root  64K Jul  3 10:10 id_dep_ud_sm-0.0.1.tar.gz
# drwxr-xr-x  3 root root 4.0K Jul  3 10:20 UD_Indonesian-GSD
# -rw-r--r--  1 root root 1.9M Jul  3 10:31 id_gsd-ud-dev.json
# -rw-r--r--  1 root root  15M Jul  3 10:34 id_gsd-ud-train.json
# drwxr-xr-x 34 root root 4.0K Jul  3 11:02 models
# -rw-r--r--  1 root root 1.2M Jul  3 11:25 BahasaOutput.csv
# drwxr-xr-x  4 root root 4.0K Jul  3 13:44 model_01
# drwxr-xr-x 34 root root 4.0K Jul  3 14:28 model_02
# -rw-r--r--  1 root root  11G Jul  3 14:43 model_w2v_id.zip

# %%
import spacy
spacy.util.use_gpu(0)
# Out:
# <CUDA Device 0>

# %%
import thinc.neural.gpu_ops
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-a8390d9388a1> in <module>()
# ----> 1 import thinc.neural.gpu_ops
#
# ModuleNotFoundError: No module named 'thinc.neural.gpu_ops'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
