# %%
# !pip install newsapi-python
# Out:
# ...
#     100% |████████████████████████████████| 92kB 5.8MB/s
# ...
#     100% |████████████████████████████████| 61kB 23.7MB/s
# ...
#     100% |████████████████████████████████| 133kB 14.7MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/a0/58/f4/627d98e817f4c1819fc524ec3b3187534f8078e36c0d4048a1
# Successfully built newsapi-python
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# google-colab 1.0.0 has requirement requests~=2.18.0, but you'll have requests 2.17.1 which is incompatible.
# google-api-core 1.8.2 has requirement requests<3.0.0dev,>=2.18.0, but you'll have requests 2.17.1 which is incompatible.
# fastai 1.0.50.post1 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: idna 2.6
#     Uninstalling idna-2.6:
#       Successfully uninstalled idna-2.6
# ...

# %%
from newsapi import NewsApiClient
import pandas as pd

# %%
api = NewsApiClient(api_key='e7082f0262de4b03ac0e200b2b5027c2')

# %%
api.get_everything(q='India Forest')
# Out:
# {'articles': [{'author': 'https://www.facebook.com/bbcnews',
#    'content': 'Image copyrightGetty Images\r\nThe Indian government launched a flagship scheme in 2016 to eliminate the indoor pollution generated by using kerosene, wood and cow dung on cooking stoves by encouraging the use of cleaner fuel.\r\nThis scheme involved supplying of… [+3552 chars]',
#    'description': 'Is a government scheme to persuade people to use cleaner cooking fuel really working?',
#    'publishedAt': '2019-03-14T00:25:50Z',
#    'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'title': 'India election 2019: The great kitchen clean-up',
#    'url': 'https://www.bbc.co.uk/news/world-asia-india-46837291',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/11E36/production/_106007237_cc3819c7-95f1-4078-866a-4159757ebd09.jpg'},
#   {'author': 'Devjyot Ghoshal',
# ...

# %%
df = pd.DataFrame.from_dict(data_json, orient='columns')

# %%
'df
# Out:
#                                              articles status  totalResults
# 0   {'source': {'id': 'techcrunch', 'name': 'TechC...     ok          1540
# 1   {'source': {'id': 'bbc-news', 'name': 'BBC New...     ok          1540
# 2   {'source': {'id': None, 'name': 'Thehansindia....     ok          1540
# 3   {'source': {'id': None, 'name': 'News18.com'},...     ok          1540
# 4   {'source': {'id': 'techcrunch', 'name': 'TechC...     ok          1540
# 5   {'source': {'id': None, 'name': 'Timesnownews....     ok          1540
# 6   {'source': {'id': None, 'name': 'Gizmodo.com'}...     ok          1540
# 7   {'source': {'id': 'reuters', 'name': 'Reuters'...     ok          1540
# 8   {'source': {'id': None, 'name': 'India.com'}, ...     ok          1540
# 9   {'source': {'id': None, 'name': 'Financialexpr...     ok          1540
# 10  {'source': {'id': 'the-new-york-times', 'name'...     ok          1540
# ...
