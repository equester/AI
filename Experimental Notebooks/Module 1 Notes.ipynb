# %% [markdown]
# #8 June
#
# - Topics
#   - Insights
#    - Question & Answers

# %% [markdown]
# # New Section

# %% [markdown]
# ## Links:
# Venkata's Numpy Assignment (Currency Normalization assignment, normalize all the curriencies to Dollar and plot it aginst rating.)
#  - https://colab.research.google.com/drive/1iIWXzoLXCZ4y5TvnVeUbvTYz3NN-ucMz
#
#  Common Notebook on Colab
#  -https://colab.research.google.com/drive/1zhqLvYDi2cEUZkma73v4c13PjpXGCSbG#scrollTo=cPEm9PzquKEU

# %% [markdown]
# #Codes:-

# %%
#CODES

- zomato_df[['City','Locality']][:200]

- zomato_df[zomato_df["Restaurant Name"].str.match('Dhaba')]

- def findValue(val):

  if(val.find("pizza")):

return 1

else:

return 0
  

findfunc = zomato_df["Restaurant Name"].apply(findValue)
findfunc

- import re
from fuzzywuzzy import fuzz
def evaluateString(eachvalue):
#   if KeyWord.lower() in eachvalue.lower():
  
  if fuzz.ratio(KeyWord.lower(), eachvalue.lower())>30:
#   if re.search(KeyWord, eachvalue.lower()):
    return 1
  else:
    return 0
global KeyWord
KeyWord = "piz+a$"
# pizza
# pizzzzaa
#pizaaaa
#pizzzaaaaaa
#pppppppzaaa

# %time zomato_df['NewValue'] = zomato_df['Restaurant Name'].apply(evaluateString)
zomato_df[zomato_df['NewValue'] == 1]['Restaurant Name']
 # Fuzzy String Match

# %% [markdown]
# ## Theory

# %% [markdown]
# Hands-On

# %% [markdown]
# ## Doubts

# %% [markdown]
# #9 June
#  ## Intro. to M.L.

# %% [markdown]
# #Links:
#
# ## For Regex
# - https://www.w3schools.com/python/python_regex.asp
# - http://www.pyregex.com
# - https://pythex.org
#
# ##Few Real life datasets
# - https://drive.google.com/drive/folders/1KOm2Fxa9PnvP1vU_ruOk84rESzpG9ynu?usp=sharing
#
# ##Venkat's colab
# - https://colab.research.google.com/drive/1ByHZ8Qzd05_GbkM5U7ZgVxF1whwSwZo6

# %% [markdown]
# # Requirements : Features of a Model:
# X-> Features -> Independent Varaible
#
# Y- > Output -> Class
#
# ##Conditions (Events)
#
# X, Y -> Supervised Learning
#
# X , Not Y  -> Unsuperived Learning

# %% [markdown]
# #Assignments:
# ### 1. All restaurants on first or second floor.
# ### 2. All Rest. Names & their countries (Code-> Country)
# ####     i) Chinese: >4 Rating & <300 votes (Play with numbers, it could be any filter of these columns)
# ####  ii) American:  >4 Rating & <300 votes (Play with numbers, it could be any filter of these columns)
# ### 3. All Rest. Names & Country, where they are in "CITY" ; The locality string should contain city.
#
#
# 1) Find Restaurants which are in first and second floor.(Venkat), Used Regex (((1|2)(st|nd)[ ]*fl[o]*r)|((first|second)[ ]*fl[o]*r) to filter the first and second floor
# https://colab.research.google.com/drive/1P7LvJZivCulJutBzWksM8CEj53s62kDe
#
# 2) Cuisine filtering using oops
# https://colab.research.google.com/drive/1Y01Fruqb-5LQzECdJhBhEZALz1hhejr-
#
# 3) Amit;
# https://colab.research.google.com/drive/1iQErAf75GaJ3xR_wNJDVXtdlX0_gohKL#scrollTo=5yo_L5mePDqv

# %% [markdown]
# #15 JUNE
# ## MACHINE LEARNING

# %% [markdown]
# #Links:
#
# *   List item
# *   List item

# %%
# Assignment 
Pick any one Internet Comapany and understand their supply chain and see where they might be using Data Science
Anything which you use from Mobile EndPoint ( Thrugh APps)

-- Practo (Which doctors are in high demand and get them to platoform)
-- Dunzo ( How are they managing their riders )
-- Urbanclap - How do they manage the suppliers of services based on demand

# %% [markdown]
# Machine Learning Graph
#
# ![alt text](https://drive.google.com/file/d/18uINlOlFTgik55lIM7FrqbD-XHBnlKB3/view?usp=sharing)

# %% [markdown]
# ![alt text](https://drive.google.com/file/d/173ZUKr_Pwb6OnS14QbMxWu7tUmhPQbz0/view?usp=sharing)

# %% [markdown]
# #16 June

# %% [markdown]
# ##Definitions and examples: 3 kinds of learning
#
# - Supervised learning:
#
# - Unsupervised learning:
#
# - Reinforcement learning: algorithm is set to manage its E, T and P

# %% [markdown]
# ## Step 1: Model Objective
#
# Precit if a customer is going to churn based on it's historical transaction and thus reduce the overall customer churn by 20% in coming 2 quarters  + Model should be deployed ons erver with latency ~ 1Lack Prediction/Sec
#
#
# ## Step 2: Gathering of the data
#
# ## Step 3: Data pre-processing
#
# ## Step 4: Building a Model
#
# ## Step 5: Train the data
#
# ## Step 6:  Model Evaluation
#
# ## Step 7: Test for Business Goal

# %% [markdown]
# # Note:
#
# In vector-space: Rows= points
#                              ;Columns= dimension
#
#  y = mx -> LR
#
# y = mx^6 -> One variation of neural network

# %% [markdown]
# ###Machine Learning and AI use cases
#
# https://docs.google.com/document/d/1jnMNWL_ARdPbT95reONyWTXvX8oDmlwjUMJHDDGLsn8/edit?usp=sharing

# %% [markdown]
# Swiggy_Objective
# https://drive.google.com/open?id=1T6UVc0N_z4ov6RvNhm7quVedRFrT7sny

# %% [markdown]
# # **Assignment**
#
# ##**MSE and RMSE calculation using Python**
#
# 1. Prasanta: https://colab.research.google.com/drive/1Z6tSyJtN-TfvGQrQ9pYe_jEpw316HCff

# %% [markdown]
# #30 JUNE

# %% [markdown]
# - Dask is almost 10 times faster than Pandas when reading files
# - int64 and flt64=> numerical values
# - object=> not a numerical value

# %% [markdown]
# —— Pre-Processing Pipeline ———
#
# Take Backup of Data
# ->  df_prop_backup = df_prop.copy()
# Drop:   — Done -> Either not important to be used ; no inherent information; High Correlated Values
# * Address
# * Appartment Number
# * ID
# * Easement
# * ZIP
# * Total Units
# Skewed:   - > Not Done Anything so far; However - > We do Numerical Transformations like LOG ; High skew to Normal Distribution
# * COMMERCIAL UNITS
# * RESIDENTIAL UNITS
# * High Skewed
# * RESIDENTIAL UNITS
# * Commercial Units
# * borough
#
# — Removing data where the ranges or values are not in accordance of Domain
# High Zero's: ( Non Availability of Data)
# * Total Unit
# * Year Built
# * ZIP - removed
# * GROSS SQUARE FEET
# * LAND SQUARE FEET
# Dash Substitute ( Non Availability of Data)  - Done
# * Sales Price
# * GROSS SQUARE FEET
# * LAND SQUARE FEET
# Action:   — Done
# * Remoe 0, - & 10 rows from Sales Price
# *
#
# DataType Conversion: From a value prospective (domain dependent)
# - Tax Class at time of sale
# - Tax class t present
# - Land Square Feet
# - Gross Square feet
# - Sales Price
# - Borough
# - Sale Date
#
# Filter Values which are not Domain Appropriate
#  - Sales Prices > 100
# - Gross Square Feet
# - Land Square Feet
#
# Outliers: Values beyond particular domain range
#  - Remove everything beyond 90 percentile in Sales Column
#
#
# Feature Engineering - Gives us new features from old data
# 	- Extract individual time features from time column
#
# Insights from Data:
# - Manhattan typical sells smaller units and in range of square feet <> & Sales Pricc <>
#
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')
#
# High Correlation Insights :
#  - Residential Unit vs Gross Square Feet
# - Residential Unit vs Land Square
# - Month vs Year ( Negative)
#
# Action 2:
#
# - Don’t remove Nan Columns —> Impute with some value   —> Assignment
# -
# -
#
# Assignments:
#
# — Impute Median Values to Gross Square and Land Square rather than removing
#
# — Convert high Skew Numerical Data to Log Transformation ( Use np.log) - Only Numerical Continuous Data
#
# — Research why Y should be normal distributed in Linear Regression
#
# — English Translation of Sales Prices Kurtosis and Skewness - no mathematical concepts
#
# -- What should we do with new correlation and possible english translation
#
# -Assumption: Linear Regression
#
# — Y should be normally distributed
#
# — Y & X should no the highly correlated; they should be least correlated

# %% [markdown]
# #6 JULY

# %% [markdown]
# 1-> Signifies presence of that column in that row
#
# 0-> Non presence of that value

# %%
Standardization:-

# Import the Model Library 
# Initialize the class object of model and save it in variable ---> Model Training Y= f(x)
# Call the .fit method of that class to run Model by passing (XTrain YTrain)
# Call the .predict method to predict the test data using the model in the previous step

For Scaling (standard steps):-

#[X,Y] ---> Feature Vector

#Scale the values
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Scale and center the data
fdf_normalized = scaler.transform(X)  ---> #always uses the apply function

# Create a pandas DataFrame
fdf_normalized = pd.DataFrame(data=X, index=X.index, columns=X.columns)

# %% [markdown]
# #7 JULY
# ##Credit card default ipynb

# %% [markdown]
# - Dummies: are basically 1 and 0 representing the discrete objects from a column perspective.
#
# - One hot encoding: categorical variables are converted into a form that could be provided to ML algorithms.
#    - As the number of unique entries increases, the categorical values also proportionally increases.
#    - perform “binarization” of the category and include it as a feature to train the model.
#    (for more refer : https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f)
#
# - Packages:
#  - plotly-express ---> visualization
#
#  - shap --->
#
#  - eli5 --->
#
#  - lime --->
#    - *(Model explainabilty is yet to be discussed)*
#
# - pd.crosstab ----> pivot table (~to excel sheet)
#
# - random_state=1234 ---> first time is random and then it is identified and not changed further

# %% [markdown]
# # 13 July
# ##Decision tree and random forest ppt

# %% [markdown]
# 1. Root Nodes (Roots) ---> can be Decision Node if it's split into decision
# 2. Decision Nodes (Bark)
# 3. Terminal Nodes(Leaves)
#
# - Kullback-Leibler Divergence (KL Divergence) ---> information gain

# %% [markdown]
# #14 JULY

# %% [markdown]
# Decision tree Notes:
#
# https://drive.google.com/file/d/1VYr4ur0RVAivHy7scxEkENTNGKbxFzwJ/view?usp=sharing

# %% [markdown]
# ##WEBSITES
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html
# https://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1545933328/output_65_0_jteora.png

# %% [markdown]
# https://www.quora.com/What-is-the-best-way-to-understand-the-terms-precision-and-recall

# %% [markdown]
# Sonya's notes: https://drive.google.com/file/d/1VYr4ur0RVAivHy7scxEkENTNGKbxFzwJ/view?usp=sharing

# %% [markdown]
# Max_Depth --> Maximum depth of the tree.
#
# Min_samples_leaf --> Number of sampels in leaf nodes

# %% [markdown]
# #20 JULY
# ##Telecom binary attack ipynb

# %%
train[(train['Dst_bytes'] <5000) &(train['Src_bytes']<5000)]['attack'].value_counts()

# %% [markdown]
# What are the list of graphs used in multivarient analysis?
# https://seaborn.pydata.org/api.html

# %% [markdown]
# ###Questions:
# What is the advantage of RMSE over MSE?
#
# How can i use the conceptual pwer of random forest in decision tree implementation
# such that, i get the goods of RF (stable, and high accurate)  and the Goods of DT (explainability and less complex)

# %% [markdown]
# #21 JULY
# ###Boosting
#
# Y^ = M@+c -> Predicted
#
# Y -> Actual
#
# Assume, that constant value C is Zero, or The model originates from origin
#
# Cost Function/Loss Function = (P-A)^2
#
#                                                      = (@X - Y)^2
#
# Ideal Value of Cost Function Should be Zero
#
# (@X - Y) ^2 = 0
#
# Find the value of @(Theta, M) such that the cost function is at minimum
#
# First Random Value -> 2
#
# LR = 0.1
#
# First DIff - > 2
#
# Second Diff -> 2+LR = 2.01
#
# THrid Diff = 2.01 + 0.1 = 2.02
#
# Until, D/Dx becomes zero or , Slope is Zero
#
#
# ---
#
#
#
# ---

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html
#
# https://xgboost.readthedocs.io/en/latest/
#
# https://github.com/catboost/catboost
#
# https://lightgbm.readthedocs.io/en/latest/

# %% [markdown]
# https://blog.goodaudience.com/machine-learning-using-decision-trees-and-random-forests-in-python-with-code-e50f6e14e19f

# %% [markdown]
# ###Stacking

# %% [markdown]
# #27 JULY-28JULY

# %% [markdown]
# https://drive.google.com/file/d/1yxRsksDsQkvsdu-BP1F57ZhLXVVgvyJh/view?usp=sharing
#
# https://www.youtube.com/watch?v=3liCbRZPrZA

# %% [markdown]
# #10th August
# https://colab.research.google.com/drive/1UtZxBdOzInVRM7zWPSM-j-YoX2mUkYRZ

# %% [markdown]
# # 11th August
#
# Unlock the locked research papers:- http://sci-hub.tw
#
# https://www.reddit.com/r/MachineLearning
#
# https://www.reddit.com/r/artificial/
#
# medium
#
# https://algorithms-tour.stitchfix.com/#recommendation-systems
#
# https://www.amazon.in/Prediction-Machines-Economics-Artificial-Intelligence/dp/1633695670
#
# http://www.r2d3.us/visual-intro-to-machine-learning-part-1/
#
# http://www.r2d3.us/visual-intro-to-machine-learning-part-2/
#
# facebook is also doing lot of AI related stuff
#
# https://eng.uber.com/category/articles/ai/

# %% [markdown]
#  Quora: What do you think of the AI specific course at UpX Academy?---> write here--->
#  https://qr.ae/TWr1BH
