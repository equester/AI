# %% [markdown]
# ## Problem
# -- Client Query (" Manufactoring in 3D Printing Space") -> entered by client  --> Recomm should be personlized
#   Subject -> Manufactoring in 3D Printing Space
#   TextLine -> Extension; what vendors should we go? trends? 3D implememtation in specific domain?
#     - text field
#     - short subject line
#
# To be searched in:
#     -- Events
#       - name, location, desc ,speakers , agenda -- Text
#     -- Research Reports
#       - huge category
#           -- Document title
#           -- Summary
#           --  Date (revised as well)
#     -- Webinars
#       - Title, Summary, Speaker
#
#
#  Cleant Data:
#   - Demographic Details  ( CSV ; company details)
#   - Gartner Activity  ( Asset mapping in 1/0 ; not always binary ; text & cat -> Time dependent data)
#   - Past question -> Text
#   - Historical Recom Data -  Activity Data
#       - Query --> recommended assets
#
#
#
#  To do : --> Find the top 10 closest asset for the query

# %% [markdown]
#  --- Clent Query
#     - Filter on Asset Level
#       -- Break that into Parsable Entities  --> We can do filter on the assets
#       -- We should have standard query entities by analyzing historical query records  -> Training Custom NER Tags on English Corpus ; Classification of query Doc -> into specific endGoal
#             --- Industry: ? ( Demo Data )
#             -- Technology?
#             --LookingForTrend (Y/N)
#             --Implementation?
#
#  Filter on Clients/Query (Historical)
#   Figure out nearest neigbours or create Cluster of  similar behaviour this Data?
#     -- Combining:
#           - Demogr Data
#           - Query Filter Data
#           - Asset Activity
#           - Similar Query (Current & Historical)
#
#  Filtering & Ranking
#
#  --- Eeuclidian Distance
#
#
#  Text-> Has to be Vectorized
#  Numerical Data -> No Need ( Scale)
#  Categorical -> Dummify ( BInary Representation )
#
#  Gartner2Vec    ->
#
#  Input -> Vec
#  1)
# Train: (Y)--> Asset Classification ( Tech/3d/Poly)
#
# 2) Uns
# -Cluster
# - Similarity based on CF
#
#     -- Get the assets of that cluster
#     - In cluster -> closest
#
#   Model Validation:
#       - Model QA
#           - Test Accuracy (Doing N Experiment -> Precision ( Bias))
#           -  Uns -> SSD (bw clusters) -> Elbow Curve -> K Value
