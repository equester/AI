# %%
import pandas as pd
data = pd.read_csv("TopicDFFinal.csv")

# %%
global_topic_list = data['ImportantTopic'].tolist()

# %%
import spacy
spacy.cli.download("en_core_web_md")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
# !python -m spacy link en_core_web_md enmd
# Out:
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_md -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/enmd
# You can now load the model via spacy.load('enmd')

# %%
nlp = spacy.load("enmd")

# %%
for eachTopic in Topics:
  if eachTopic != "works well":
    if nlp(eachTopic).similarity(nlp("works well")) > 0.70 and nlp(eachTopic).similarity(nlp("works well")) <0.80:
      print (eachTopic)
# Out:
# well made
# well worth
# well built
# much better
# seems like
# still use
# pretty much
# tune well

# %%
# %%time
topicList = []
start_threshold = 0.7
end_threshold = 1
global_topic_count = 100
topic_to_search = "electric guitar"
for eachTopic in global_topic_list[:global_topic_count]:
  if eachTopic != topic_to_search:
    if nlp(eachTopic).similarity(nlp(topic_to_search)) > start_threshold and nlp(eachTopic).similarity(nlp(topic_to_search)) < end_threshold:
      topicList.append(eachTopic)
# print (list(filter(lambda k: topic_to_search not in k, topicList))[-10:])
print (list(filter(lambda k: topic_to_search not in k, topicList))[:5])
# print(topicList[:5])
# Out:
# ['playing guitar', 'guitar strap', 'guitar strings', 'acoustic guitar', 'play guitar']
# CPU times: user 1.69 s, sys: 654 µs, total: 1.69 s
# Wall time: 1.69 s

# %%
# !wget -c "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
# Out:
# --2019-07-02 08:55:46--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.73.66
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.73.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  68.5MB/s    in 21s
#
# 2019-07-02 08:56:07 (76.2 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M-subword.vec.zip
# Out:
# --2019-07-02 09:14:15--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M-subword.vec.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.20.22.166, 104.20.6.166, 2606:4700:10::6814:16a6, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.20.22.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 587879973 (561M) [application/zip]
# Saving to: ‘wiki-news-300d-1M-subword.vec.zip’
#
# wiki-news-300d-1M-s 100%[===================>] 560.65M  28.7MB/s    in 20s
#
# 2019-07-02 09:14:36 (27.9 MB/s) - ‘wiki-news-300d-1M-subword.vec.zip’ saved [587879973/587879973]

# %%
# !unzip wiki-news-300d-1M-subword.vec.zip
# Out:
# Archive:  wiki-news-300d-1M-subword.vec.zip
#   inflating: wiki-news-300d-1M-subword.vec

# %%
import gensim
#load word2vec model, here GoogleNews is used
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)
#two sample sentences 
s1 = 'the first sentence'
s2 = 'the second text'

#calculate distance between two sentences using WMD algorithm
distance = model.wmdistance(s1, s2)

print ('distance = %.3f' % distance)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# distance = 0.811

# %%
s1 = 'works well'
s2 = 'great buy'

#calculate distance between two sentences using WMD algorithm
distance = model.wmdistance(s1, s2)

print ('distance = %.3f' % distance)
# Out:
# distance = 2.190

# %%
for eachTopic in Topics:
  if eachTopic != "works great":
#     if nlp(eachTopic).similarity(nlp("works great")) > 0.70:
    if model.wmdistance("works great", eachTopic) > 2:
      print (eachTopic)
# Out:
# well made
# sound quality
# mic stand
# playing guitar
# highly recommended
# tube amp
# little bit
# pretty much
# new one
# next time
# les paul

# %%
import gensim
#load word2vec model, here GoogleNews is used
model2 = gensim.models.KeyedVectors.load_word2vec_format('wiki-news-300d-1M-subword.vec')
#two sample sentences
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
s1 = 'works well'
s2 = 'great buy'

#calculate distance between two sentences using WMD algorithm
distance = model2.wmdistance(s1, s2)

print ('distance = %.3f' % distance)
# Out:
# distance = 1.430

# %%
for eachTopic in Topics:
  if eachTopic != "works great":
#     if nlp(eachTopic).similarity(nlp("works great")) > 0.70:
    if model2.wmdistance("works great", eachTopic) > 1.1:
      print (eachTopic)
# Out:
# well made
# highly recommend
# well built
# much better
# mic stand
# playing guitar
# highly recommended
# tube amp
# many years
# seems like
# little bit
# price point
# still use
# pretty much
# first time
# title says
# pick pocket
# new one
# tune well
# second one
# next time
# les paul
# look like

# %%
from DPU import nlp
