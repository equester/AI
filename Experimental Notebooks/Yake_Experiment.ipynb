# %%
# !pip install git+https://github.com/LIAAD/yake
# Out:
# ...
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-wpnpv9g8
#   Running command git clone -q https://github.com/LIAAD/yake /tmp/pip-req-build-wpnpv9g8
# ...
#      |████████████████████████████████| 143kB 8.0MB/s
# ...
#      |████████████████████████████████| 655kB 40.1MB/s
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j2dlowl3/wheels/be/35/27/e4ebd54b78c1806ed8b0271ce247fcd91e2bedde35889fbc9b
# ...
#   Stored in directory: /root/.cache/pip/wheels/15/ee/a8/6112173f1386d33eebedb3f73429cfa41a4c3084556bcee254
# ...
#   Stored in directory: /root/.cache/pip/wheels/e8/fe/99/d8fa8f2ef7b82a625b0b77a84d319b0b50693659823c4effb4
# ...
#   Stored in directory: /root/.cache/pip/wheels/35/e4/80/abf3b33ba89cf65cd262af8a22a5a999cc28fbfabea6b38473
# Successfully built yake segtok jellyfish regex
# ...

# %%
import yake

with open("negative.txt") as fh:
  data = fh.read()

text_content = """
	foundation makeover ini lumayan coverage
untuk tekstur ketika dipakai dimukaku lumayan ringan
mungkin untuk ketahanan masih kurang
kemasan produk ini bagus sudah ada pump nya sehingga gampang pd saat pemakaian
harga seperti foundation pd umumnya lumayan lah ya
untuk warna shade cukup bervariasi
mudah di blend pada saat pemakaian
suka sama foundation ini
biasanya aku pakai habis pakai primer dari makeover
menurutku hasilnya bagus
dan lumayan tahan lama juga
warnanya juga cocok di kulitku
so far foundation ini yang paling aku suka sih
sejauh ini cocok cocok aja pakai foundation ini warnanya pas kulit dan tidak bikin muka tambah kering
terus yang paling bagus juga packaging sih asli suka banget karena ada pump nya
tidak bohong ini foundation andalan aku
dari coverage nya bagus banget bisa cover bekas jerawat aku yang banyak padahal cuma pakai pump doang
tapi biasanya setelah aku pakai foundation lanjut pakai concealer sih buat lebih cover bekas jerawat aku hehe
warnanya juga cocok ke kulit aku
oh ya packaging praktis suka
a nice local foundation in town
tapi one thing is that this doesn't really give the matte finish it promises despite its name the final finish is rather satin-like tapi i'm not complaining since my skin is rather dry
even with my dry skin after a few hours my skin will turn oily wearing this foundation
it has perfect shade for my skin who has a rather yellowish undertone
the consistency is rather creamy than runny tapi the product still doesn't last that long if not being set with setting powder
overall this is my perfect shade of foundation tapi i'm looking for other formula of foundation that don't make my face as oily as this product
last one the packaging could've been better if the pump is covered with somewhat a lid to protect it from leaking or accidentally being pumped
the bottle is cukup besar dan berat too mungkin it's the downside of having glass tube
foundation lokal yang bagus
satu hal yang perlu diperhatikan adalah foundation ini tidak memberikan finish yang matte tapi lebih ke arah satin tapi cocok untuk kulitku yang kering
tapi dalam beberapa jam kulitku jadi berminyak setelah pakai foundation ini padahal kulitku tergolong kering
shade cocok buat kulitku yang undertone agak kuning
konsistensinya tergolong padat daripada cair tapi produk ini tetap tidak bertahan terlalu lama kalau tidak diset dengan setting powder
shade ini bagus banget buat kulitku tapi aku masih mau cari formula lain yang tidak membuat mukaku seberminyak produk ini
terakhir packaging bisa lebih baik lagi kalau pump ada tutup yang bisa mencegah produk tercecer atau tidak sengaja terpencet
botolnya juga lumayan besar dan berat mungkin karena terbuat dari kaca
wow
foundation drugstore serasa kayak foundation highend haha aku suka banget coverage nya tidak terlalu tutup banget terus cocok banget shade kulit aku walau dia matte tapi dia tidak berat banget kulit terus tidak bikin kering
terus uda dipakai seharian tidak bikin oily juga
parah love banget deh
tapi aku kurang suka aja sih sama baunya hehe
packaging ok banget karena pump begitu tidak usah takut kelebihan pas mau dipakai
pertama kali pakai ini punya adik aku dan bagus banget ringan di wajah warnanya cantik dan membuat kulit aku jadi cerah
foundation ini juga cukup tahan lama kulit aku untuk beberapa spot oily di kulit aku juga masih aman pakai foundation ini
pertama kali punya foundation dan memutuskan pakai produk dari makeover
hasilnya dimuka aku memang tidak terlalu bisa cover bekas jerawat dan wajah jadi terlihat lebih cepat oily
warnanya agak pink di wajah
foundation juara banget pakai makeup dari pagi sampai malam matte banget abis dari perjalanan jauh pun tidak berubah
tidak bikin kering dan tidak berminyak
foundation ini keren banget sih
packaging nya cakep
coverage nya medium
yang pasti nyaman dipakai tidak bikin muka panas
tekstur nya juga gampang di blend
makanya pilih ini
sayangnya waktu beli salah shade aku beli pink shade padahal harusnya ivory
tapi di set pakai powder makeover masih bisa jadi cantik
cocok banget buat kulit yang medium dan warm tone
karena kulitku di t-zone itu berminyak jadi agak dewy hasilnya
untuk bagian lain so far matte dan tidak gampang hilang
coverage nya juga lumayan bisa di build tapi tidak bisa penuh coverage
gampang juga untuk di blend dan tidak berat kerasanya kalo dipakai
jarang banget temu foundation yang shade nya pas di muka dan baru temu dan cocok banget pakai si makeover ini
hasilnya matte lumayan tahan lama dipakai almost jam masih oke banget
"""

# assuming default parameters
simple_kwextractor = yake.KeywordExtractor()
keywords = simple_kwextractor.extract_keywords(data)

for kw in keywords:
	print(kw)

# specifying parameters
custom_kwextractor = yake.KeywordExtractor(lan="id", n=2, dedupLim=0.9, dedupFunc='seqm', windowsSize=1, top=20, features=None)

keywords = custom_kwextractor.extract_keywords(text_content)

for kw in keywords:
	print(kw)
# Out:
# ('yang', 3.5573314420328355e-05)
# ('saya saya saya', 5.065219247265737e-05)
# ('anda saya saya', 6.231813439817236e-05)
# ('yang tidak', 6.537647167943246e-05)
# ('saya tidak', 7.778538871958525e-05)
# ('saya', 7.782440517661927e-05)
# ('saya saya kepada', 8.519092221651194e-05)
# ('tidak', 8.89849034076979e-05)
# ('yang saya tidak', 0.00010628117669982591)
# ('dan saya tidak', 0.00010824987238005482)
# ('saya saya anda', 0.00010905673519680161)
# ('saya anda saya', 0.00010905673519680163)
# ('dan', 0.0001095137106313604)
# ('kepada saya saya', 0.00010953118570694391)
# ('yang saya', 0.00011192707568783191)
# ('saya tidak akan', 0.00011713510360730182)
# ('untuk', 0.0001255242726625082)
# ('saya kepada saya', 0.00012778638332476788)
# ('saya saya', 0.00012964117482827542)
# ('apa yang', 0.00013842263525510047)
# ('coverage nya', 0.0013238793159873043)
# ('cover bekas', 0.00144986703855268)
# ('bekas jerawat', 0.00144986703855268)
# ('pakai foundation', 0.0019712924752585403)
# ...

# %%
# !pip install git+https://github.com/boudinfl/pke.git
# Out:
# ...
#   Cloning https://github.com/boudinfl/pke.git to /tmp/pip-req-build-0ntq33z4
#   Running command git clone -q https://github.com/boudinfl/pke.git /tmp/pip-req-build-0ntq33z4
# ...
#      |████████████████████████████████| 245kB 2.8MB/s
# ...
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9shtfss_/wheels/8d/24/54/6582e854e9e32dd6c632af6762b3a5d2f6b181c2992e165462
# Successfully built pke
# ...

# %%
# !python -m nltk.downloader stopwords
# !python -m nltk.downloader universal_tagset
# !python -m spacy download en # download the english model
# Out:
# /usr/lib/python3.6/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/lib/python3.6/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# ...

# %%
# !wget https://raw.githubusercontent.com/boudinfl/pke/master/examples/C-1.txt
# Out:
# --2019-07-25 15:34:27--  https://raw.githubusercontent.com/boudinfl/pke/master/examples/C-1.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33058 (32K) [text/plain]
# Saving to: ‘C-1.txt’
#
# C-1.txt             100%[===================>]  32.28K  --.-KB/s    in 0.01s
#
# 2019-07-25 15:34:27 (2.57 MB/s) - ‘C-1.txt’ saved [33058/33058]

# %%
# !wget https://raw.githubusercontent.com/huseinzol05/Malaya-Dataset/master/irony/negative
# Out:
# --2019-07-25 15:36:59--  https://raw.githubusercontent.com/huseinzol05/Malaya-Dataset/master/irony/negative
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 361391 (353K) [text/plain]
# Saving to: ‘negative’
#
# negative            100%[===================>] 352.92K  --.-KB/s    in 0.05s
#
# 2019-07-25 15:37:00 (6.89 MB/s) - ‘negative’ saved [361391/361391]

# %%
# !mv negative negative.txt

# %%
import pke

# initialize keyphrase extraction model, here TopicRank
extractor = pke.unsupervised.TopicRank()

# load the content of the document, here document is expected to be in raw
# format (i.e. a simple text file) and preprocessing is carried out using spacy
extractor.load_document(input='negative.txt', language='id')

# keyphrase candidate selection, in the case of TopicRank: sequences of nouns
# and adjectives (i.e. `(Noun|Adj)*`)
extractor.candidate_selection()

# candidate weighting, in the case of TopicRank: using a random walk algorithm
extractor.candidate_weighting()

# N-best selection, keyphrases contains the 10 highest scored candidates as
# (keyphrase, score) tuples
keyphrases = extractor.get_n_best(n=10)
# Out:
# WARNING:root:ISO 639 code id is not supported, switching to 'en'.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-872953f28eb3> in <module>()
#      13
#      14 # candidate weighting, in the case of TopicRank: using a random walk algorithm
# ---> 15 extractor.candidate_weighting()
#      16
#      17 # N-best selection, keyphrases contains the 10 highest scored candidates as
#
# /usr/local/lib/python3.6/dist-packages/pke/unsupervised/graph_based/topicrank.py in candidate_weighting(self, threshold, method, heuristic)
#     201
#     202         # cluster the candidates
# --> 203         self.topic_clustering(threshold=threshold, method=method)
#     204
#     205         # build the topic graph
#
# /usr/local/lib/python3.6/dist-packages/pke/unsupervised/graph_based/topicrank.py in topic_clustering(self, threshold, method)
#     150
# ...

# %%
keyphrases
# Out:
# [('uddi', 0.04283411708502489),
#  ('services', 0.03441169302548494),
#  ('registries', 0.03199063888750455),
#  ('dht', 0.029745961762536535),
#  ('grid services', 0.023208351450463065),
#  ('local proxy registry', 0.02124697857797566),
#  ('scalable grid service discovery', 0.01746073673059262),
#  ('keys', 0.015852261803247517),
#  ('query', 0.015210403621622315),
#  ('service information', 0.011774442275706109)]
