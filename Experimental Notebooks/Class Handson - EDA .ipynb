# %%
import pandas as pd                                 # Importing pandas
import numpy as np                                  # Importing numpy
import matplotlib.pyplot as plt                     # Importing matplotlib for visualization

# %matplotlib inline                      
import seaborn as sns                               # Importing seaborn for visualization

import matplotlib.ticker as ticker
import matplotlib.cm as cm

import pandas_profiling                             # AUtomatic EDA

import ipywidgets as widgets                        # Creating widgets
from IPython.display import display                 # Displaying widgets

# %%
zomato_df = pd.read_csv('zomato.csv',encoding = "ISO-8859-1")    # Reading file zomato.csv

# %%
zomato_df[['City','Locality']][:200]
# Out:
#                        City                                           Locality
# 0               Makati City          Century City Mall, Poblacion, Makati City
# 1               Makati City         Little Tokyo, Legaspi Village, Makati City
# 2          Mandaluyong City         Edsa Shangri-La, Ortigas, Mandaluyong City
# 3          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 4          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 5          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 6                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 7                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 8                Pasay City        Sofitel Philippine Plaza Manila, Pasay City
# 9                Pasig City                                          Kapitolyo
# 10               Pasig City                                          Kapitolyo
# ...

# %%
# Manish
zomato_df.loc[0:200,['City','Locality']]
# Out:
#                        City                                           Locality
# 0               Makati City          Century City Mall, Poblacion, Makati City
# 1               Makati City         Little Tokyo, Legaspi Village, Makati City
# 2          Mandaluyong City         Edsa Shangri-La, Ortigas, Mandaluyong City
# 3          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 4          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 5          Mandaluyong City             SM Megamall, Ortigas, Mandaluyong City
# 6                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 7                Pasay City    SM by the Bay, Mall of Asia Complex, Pasay City
# 8                Pasay City        Sofitel Philippine Plaza Manila, Pasay City
# 9                Pasig City                                          Kapitolyo
# 10               Pasig City                                          Kapitolyo
# ...

# %%
#Pramod
zomato_df.loc[1:200,["City","Address"]]

# %%
#venkat
zomato_df[(zomato_df["City"] == 'Makati City') & (zomato_df["Aggregate rating"] > 4)]
# Out:
#    Restaurant ID   Restaurant Name  ...  Rating text Votes
# 0        6317637  Le Petit Souffle  ...    Excellent   314
# 1        6304287  Izakaya Kikufuji  ...    Excellent   591
#
# [2 rows x 21 columns]

# %%
#

# %%
#Venkat
zomato_df[zomato_df["Restaurant Name"].str.contains('pizza', case=False)]
# Out:
#      Restaurant ID                          Restaurant Name  ...  Rating text Votes
# 26         6600970                           Pizza íæ Bessa  ...      Average    11
# 131       17294441  Giuseppe's Pizza & Italian Specialities  ...    Very Good   430
# 154       17303646                      Flying Pie Pizzaria  ...    Very Good   550
# 156       17303684    Guido's Original New York Style Pizza  ...    Very Good   410
# 179       17316374                    A & A Pagliai's Pizza  ...    Very Good   485
# 217       17334254        Tony's Italian Restaurant & Pizza  ...         Good   116
# 231       17335225                   Crust Stone Oven Pizza  ...         Good   136
# 256       17259368                             Fong's Pizza  ...    Excellent   728
# 277       17342548            Happy Joe's Pizza & Ice Cream  ...         Good    74
# 324       17500759                  Ingleside Village Pizza  ...    Excellent   478
# ...

# %% [markdown]
# create a column -> such that, if Rest Name contains piizaa, then the value in column should be 1, else 0 ; Apply Function

# %%
if 
elif
else


eachValue ---> Partial "Text" ; == "Pizza"
La pino Pizza

# %%
zomato_df.assign(**{'New column':apply(if bool(zomato_df['Restaurant Name'].str.contains('Pizza'))=1 else return 0)})
# Out:
#   File "<ipython-input-25-4a05f4e47d4e>", line 1
#     zomato_df.assign(**{'New column':apply(if bool(zomato_df['Restaurant Name'].str.contains('Pizza'))=1 else return 0)})
#                                             ^
# SyntaxError: invalid syntax

# %%
S = "I love pizza and burger"
if "pizza".lower() in S.lower():
  print ("Found")
# Out:
# Found

# %%
# !pip install fuzzywuzzy[speedup]
# Out:
# ...
#      |████████████████████████████████| 51kB 3.8MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-levenshtein
# ...

# %%
from fuzzywuzzy import fuzz
fuzz.ratio("pizza", "La pino Pizza")
# Out:
# 56

# %%
import re
from fuzzywuzzy import fuzz



# Logic 
"""
Column with Rest Name 

-> Filter all Names where, it has nothing to do with Pizza
  -> Break the words into tokens 
      --> For each token, check fuzzymatch ratio
            ---> eachToken should be >50
      -->For overall token , ratio can be >30
      
--> Use, IF and Not For 
--> Tried Regex ( String Matching Functionality )
--> Use Apply function on table for each row ( no for loop )




"""

# Code 

# Hemant's Code 
# from fuzzywuzzy import process
# length=len(zomato_df['Restaurant Name'])
# process.extract("pizza", zomato_df['Restaurant Name'], scorer=fuzz.token_set_ratio, limit=length)


# Venkat's Code 
import re
from fuzzywuzzy import fuzz
def findValue(val):
#   if(val.find("pizza")):
  if(re.search("piz+a+[a-z]*$", val.lower()) or (fuzz.ratio("pizza", val.lower()) > 60)) :
    return 1
  else:
    return 0
  
# %time zomato_df["pizzaRest"] = zomato_df["Restaurant Name"].apply(findValue)
zomato_df[zomato_df["pizzaRest"]==1]["Restaurant Name"]
print (zomato_df[zomato_df['pizzaRest'] == 1]['Restaurant Name'])

"""
def evaluateString(eachvalue):
#   if KeyWord.lower() in eachvalue.lower():
  
  if fuzz.ratio(KeyWord.lower(), eachvalue.lower())>30:
#   if re.search(KeyWord, eachvalue.lower()):
    return 1
  else:
    return 0

global KeyWord
KeyWord = "piz+a$"
# pizza 
# pizzzzaa
#pizaaaa
#pizzzaaaaaa
#pppppppzaaa
# %time zomato_df['NewValue'] = zomato_df['Restaurant Name'].apply(evaluateString)
zomato_df[zomato_df['NewValue'] == 1]['Restaurant Name']


# Fuzzy String Match 


# Hint:

1) Use Regex 
2) Use Token For Loop --->   For eachWord in EachValue:
                                  FuzzyRatio (KeyWOrd, EachWOrd )>60
                                      ---> Update this to DAta Strcture 
      
Assignment: 
  
  Remove all Rest Name, where there is nothing related to word PIZZAA
  
"""
# Out:
# CPU times: user 63 ms, sys: 2.59 ms, total: 65.6 ms
# Wall time: 67.2 ms
# 154                       Flying Pie Pizzaria
# 156     Guido's Original New York Style Pizza
# 179                     A & A Pagliai's Pizza
# 217         Tony's Italian Restaurant & Pizza
# 231                    Crust Stone Oven Pizza
# 256                              Fong's Pizza
# 324                   Ingleside Village Pizza
# 477                           Bob Roe's Pizza
# 483                             Jerry's Pizza
# 493                            El Fredo Pizza
# 613                                 Pizza Hut
# 641                                 Pizza Hut
# 648                        Fozzie's Pizzaiolo
# 649                           La Pino'z Pizza
# 657                                  Puffizza
# 674                                 Pizza Hut
# 709                            Domino's Pizza
# 753                                 Pizza Hut
# 757                               Da pizzeria
# ...

# %%
import re
from fuzzywuzzy import fuzz
def findValue(val):
  if(re.search("pi[a-z]+$", val.lower()) or (fuzz.ratio("pizza", val.lower()) > 70)) :
    return 1
  else:
    return 0
  
# %time zomato_df["pizzaRest"] = zomato_df["Restaurant Name"].apply(findValue)
zomato_df[zomato_df["pizzaRest"]==1]["Restaurant Name"]
print (zomato_df[zomato_df['pizzaRest'] == 1]['Restaurant Name'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-07ae8b821b5e> in <module>()
#       1 import re
# ----> 2 from fuzzywuzzy import fuzz
#       3 def findValue(val):
#       4   if(re.search("pi[a-z]+$", val.lower()) or (fuzz.ratio("pizza", val.lower()) > 70)) :
#       5     return 1
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import re
def findValue(val):
#   if(val.find("pizza")):
  re.search("pi[a-z]+$", val.lower()) ||
  if "pizza" in val:
    return 1
  else:
    return 0
  
findfunc = zomato_df["Restaurant Name"].apply(findValue)
findfunc
# Out:
#   File "<ipython-input-18-a1cdd6e2ffcb>", line 4
#     re.search("pi[a-z]+$", val.lower()) ||
#                                          ^
# SyntaxError: invalid syntax
