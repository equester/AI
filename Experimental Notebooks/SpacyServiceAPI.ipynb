# %%
# !pip install spacy_api[all]
# Out:
# Collecting spacy_api[all]
#   Downloading https://files.pythonhosted.org/packages/b5/b6/681f430da9221c117a2c931ee0bc4485365aee1773504acc17e8f6c83990/spacy_api-0.4.50-py2.py3-none-any.whl
#   spacy-api 0.4.50 does not provide the extra 'all'
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from spacy_api[all]) (1.16.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.6/dist-packages (from spacy_api[all]) (3.1.0)
# Collecting mprpc (from spacy_api[all])
#   Downloading https://files.pythonhosted.org/packages/08/dd/87e7e3290c00e28423e46b483d288f13ddcc88bf71fd0677b619bdee32d3/mprpc-0.1.17.tar.gz (116kB)
#     100% |████████████████████████████████| 122kB 10.7MB/s
# Collecting gsocketpool (from mprpc->spacy_api[all])
#   Downloading https://files.pythonhosted.org/packages/af/3d/a9a5636e855908375a3a06e2eada48ce1bf2bd6eba07651dd019772f648d/gsocketpool-0.1.6.tar.gz
# Requirement already satisfied: gevent in /usr/local/lib/python3.6/dist-packages (from mprpc->spacy_api[all]) (1.4.0)
# Collecting msgpack-python (from mprpc->spacy_api[all])
#   Downloading https://files.pythonhosted.org/packages/8a/20/6eca772d1a5830336f84aca1d8198e5a3f4715cd1c7fc36d3cc7f7185091/msgpack-python-0.5.6.tar.gz (138kB)
#     100% |████████████████████████████████| 143kB 14.4MB/s
# Requirement already satisfied: greenlet>=0.4.14; platform_python_implementation == "CPython" in /usr/local/lib/python3.6/dist-packages (from gevent->mprpc->spacy_api[all]) (0.4.15)
# Building wheels for collected packages: mprpc, gsocketpool, msgpack-python
#   Building wheel for mprpc (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/19/97/c9/0e426dcf413d369a3a9c3fce61d8ed84da96d90c5b894499ad
#   Building wheel for gsocketpool (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/25/5d/1f/06594e19a4e3b66de8add3d3987cfe3d522a945177b48981a8
#   Building wheel for msgpack-python (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/d5/de/86/7fa56fda12511be47ea0808f3502bc879df4e63ab168ec0406
# Successfully built mprpc gsocketpool msgpack-python
# Installing collected packages: gsocketpool, msgpack-python, mprpc, spacy-api
# Successfully installed gsocketpool-0.1.6 mprpc-0.1.17 msgpack-python-0.5.6 spacy-api-0.4.50

# %%
# !spacy serve
# Out:
# Serving spacy_api at 127.0.0.1:9033
# KeyboardInterrupt
# 2019-04-17T11:29:25Z
# Traceback (most recent call last):
#   File "/usr/local/bin/spacy", line 10, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.6/dist-packages/spacy_api/__main__.py", line 26, in main
#     serve(args.host, args.port)
#   File "/usr/local/lib/python3.6/dist-packages/spacy_api/server.py", line 36, in serve
#     server.serve_forever()
#   File "/usr/local/lib/python3.6/dist-packages/gevent/baseserver.py", line 369, in serve_forever
#     self._stop_event.wait()
#   File "src/gevent/event.py", line 127, in gevent._event.Event.wait
#   File "src/gevent/_abstract_linkable.py", line 192, in gevent.__abstract_linkable.AbstractLinkable._wait
#   File "src/gevent/_abstract_linkable.py", line 165, in gevent.__abstract_linkable.AbstractLinkable._wait_core
#   File "src/gevent/_abstract_linkable.py", line 169, in gevent.__abstract_linkable.AbstractLinkable._wait_core
#   File "src/gevent/_greenlet_primitives.py", line 60, in gevent.__greenlet_primitives.SwitchOutGreenletWithLoop.switch
#   File "src/gevent/_greenlet_primitives.py", line 60, in gevent.__greenlet_primitives.SwitchOutGreenletWithLoop.switch
#   File "src/gevent/_greenlet_primitives.py", line 64, in gevent.__greenlet_primitives.SwitchOutGreenletWithLoop.switch
#   File "src/gevent/__greenlet_primitives.pxd", line 35, in gevent.__greenlet_primitives._greenlet_switch
# KeyboardInterrupt

# %%
from spacy_api import Client

spacy_client = Client() # default args host/port

doc = spacy_client.single("How are you")
doc
# [[How, are, you]]

# iterate over sentences
for sentence in doc.sents:
    for token in sentence:
        print(token.text, token.pos_, token.lemma_)

# iterate over a whole document
for token in doc:
    print(token)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-4-39399bbd60c5> in <module>()
#       1 from spacy_api import Client
#       2
# ----> 3 spacy_client = Client() # default args host/port
#       4
#       5 doc = spacy_client.single("How are you")
#
# /usr/local/lib/python3.6/dist-packages/spacy_api/client.py in __init__(self, host, port, model, embeddings_path, verbose, attributes)
#     116         self.host = host
#     117         self.port = port
# --> 118         self.rpc = RPCClient(host, port)
#     119         self.verbose = verbose
#     120         self.attributes = attributes
#
# /usr/local/lib/python3.6/dist-packages/mprpc/client.pyx in mprpc.client.RPCClient.__init__()
#
# /usr/local/lib/python3.6/dist-packages/mprpc/client.pyx in mprpc.client.RPCClient.open()
#
# /usr/local/lib/python3.6/dist-packages/gevent/socket.py in create_connection(address, timeout, source_address)
#      94             if source_address:
#      95                 sock.bind(source_address)
# ---> 96             sock.connect(sa)
#      97         except error:
#      98             if sock is not None:
#
# /usr/local/lib/python3.6/dist-packages/gevent/_socket3.py in connect(self, address)
#     333                 err = self.getsockopt(SOL_SOCKET, SO_ERROR)
#     334                 if err:
# --> 335                     raise error(err, strerror(err))
#     336                 result = _socket.socket.connect_ex(self._sock, address)
#     337
#
# ConnectionRefusedError: [Errno 111] Connection refused
