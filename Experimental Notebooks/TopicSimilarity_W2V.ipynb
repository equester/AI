# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M-subword.zip
# !unzip crawl-300d-2M-subword.zip
# Out:
# --2019-07-02 09:39:38--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M-subword.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.20.22.166, 104.20.6.166, 2606:4700:10::6814:16a6, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.20.22.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5828358084 (5.4G) [application/zip]
# Saving to: ‘crawl-300d-2M-subword.zip’
#
# crawl-300d-2M-subwo 100%[===================>]   5.43G  13.0MB/s    in 7m 10s
#
# 2019-07-02 09:46:50 (12.9 MB/s) - ‘crawl-300d-2M-subword.zip’ saved [5828358084/5828358084]
#
# Archive:  crawl-300d-2M-subword.zip
#   inflating: crawl-300d-2M-subword.vec
#   inflating: crawl-300d-2M-subword.bin

# %%
import gensim
#load word2vec model, here GoogleNews is used
# %time model2 = gensim.models.KeyedVectors.load_word2vec_format('crawl-300d-2M-subword.vec')
#two sample sentences
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# CPU times: user 9min 26s, sys: 7.31 s, total: 9min 34s
# Wall time: 9min 33s

# %%
Topics = [
"works great",
"well made",
"works well",
"sound great",
"long time",
"well worth",
"work well",
"sounds great",
"highly recommend",
"work great",
"great price",
"sound quality",
"great product",
"well built",
"much better",
"pedal board",
"addario strings",
"mic stand",
"make sure",
"works fine",
"playing guitar",
"one thing",
"guitar strap",
"pop filter",
"works perfectly",
"work fine",
"go wrong",
"highly recommended",
"great strings",
"new strings",
"tube amp",
"great sound",
"looks like",
"electric guitar",
"well constructed",
"guitar strings",
"many years",
"strap locks",
"seems like",
"years ago",
"last longer",
"worked great",
"get one",
"acoustic guitar",
"coated strings",
"elixir strings",
"little bit",
"price range",
"play guitar",
"string winder",
"planet waves",
"great quality",
"pick holder",
"price point",
"guitar case",
"reasonable price",
"bought one",
"still use",
"looks great",
"works like",
"sound like",
"last forever",
"pretty much",
"first time",
"solid construction",
"title says",
"sturdy enough",
"great value",
"power supply",
"reasonably priced",
"new guitar",
"pick pocket",
"electric guitars",
"new one",
"tune well",
"take care",
"string cutter",
"guitar stand",
"second one",
"much easier",
"first one",
"great deal",
"pleasantly surprised",
"worked well",
"next time",
"sound better",
"try one",
"low price",
"worked fine",
"les paul",
"great tone",
"strap button",
"sounds like",
"look like",
"right amount",
"great buy",
"truss rod",
"tortex picks"
]

# %%
s1 = 'works well'
s2 = 'great buy'

#calculate distance between two sentences using WMD algorithm
distance = model2.wmdistance(s1, s2)

print ('distance = %.3f' % distance)
# Out:
# distance = 1.958

# %%
for eachTopic in Topics:
  if eachTopic != "works great":
#     if nlp(eachTopic).similarity(nlp("works great")) > 0.70:
    if model2.wmdistance("playing guitar", eachTopic) > 1.5:
      print (eachTopic)
# Out:
# well made
# works well
# well worth
# work well
# highly recommend
# work great
# well built
# much better
# pedal board
# mic stand
# make sure
# works fine
# one thing
# works perfectly
# work fine
# go wrong
# highly recommended
# tube amp
# looks like
# well constructed
# many years
# strap locks
# seems like
# years ago
# worked great
# get one
# little bit
# pick holder
# bought one
# still use
# works like
# sound like
# last forever
# pretty much
# first time
# power supply
# pick pocket
# new one
# tune well
# take care
# second one
# much easier
# first one
# worked well
# next time
# sound better
# try one
# low price
# worked fine
# sounds like
# look like
# truss rod
# tortex picks
