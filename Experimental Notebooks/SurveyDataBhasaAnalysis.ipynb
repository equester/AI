# %%
import pandas as pd

# %%
data = pd.read_csv("surveydata.csv", encoding='utf-8')

# %%
data.head(5)
# Out:
#                                             S_128_5  \
# 0  rasaanya kalau dibikin olesan roti terlalu manis
# 1                          rasa gurih kurang terasa
# 2           kurang manis dikit karena rotinya tawar
# 3                             warnanya kurang gelap
# 4                              warna susunya kurang
#
#                                           Unnamed: 1
# 0     it's too sweet to make it as a jam for a bread
# 1                                    it's less tasty
# 2  it needs to be sweeter if you use it for a whi...
# 3         the colour needs to be a liitle bit darker
# 4                                   the milk colour

# %%
data.columns
# Out:
# Index(['S_128_5', 'Unnamed: 1', 'English_tranlated', 'ranked_topic_tranlated'], dtype='object')

# %%
# !pip install rake_nltk
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# ...

# %%
# !pip install googletrans
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/50/d6/e7/a8efd5f2427d5eb258070048718fa56ee5ac57fd6f53505f95
# Successfully built googletrans
# ...

# %%
from rake_nltk import Rake
from textblob import TextBlob
from googletrans import Translator

# Uses stopwords for english from NLTK, and all puntuation characters by
# default


#Transalton to English 
def translate_to_english(eachRow):
  translator = Translator()
  return translator.translate(eachRow).text
#   try:
#   print (TextBlob(eachRow).translate(to='en'))
#   return str(TextBlob(eachRow).translate(to='en'))
#   except:
#     print("except condition")
#     return ""



#Rank Topic Models with length 1
def ranked_topic_model(eachRow):
  try:
#     print (eachRow)
#     print (type(eachRow))
    r = Rake()
    r.extract_keywords_from_text(eachRow)
  #   print (GroupedReviews[[ProductNumber]])
  #   print ([eachTuple for eachTuple in r.get_ranked_phrases_with_scores() if len(eachTuple[1].split())<2 and len(eachTuple[1].split())>1])
  #   return [eachTuple for eachTuple in r.get_ranked_phrases_with_scores() if len(eachTuple[1].split())<2 and len(eachTuple[1].split())>1]
  #   print (r.get_ranked_phrases_with_scores())
    return r.get_ranked_phrases_with_scores()
  except TypeError:
    return ""
  
  
def get_noun


def get_adjective


def get_pos_tag_all


def get_noun_chunck

# %%
data['English_tranlated'] = data['S_128_5'].apply(translate_to_english)
data['ranked_topic_tranlated'] = data['English_tranlated'].apply(ranked_topic_model)
data['ranked_topic_original_english'] = data['Unnamed: 1'].apply(ranked_topic_model)
data.tail(5)
# Out:
#                                            S_128_5  \
# 337  rasa manis pas karena kandungan gula rendah//
# 338  kadar gulanya rendah tapi tetap sama lezatnya
# 339   rasanya kezat // rasa secara keseluruhan pas
# 340          rasa manisnya pas tidak terlalu manis
# 341                     Rasa manisnya  tetap manis
#
#                                            Unnamed: 1  \
# 337  the sweetness taste good because it's less sugar
# 338    less sugar but the delicious is still the same
# 339   it taste delicious// over all the taste is good
# 340            the sweetness taste good not too sweet
# 341                         the sweetness still sweet
#
#                                      English_tranlated  \
# 337  sweetness is right because of the low sugar co...
# 338           low sugar content but still as delicious
# 339        it tastes delicious / flavored whole passes
# 340                         The sweetness is not sweet
# ...

# %%
data.to_csv("surveyData.csv")

# %%
eachRow ="Rasa manisnya tetap manis	"
translator = Translator()
translator.translate(eachRow).text
# Out:
# 'The sweetness remains sweet'

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
from textblob import TextBlob
review = TextBlob('because it is available in the nearest warung, the price is affordable and the packaging is practical and the taste of the milk is delicious, just right')
print(review.tags)
print(review.noun_phrases)
# Out:
# [('because', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('available', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('nearest', 'JJS'), ('warung', 'NN'), ('the', 'DT'), ('price', 'NN'), ('is', 'VBZ'), ('affordable', 'JJ'), ('and', 'CC'), ('the', 'DT'), ('packaging', 'NN'), ('is', 'VBZ'), ('practical', 'JJ'), ('and', 'CC'), ('the', 'DT'), ('taste', 'NN'), ('of', 'IN'), ('the', 'DT'), ('milk', 'NN'), ('is', 'VBZ'), ('delicious', 'JJ'), ('just', 'RB'), ('right', 'RB')]
# []

# %%
# !python -m spacy download en_core_web_lg
# Out:
# ...
#     100% |████████████████████████████████| 852.3MB 52.5MB/s
# ...
#   Running setup.py install for en-core-web-lg ... done
# ...
#
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/en_core_web_lg -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/en_core_web_lg
#
#     You can now load the model via spacy.load('en_core_web_lg')

# %%
review1 = u"""the sweetness tatse good not too much, tasty enough, the viscosity is enough, the milk smells good, and when you drink it the throat feels good it's not sticky"""

# %%
review2 = u"""the sweetness is right not too, there is a savory taste that is right, the thickness is right, the milk aroma is right, when you drink it in the tasty throat it's not sticky"""

# %%
import spacy

nlp = spacy.load('en_core_web_lg')
doc = nlp(u"""because my kid really like it and because it's lower sugar content, contains vitamin and mineral, and the price is affordable""")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# because because ADP IN mark xxxx True False
# my -PRON- ADJ PRP$ poss xx True False
# kid kid NOUN NN nsubj xxx True False
# really really ADV RB advmod xxxx True False
# like like ADP IN ROOT xxxx True False
# it -PRON- PRON PRP dobj xx True False
# and and CCONJ CC cc xxx True False
# because because ADP IN mark xxxx True False
# it -PRON- PRON PRP nsubj xx True False
# 's be VERB VBZ conj 'x False False
# lower low ADJ JJR amod xxxx True False
# sugar sugar NOUN NN compound xxxx True False
# content content NOUN NN attr xxxx True False
# , , PUNCT , punct , False False
# contains contain VERB VBZ conj xxxx True False
# vitamin vitamin NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# mineral mineral NOUN NN conj xxxx True False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True False
# the the DET DT det xxx True False
# price price NOUN NN nsubj xxxx True False
# is be VERB VBZ conj xx True False
# ...

# %%
import spacy

nlp = spacy.load('en_core_web_lg')

# %%
doc = nlp(review1)

print("Noun")
for token in doc:
  if token.tag_ == 'NN':
    print (token.text)
  
print("Adjective")
for token in doc:
  if token.tag_ == 'JJ':
    print (token.text)
# Out:
# Noun
# sweetness
# viscosity
# milk
# throat
# Adjective
# good
# tasty
# enough
# good
# good
# sticky

# %%
doc = nlp(review2)

print("Noun")
for token in doc:
  if token.tag_ == 'NN':
    print (token.text)
  
print("Adjective")
for token in doc:
  if token.tag_ == 'JJ':
    print (token.text)

# %%
doc = nlp(review1)
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_,
          chunk.root.head.text)
# Out:
# the sweetness sweetness nsubj tatse
# the viscosity viscosity nsubj is
# the milk milk nsubj smells
# you you nsubj drink
# it it dobj drink
# the throat throat nsubj feels
# it it nsubj 's

# %%
doc = nlp(review2)
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_,
          chunk.root.head.text)
# Out:
# the sweetness sweetness nsubj is
# a savory taste taste attr is
# the thickness thickness nsubj is
# the milk aroma aroma nsubj is
# you you nsubj drink
# it it dobj drink
# the tasty throat throat pobj in
# it it nsubj 's

# %%
doc = nlp(review1)
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
          [child for child in token.children])
# Out:
# the det sweetness NOUN []
# sweetness nsubj tatse VERB [the]
# tatse ccomp is VERB [sweetness, good, ,, tasty]
# good acomp tatse VERB [much]
# not neg much ADV []
# too advmod much ADV []
# much advmod good ADJ [not, too]
# , punct tatse VERB []
# tasty amod tatse VERB [enough]
# enough advmod tasty ADJ []
# , punct is VERB []
# the det viscosity NOUN []
# viscosity nsubj is VERB [the]
# is ROOT is VERB [tatse, ,, viscosity, enough, smells]
# enough acomp is VERB []
# , punct smells VERB []
# the det milk NOUN []
# milk nsubj smells VERB [the]
# smells conj is VERB [,, milk, good, ,, and, feels]
# good acomp smells VERB []
# , punct smells VERB []
# and cc smells VERB []
# when advmod drink VERB []
# you nsubj drink VERB []
# drink advcl feels VERB [when, you, it]
# it dobj drink VERB []
# the det throat NOUN []
# throat nsubj feels VERB [the]
# feels conj smells VERB [drink, throat, good]
# good acomp feels VERB []
# it nsubj 's VERB []
# 's ROOT 's VERB [it, not, sticky]
# ...

# %%
doc = nlp(review2)
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
          [child for child in token.children])
# Out:
# the det sweetness NOUN []
# sweetness nsubj is VERB [the]
# is ccomp is VERB [sweetness, right, too]
# right acomp is VERB []
# not neg too ADV []
# too advmod is VERB [not]
# , punct is VERB []
# there expl is VERB []
# is ccomp is VERB [is, ,, there, taste]
# a det taste NOUN []
# savory amod taste NOUN []
# taste attr is VERB [a, savory, is]
# that nsubj is VERB []
# is relcl taste NOUN [that, right]
# right acomp is VERB []
# , punct is VERB []
# the det thickness NOUN []
# thickness nsubj is VERB [the]
# is ccomp 's VERB [is, ,, thickness, right]
# right acomp is VERB []
# , punct is VERB []
# the det aroma NOUN []
# milk compound aroma NOUN []
# aroma nsubj is VERB [the, milk]
# is ccomp 's VERB [,, aroma, right, ,]
# right acomp is VERB []
# , punct is VERB []
# when advmod drink VERB []
# you nsubj drink VERB []
# drink advcl 's VERB [when, you, it, in]
# it dobj drink VERB []
# in prep drink VERB [throat]
# the det throat NOUN []
# tasty amod throat NOUN []
# ...

# %%
doc = nlp(review1)
print([token.text for token in doc[2].lefts])  # ['bright', 'red']
print([token.text for token in doc[2].rights])  # ['on']
print(doc[2].n_lefts)  # 2
print(doc[2].n_rights)  # 1
# Out:
# ['sweetness']
# ['good', ',', 'tasty']
# 1
# 3

# %%
doc = nlp(review1)
root = [token for token in doc if token.head == token][0]
subject = list(root.lefts)[0]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    print(descendant.text, descendant.dep_, descendant.n_lefts,
          descendant.n_rights,
          [ancestor.text for ancestor in descendant.ancestors])
# Out:
# the det 0 0 ['sweetness', 'tatse', 'is']
# sweetness nsubj 1 0 ['tatse', 'is']
# tatse ccomp 1 3 ['is']
# good acomp 0 1 ['tatse', 'is']
# not neg 0 0 ['much', 'good', 'tatse', 'is']
# too advmod 0 0 ['much', 'good', 'tatse', 'is']
# much advmod 2 0 ['good', 'tatse', 'is']
# , punct 0 0 ['tatse', 'is']
# tasty amod 0 1 ['tatse', 'is']
# enough advmod 0 0 ['tasty', 'tatse', 'is']

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="123-0" class="displacy" width="5300" height="662.0" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">sweetness</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">tatse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# ...

# %%
doc = nlp(review2)
root = [token for token in doc if token.head == token][0]
subject = list(root.lefts)[0]
for descendant in subject.subtree:
    assert subject is descendant or subject.is_ancestor(descendant)
    print(descendant.text, descendant.dep_, descendant.n_lefts,
          descendant.n_rights,
          [ancestor.text for ancestor in descendant.ancestors])
# Out:
# the det 0 0 ['sweetness', 'is', 'is', 'is', "'s"]
# sweetness nsubj 1 0 ['is', 'is', 'is', "'s"]
# is ccomp 1 2 ['is', 'is', "'s"]
# right acomp 0 0 ['is', 'is', 'is', "'s"]
# not neg 0 0 ['too', 'is', 'is', 'is', "'s"]
# too advmod 1 0 ['is', 'is', 'is', "'s"]
# , punct 0 0 ['is', 'is', "'s"]
# there expl 0 0 ['is', 'is', "'s"]
# is ccomp 3 1 ['is', "'s"]
# a det 0 0 ['taste', 'is', 'is', "'s"]
# savory amod 0 0 ['taste', 'is', 'is', "'s"]
# taste attr 2 1 ['is', 'is', "'s"]
# that nsubj 0 0 ['is', 'taste', 'is', 'is', "'s"]
# is relcl 1 1 ['taste', 'is', 'is', "'s"]
# right acomp 0 0 ['is', 'taste', 'is', 'is', "'s"]
# , punct 0 0 ['is', "'s"]
# the det 0 0 ['thickness', 'is', "'s"]
# thickness nsubj 1 0 ['is', "'s"]
# is ccomp 3 1 ["'s"]
# right acomp 0 0 ['is', "'s"]

# %%
doc = nlp(review1)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
